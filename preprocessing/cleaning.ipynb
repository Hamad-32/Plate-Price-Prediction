# %%
import numpy as py 
import pandas as pd

# %%
df = pd.read_csv('lu7ah.csv')

# %%
df1 = pd.read_csv('mazad.csv')

# %%
df2 = pd.read_csv('mazad1.csv')

# %%
df.head()
# Out:
#   chakra-text 4 chakra-text 5 chakra-text 6 chakra-text 7 chakra-text 8  \
# 0             ر            هـ             م             R             H
# 1             ر            هـ             م             R             H
# 2             ر            هـ             م             R             H
# 3             ب             ل             ل             B             L
# 4             د             ص             م             D             X
#
#   chakra-text 9  chakra-text 10 chakra-text 12 chakra-text 14 chakra-text 16  \
# 0             Z            9777         الرياض     2025-03-13           6500
# 1             Z            9888         الرياض     2025-03-13           6500
# 2             Z            9666         الرياض     2025-03-13           6500
# 3             L            1116         الرياض     2025-03-13      على السوم
# 4             Z              77            مكة     2025-03-13          23000
#
#                                   chakra-image src 3  \
# ...

# %%
df.shape
# Out:
# (2430, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['chakra-text 16'] != 'على السوم']
# Out:
#      chakra-text 4 chakra-text 5 chakra-text 6 chakra-text 7 chakra-text 8  \
# 0                ر            هـ             م             R             H
# 1                ر            هـ             م             R             H
# 2                ر            هـ             م             R             H
# 4                د             ص             م             D             X
# 11               ق             ح             ط             G             J
# ...            ...           ...           ...           ...           ...
# 2410             أ             ل             م             A             L
# 2420             م             ك             ق             Z             K
# 2422             ق             ق             ق             G             G
# 2423             ر             ع             ب             R             E
# 2427            هـ             ع             ل             H             E
#
#      chakra-text 9  chakra-text 10 chakra-text 12 chakra-text 14  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2430 entries, 0 to 2429
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   chakra-text 4       2430 non-null   object
#  1   chakra-text 5       2430 non-null   object
#  2   chakra-text 6       2430 non-null   object
#  3   chakra-text 7       2430 non-null   object
#  4   chakra-text 8       2430 non-null   object
#  5   chakra-text 9       2430 non-null   object
#  6   chakra-text 10      2430 non-null   int64
#  7   chakra-text 12      2430 non-null   object
#  8   chakra-text 14      2430 non-null   object
#  9   chakra-text 16      2430 non-null   object
#  10  chakra-image src 3  762 non-null    object
#  11  chakra-button href  2430 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 227.9+ KB

# %%
df = df[df['chakra-text 16'] !='على السوم']

# %%
df['chakra-text 16'] = pd.to_numeric(df['chakra-text 16'].str.replace(',', '', regex=True), errors='coerce').astype('Int64')

# %%
df['chakra-text 16'].describe()
# Out:
# count            726.0
# mean      56820.384298
# std      281261.931871
# min                0.0
# 25%             9000.0
# 50%            18500.0
# 75%            35000.0
# max          5250000.0
# Name: chakra-text 16, dtype: Float64

# %%
df[df['chakra-text 16'] == 0 ]
# Out:
#      chakra-text 4 chakra-text 5 chakra-text 6 chakra-text 7 chakra-text 8  \
# 580              ب             ع             و             B             E
# 691              أ             د             ب             A             D
# 823              ح             ل             أ             J             L
# 923              ح             ب             ك             J             B
# 1008             و             م             ل             U             Z
# 1207             ع             ك             س             E             K
# 1262             ح             ب             ن             J             B
# 1608             ق             د            هـ             G             D
# 1859             أ             و             ط             A             U
# 1896             ر             ب             د             R             B
# 1911             ر             ع             ب             R             E
#
#      chakra-text 9  chakra-text 10 chakra-text 12 chakra-text 14  \
# ...

# %%
df=df[df['chakra-text 16'] != 0 ]

# %%
df['chakra-text 16'].unique()
# Out:
# <IntegerArray>
# [   6500,   23000,   24500,   15000,   32000,   14000,    3300,    4000,
#     1500,   17500,
#  ...
#   220000,   93000,  500000,    9500,    4900, 5250000,  105000, 4000000,
#     2800,    4100]
# Length: 122, dtype: Int64

# %%
df.tail()
# Out:
#      chakra-text 4 chakra-text 5 chakra-text 6 chakra-text 7 chakra-text 8  \
# 2410             أ             ل             م             A             L
# 2420             م             ك             ق             Z             K
# 2422             ق             ق             ق             G             G
# 2423             ر             ع             ب             R             E
# 2427            هـ             ع             ل             H             E
#
#      chakra-text 9  chakra-text 10 chakra-text 12 chakra-text 14  \
# 2410             Z            8288         الرياض     2024-11-01
# 2420             G             802          بريدة     2024-10-31
# 2422             G              16         الرياض     2024-10-30
# 2423             B            2328           أخرى     2024-10-30
# 2427             L              20            جدة     2024-10-30
#
#       chakra-text 16                                 chakra-image src 3  \
# ...

# %%
df.columns = ['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en','Plate number','City','Publication date','price','Href','image']  # تأكد من تطابق عدد الأسماء مع عدد الأعمدة

# %%
df
# Out:
#      char1_ar char2_ar char3_ar char1_en char2_en char3_en  Plate number  \
# 0           ر       هـ        م        R        H        Z          9777
# 1           ر       هـ        م        R        H        Z          9888
# 2           ر       هـ        م        R        H        Z          9666
# 4           د        ص        م        D        X        Z            77
# 11          ق        ح        ط        G        J        T           980
# ...       ...      ...      ...      ...      ...      ...           ...
# 2410        أ        ل        م        A        L        Z          8288
# 2420        م        ك        ق        Z        K        G           802
# 2422        ق        ق        ق        G        G        G            16
# 2423        ر        ع        ب        R        E        B          2328
# 2427       هـ        ع        ل        H        E        L            20
#
#         City Publication date   price  \
# 0     الرياض       2025-03-13    6500
# ...

# %%
df = df.drop(columns=['Href','image','City','Publication date'] )

# %%
df.head(2)
# Out:
#   char1_ar char2_ar char3_ar char1_en char2_en char3_en  Plate number  price
# 0        ر       هـ        م        R        H        Z          9777   6500
# 1        ر       هـ        م        R        H        Z          9888   6500

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 715 entries, 0 to 2427
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   char1_ar      715 non-null    object
#  1   char2_ar      715 non-null    object
#  2   char3_ar      715 non-null    object
#  3   char1_en      715 non-null    object
#  4   char2_en      715 non-null    object
#  5   char3_en      715 non-null    object
#  6   Plate number  715 non-null    int64
#  7   price         715 non-null    Int64
# dtypes: Int64(1), int64(1), object(6)
# memory usage: 51.0+ KB

# %%
df[df.duplicated()]
# Out:
#      char1_ar char2_ar char3_ar char1_en char2_en char3_en  Plate number  \
# 371         ب        س        م        B        S        Z           911
# 444         ل        ن        ط        L        N        T            61
# 836         ح        م        ب        J        Z        B            44
# 893        هـ        ب       هـ        H        B        H           953
# 1321        أ        ك        و        A        K        U          5552
# 1415        ل        ق        د        L        G        D             6
# 1655        ق        ص        ر        G        X        R           702
# 1887        ب        ك        ك        B        K        K          8881
# 2082        ب        ب        ب        B        B        B          8111
# 2162        ى        م        أ        V        Z        A           218
# 2190        ى        م        أ        V        Z        A           218
#
#        price
# 371   100000
# 444    12000
# 836    19000
# 893    15000
# 1321    5000
# ...

# %%
df.columns
# Out:
# Index(['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en',
#        'Plate number', 'price'],
#       dtype='object')

# %%
df[df.duplicated(['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en', 'Plate number'],keep=False)]
# Out:
#      char1_ar char2_ar char3_ar char1_en char2_en char3_en  Plate number  \
# 122         ل        ن        ط        L        N        T            61
# 155        هـ        ب       هـ        H        B        H           953
# 270         أ        ص        ن        A        X        N          9449
# 367         ب        س        م        B        S        Z           911
# 371         ب        س        م        B        S        Z           911
# 444         ل        ن        ط        L        N        T            61
# 809         ح        م        ب        J        Z        B            44
# 824         ح        أ        د        J        A        D          1441
# 836         ح        م        ب        J        Z        B            44
# 893        هـ        ب       هـ        H        B        H           953
# 942        هـ        ب       هـ        H        B        H           953
# 978         ل        ق        د        L        G        D             6
# ...

# %%
df = df.loc[df.groupby(['char1_ar', 'char2_ar', 'char3_ar', 'char1_en', 'char2_en', 'char3_en', 
                         'Plate number'])['price'].idxmax()]

# %%
df = df.drop_duplicates(keep=False)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (699, 8)

# %%
df['char_ar'] = df['char1_ar']+ ' ' + df['char2_ar'] + ' ' + df['char3_ar']

# %%
df['plate_no'] = df['Plate number']

# %%
df['char_en'] = df['char1_en']+ ' ' +df['char2_en']+ ' ' +df['char3_en']

# %%
df.head()
# Out:
#      char1_ar char2_ar char3_ar char1_en char2_en char3_en  Plate number  \
# 1796        أ        أ        أ        A        A        A             0
# 802         أ        أ        أ        A        A        A          2116
# 1101        أ        أ        أ        A        A        A          3309
# 1333        أ        أ        أ        A        A        A          5561
# 1998        أ        أ        أ        A        A        A          6932
#
#         price char_ar  plate_no char_en
# 1796  2000000   أ أ أ         0   A A A
# 802      7000   أ أ أ      2116   A A A
# 1101    13000   أ أ أ      3309   A A A
# 1333     9000   أ أ أ      5561   A A A
# 1998     5000   أ أ أ      6932   A A A

# %%
#df = df[['char_ar','plate_no','char_en','price']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1796 to 394
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   char1_ar      699 non-null    object
#  1   char2_ar      699 non-null    object
#  2   char3_ar      699 non-null    object
#  3   char1_en      699 non-null    object
#  4   char2_en      699 non-null    object
#  5   char3_en      699 non-null    object
#  6   Plate number  699 non-null    int64
#  7   price         699 non-null    Int64
#  8   char_ar       699 non-null    object
#  9   plate_no      699 non-null    int64
#  10  char_en       699 non-null    object
# dtypes: Int64(1), int64(2), object(8)
# memory usage: 66.2+ KB

# %%
df.shape
# Out:
# (699, 11)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 1796 to 394
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   char_ar   699 non-null    object
#  1   char_en   699 non-null    object
#  2   char1_ar  699 non-null    object
#  3   char2_ar  699 non-null    object
#  4   char3_ar  699 non-null    object
#  5   char1_en  699 non-null    object
#  6   char2_en  699 non-null    object
#  7   char3_en  699 non-null    object
#  8   plate_no  699 non-null    int64
#  9   price     699 non-null    Int64
# dtypes: Int64(1), int64(1), object(8)
# memory usage: 60.8+ KB

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 1796   أ أ أ   A A A        أ        أ        أ        A        A        A
# 802    أ أ أ   A A A        أ        أ        أ        A        A        A
# 1101   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1333   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1998   أ أ أ   A A A        أ        أ        أ        A        A        A
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 1486   ى ل ق   V L G        ى        ل        ق        V        L        G
# 1907   ى م أ   V Z A        ى        م        أ        V        Z        A
# 1769   ى ن د   V N D        ى        ن        د        V        N        D
# 2382   ى ن ى   V N V        ى        ن        ى        V        N        V
# 394    ى و ى   V U V        ى        و        ى        V        U        V
#
#       plate_no    price
# 1796         0  2000000
# ...

# %%
df.to_csv('data/lu7ah_cleand.csv',index=False)

# %%
df1.head(2)
# Out:
#    numberofbids plateNumber plateNumberAr  plateNumber 2 plateNumberEn  \
# 0             0           ١         د ب س              1         S B D
# 1            30          ١۰         س ن ص             10         X N S
#
#    simply-amount 2  simply-amount 3  simply-amount 4 highestBidAmount  \
# 0                5               26               19       500,000.00
# 1                5               41               30        17,000.00
#
#    sortAmount  sortIndex
# 0      500000          0
# 1       17000          1

# %%
df2.head()
# Out:
#    ribbon  numberofbids plateNumber plateNumberAr  plateNumber 2  \
# 0    ذهبي             6           ٢         د د و              2
# 1    ذهبي             3           ٤         ن م ا              4
# 2  برونزي            32          ١۰        د هـ م             10
# 3  برونزي            33          ٤٦         ع ل م             46
# 4     فضي             3          ۸۸         ق م ح             88
#
#   plateNumberEn highestBidAmount  sortAmount  sortIndex
# 0         U D D        80,000.00       80000          0
# 1         A Z N        65,000.00       65000          3
# 2         Z H D        25,000.00       25000          5
# 3         Z L E        26,000.00       26000         10
# 4         J Z G        26,000.00       26000         12

# %%
df1 = df1[['plateNumberAr','plateNumber 2','plateNumberEn','sortAmount']]

# %%
df2 = df2[['plateNumberAr','plateNumber 2','plateNumberEn','sortAmount','ribbon']]

# %%
df1[['char1_ar', 'char2_ar', 'char3_ar']] = df1['plateNumberAr'].str.split(' ', n=2, expand=True)

# %%
df1[['char3_en', 'char2_en', 'char1_en']] = df1['plateNumberEn'].str.split(' ', n=2, expand=True)

# %%
df1['price'] = df1['sortAmount']

# %%
df1['plate_no'] = df1['plateNumber 2']

# %%
df1['char_ar'] =df1['plateNumberAr']

# %%
df1['char_en'] = df1['plateNumberEn']

# %%
df1 = df1[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price']]

# %%
df1
# Out:
#    char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0    د ب س   S B D        د        ب        س        D        B        S
# 1    س ن ص   X N S        س        ن        ص        S        N        X
# 2    ق ح ل   L J G        ق        ح        ل        G        J        L
# 3    ل ب ل   L B L        ل        ب        ل        L        B        L
# 4    أ أ أ   A A A        أ        أ        أ        A        A        A
# ..     ...     ...      ...      ...      ...      ...      ...      ...
# 65   ب ي م   Z V B        ب        ي        م        B        V        Z
# 66   ر ع د   D E R        ر        ع        د        R        E        D
# 67   د ع و   U E D        د        ع        و        D        E        U
# 68   د ع د   D E D        د        ع        د        D        E        D
# 69   أ ح ب   B J A        أ        ح        ب        A        J        B
#
#     plate_no   price
# 0          1  500000
# 1         10   17000
# 2         40   12500
# ...

# %%
df1.to_csv('data/mazad_1_cleand.csv',index=False)

# %%
df2[['char1_ar', 'char2_ar', 'char3_ar']] = df2['plateNumberAr'].str.split(' ', n=2, expand=True)

# %%
df2[['char3_en', 'char2_en', 'char1_en']] = df2['plateNumberEn'].str.split(' ', n=2, expand=True)

# %%
df2['price'] = df2['sortAmount']

# %%
df2['plate_no'] = df2['plateNumber 2']

# %%
df2['char_ar'] =df2['plateNumberAr']

# %%
df2['char_en'] = df2['plateNumberEn']

# %%
df2 = df2[['char_ar','char_en','char1_ar','char2_ar','char3_ar','char1_en','char2_en','char3_en','plate_no','price','ribbon']]

# %%
df2
# Out:
#    char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0    د د و   U D D        د        د        و        D        D        U
# 1    ن م ا   A Z N        ن        م        ا        N        Z        A
# 2   د هـ م   Z H D        د       هـ        م        D        H        Z
# 3    ع ل م   Z L E        ع        ل        م        E        L        Z
# 4    ق م ح   J Z G        ق        م        ح        G        Z        J
# 5    ر و ر   R U R        ر        و        ر        R        U        R
# 6   ر هـ ى   V H R        ر       هـ        ى        R        H        V
# 7    ر و ب   B U R        ر        و        ب        R        U        B
# 8    ر و ا   A U R        ر        و        ا        R        U        A
# 9    ر ن ص   X N R        ر        ن        ص        R        N        X
# 10   ر ن ل   L N R        ر        ن        ل        R        N        L
# 11   د د د   D D D        د        د        د        D        D        D
# ...

# %%
df2.to_csv('data/mazad_2_cleand.csv',index=False)
