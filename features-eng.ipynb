# %%
import pandas as pd
import re
import sys
import importlib.util
import itertools
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/mergedData.csv')

# %%
df.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
# 1   ر ه م   Z H R        ر        ه        م        R        H        Z
# 2   ر ه م   Z H R        ر        ه        م        R        H        Z
# 3   ر أ ن   N A R        ر        أ        ن        R        A        N
# 4   ه ر ب   B R H        ه        ر        ب        H        R        B
#
#    plate_no  price class
# 0      9777   6500   NaN
# 1      9888   6500   NaN
# 2      9666   6500   NaN
# 3         3  35000   NaN
# 4        22  50000   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3690 entries, 0 to 3689
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   char_ar   3690 non-null   object
#  1   char_en   3690 non-null   object
#  2   char1_ar  3690 non-null   object
#  3   char2_ar  3685 non-null   object
#  4   char3_ar  3677 non-null   object
#  5   char1_en  3690 non-null   object
#  6   char2_en  3685 non-null   object
#  7   char3_en  3677 non-null   object
#  8   plate_no  3690 non-null   int64
#  9   price     3690 non-null   int64
#  10  class     54 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 317.2+ KB

# %%
df['plate_no'] = df['plate_no'].astype(str)

# %% [markdown]
# # Digit Features eng

# %% [markdown]
# ## EDA to Analyze and Discover Digit Features

# %% [markdown]
# ### df with one digit

# %%
# Filter data to include only rows where plate_no is a single digit
one_digit = df[df["plate_no"].str.match(r"^\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(one_digit["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Only Single-Digit Plate Numbers)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
df[df["plate_no"].str.match(r"^\d$")]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 13     أ م ل   L Z A        أ        م        ل        A        Z        L
# 28     د ط د   D T D        د        ط        د        D        T        D
# 48     ك ح أ   A J K        ك        ح        أ        K        J        A
# 56     ص ل م   Z L X        ص        ل        م        X        L        Z
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3594   و ق ن   N G U        و        ق        ن        U        G        N
# 3677   أ ن ق   G N A        أ        ن        ق        A        N        G
# 3679   ق ى ل   L V G        ق        ى        ل        G        V        L
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no    price class
# 3           3    35000   NaN
# 13          2    85000   NaN
# 28          2   115000   NaN
# 48          7    75000   NaN
# 56          9    69000   NaN
# ...       ...      ...   ...
# 3594        5    60000   NaN
# 3677        3  1000000   NaN
# 3679        8    40000   NaN
# 3686        2    40000   NaN
# 3689        6       50   NaN
#
# [372 rows x 11 columns]

# %%
# Checking minimum and maximum price for one-digit plate_no
one_digit['price'].min(), one_digit['price'].max()
# Out:
# (1, 205000000)

# %% [markdown]
# ### Two-digit df

# %% [markdown]
# Same-two-digit df

# %%
# Filter data to include only rows where plate_no has two digits
same_two_digits = df[df["plate_no"].str.match(r"^(\d)\1$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(same_two_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Same Two Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
df[df["plate_no"].str.match(r"^(\d)\1$")]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# 9      ص ى ن   N V X        ص        ى        ن        X        V        N
# 15     د ص ط   T X D        د        ص        ط        D        X        T
# 29     ه ن ص   X N H        ه        ن        ص        H        N        X
# 36     ى ص ح   J X V        ى        ص        ح        V        X        J
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3560   ه ح ه   H J H        ه        ح        ه        H        J        H
# 3577   ب س ط   T S B        ب        س        ط        B        S        T
# 3587   ر ب ح   J B R        ر        ب        ح        R        B        J
# 3663   م ك ل   L K Z        م        ك        ل        Z        K        L
# 3667   ه ه س   S H H        ه        ه        س        H        H        S
#
#      plate_no  price class
# 4          22  50000   NaN
# 9          11  55000   NaN
# 15         77  16000   NaN
# 29         55  30000   NaN
# 36         11  33000   NaN
# ...       ...    ...   ...
# 3560       22  32000   NaN
# 3577       99  27000   NaN
# 3587       22      2   NaN
# 3663       33      1   NaN
# 3667       22  50000   NaN
#
# [207 rows x 11 columns]

# %%
#Checking minimum and maximum price for same-two-digits plates
same_two_digits['price'].min(), same_two_digits['price'].max()
# Out:
# (1, 400000)

# %% [markdown]
# Different-two-digit plates

# %%
# Filter data to include only rows where plate_no has two different digits
different_two_digits = df[df["plate_no"].str.match(r"^(\d)(?!\1)\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(different_two_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Different Two Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
df[df["plate_no"].str.match(r"^(\d)(?!\1)\d$")]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 6      أ ر ب   B R A        أ        ر        ب        A        R        B
# 23     م ع ن   N E Z        م        ع        ن        Z        E        N
# 27     ب د ل   L D B        ب        د        ل        B        D        L
# 37     ل ع و   U E L        ل        ع        و        L        E        U
# 41     و د م   Z D U        و        د        م        U        D        Z
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3658   ل ب ن   N B L        ل        ب        ن        L        B        N
# 3659   د ر ه   H R D        د        ر        ه        D        R        H
# 3660   س ق ط   T G S        س        ق        ط        S        G        T
# 3670   ر ر س   S R R        ر        ر        س        R        R        S
# 3678   ق و ن   N U G        ق        و        ن        G        U        N
#
#      plate_no  price class
# 6          75  15500   NaN
# 23         52  31000   NaN
# 27         89  30000   NaN
# 37         35  10000   NaN
# 41         86  15000   NaN
# ...       ...    ...   ...
# 3658       56  22000   NaN
# 3659       27  25000   NaN
# 3660       46  20000   NaN
# 3670       49  15000   NaN
# 3678       72      1   NaN
#
# [718 rows x 11 columns]

# %%
# Checking minimum and maximum price for different-two-digit plates
different_two_digits['price'].min(), different_two_digits['price'].max()
# Out:
# (1, 999999999999)

# %%
different_two_digits[different_two_digits['price'] == 999999999999]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 2746   ه ك ن   N K H        ه        ك        ن        H        K        N
#
#      plate_no         price class
# 2746       80  999999999999   NaN

# %% [markdown]
# ### Three-digit plates

# %% [markdown]
# Same-three-digit plates

# %%
# Filter data to include only rows where plate_no has the same three digits
same_three_digits = df[df["plate_no"].str.match(r"^(\d)\1\1$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(same_three_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Same Three Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
df[df["plate_no"].str.match(r"^(\d)\1\1$")]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 24     ط ك ل   L K T        ط        ك        ل        T        K        L
# 51     س ى أ   A V S        س        ى        أ        S        V        A
# 55     ح ك ن   N K J        ح        ك        ن        J        K        N
# 71     ل و ه   H U L        ل        و        ه        L        U        H
# 87     س ه ق   G H S        س        ه        ق        S        H        G
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3602   ص س ر   R S X        ص        س        ر        X        S        R
# 3621   أ ر ك   K R A        أ        ر        ك        A        R        K
# 3622   ح ى ل   L V J        ح        ى        ل        J        V        L
# 3627   س ق ى   V G S        س        ق        ى        S        G        V
# 3684   ر ص د   D X R        ر        ص        د        R        X        D
#
#      plate_no   price class
# 24        444   20500   NaN
# 51        555   25000   NaN
# 55        111   40000   NaN
# 71        666   45000   NaN
# 87        111   31000   NaN
# ...       ...     ...   ...
# 3602      555   13000   NaN
# 3621      777   30000   NaN
# 3622      111  100000   NaN
# 3627      222      29   NaN
# 3684      777   30000   NaN
#
# [198 rows x 11 columns]

# %%
# Checking minimum and maximum price for same-three-digit df
same_three_digits['price'].min(), same_three_digits['price'].max()
# Out:
# (1, 108446043404)

# %% [markdown]
# Different-three-digits df

# %%
# Filter data to include only rows where plate_no has different three digits
different_three_digits = df[df["plate_no"].str.match(r"^(\d)(?!\1)(\d)(?!\1|\2)\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(different_three_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Different Three Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
different_three_digits
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 7      ع ر ب   B R E        ع        ر        ب        E        R        B
# 25     ك ك ك   K K K        ك        ك        ك        K        K        K
# 30     م ل ك   K L Z        م        ل        ك        Z        L        K
# 31     ع و ن   N U E        ع        و        ن        E        U        N
# 34     س ه و   U H S        س        ه        و        S        H        U
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3672   س أ ل   L A S        س        أ        ل        S        A        L
# 3674   ر ر و   U R R        ر        ر        و        R        R        U
# 3675   ب ل د   D L B        ب        ل        د        B        L        D
# 3680   ب ه أ   A H B        ب        ه        أ        B        H        A
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
#
#      plate_no  price class
# 7         167  12000   NaN
# 25        789  25000   NaN
# 30        531  20000   NaN
# 31        570  20000   NaN
# 34        501  22000   NaN
# ...       ...    ...   ...
# 3672      740   3500   NaN
# 3674      174   4000   NaN
# 3675      345     10   NaN
# 3680      264   7000   NaN
# 3685      203  20000   NaN
#
# [501 rows x 11 columns]

# %%
# Checking minimum and maximum price for different-three-digit df
different_three_digits['price'].min(), different_three_digits['price'].max()
# Out:
# (1, 1000000)

# %% [markdown]
# ### Four-digit df

# %% [markdown]
# Same-four-digit df

# %%
# Filter data to include only rows where plate_no has the same three digits
same_four_digits = df[df["plate_no"].str.match(r"^(\d)\1\1\1$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(same_four_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Same Four Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
same_four_digits
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 45     أ أ ح   J A A        أ        أ        ح        A        A        J
# 79     أ ط ل   L T A        أ        ط        ل        A        T        L
# 111    ب ع ح   J E B        ب        ع        ح        B        E        J
# 161    ر س ط   T S R        ر        س        ط        R        S        T
# 162    ح ح ق   G J J        ح        ح        ق        J        J        G
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3378   د ب ك   K B D        د        ب        ك        D        B        K
# 3399   أ ن ع   E N A        أ        ن        ع        A        N        E
# 3434   ر ح ر   R J R        ر        ح        ر        R        J        R
# 3439   ر ق ر   R G R        ر        ق        ر        R        G        R
# 3483   أ أ ع   E A A        أ        أ        ع        A        A        E
#
#      plate_no  price class
# 45       5555  60000   NaN
# 79       1111  50000   NaN
# 111      4444  15000   NaN
# 161      2222  18500   NaN
# 162      3333  28000   NaN
# ...       ...    ...   ...
# 3378     8888  20000   NaN
# 3399     9999  21000   NaN
# 3434     3333  25000   NaN
# 3439     8888      1   NaN
# 3483     6666  15000   NaN
#
# [84 rows x 11 columns]

# %%
# Checking minimum and maximum price for same-four-digit df
same_four_digits['price'].min(), same_four_digits['price'].max()
# Out:
# (1, 1010101)

# %% [markdown]
# Different-four-digit plate

# %%
# Filter data to include only rows where plate_no has different four digits
different_four_digits = df[df["plate_no"].str.match(r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(different_four_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Different Four Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
different_four_digits
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 10     ح ر ب   B R J        ح        ر        ب        J        R        B
# 20     ب د ر   R D B        ب        د        ر        B        D        R
# 72     س ع د   D E S        س        ع        د        S        E        D
# 77     أ س د   D S A        أ        س        د        A        S        D
# 93     ر ه ص   X H R        ر        ه        ص        R        H        X
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3582   ح أ م   Z A J        ح        أ        م        J        A        Z
# 3590   ح م د   D Z J        ح        م        د        J        Z        D
# 3600   ح ل م   Z L J        ح        ل        م        J        L        Z
# 3617   ح ر ب   B R J        ح        ر        ب        J        R        B
# 3668   ح ر ب   B R J        ح        ر        ب        J        R        B
#
#      plate_no  price class
# 10       7159   5000   NaN
# 20       6379   5500   NaN
# 72       9710   4000   NaN
# 77       9320  34000   NaN
# 93       3720   2000   NaN
# ...       ...    ...   ...
# 3582     4321   8000   NaN
# 3590     9240   3000   NaN
# 3600     6490   5000   NaN
# 3617     5360   5000   NaN
# 3668     6539  15000   NaN
#
# [154 rows x 11 columns]

# %%
# Checking price for different-digit-df
different_four_digits['price'].min(), different_four_digits['price'].max()
# Out:
# (1, 90000)

# %% [markdown]
# Average / mode price for all the cases

# %%
# Define regex patterns for different plate types
patterns = {
    "One Digit": r"^\d$",
    "Two Digits (Same)": r"^(\d)\1$",
    "Two Digits (Different)": r"^(\d)(?!\1)\d$",
    "Three Digits (Same)": r"^(\d)\1\1$",
    "Three Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)\d$",
    "Four Digits (Same)": r"^(\d)\1\1\1$",
    "Four Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$"
}

avg_prices = {}
for category, pattern in patterns.items():
    filtered_df = df[df["plate_no"].str.match(pattern)]
    avg_prices[category] = int(filtered_df["price"].mean() or 0)  # Convert to int, set to 0 if NaN

# Convert dictionary to DataFrame
avg_prices_df = pd.DataFrame(list(avg_prices.items()), columns=["Category", "Average Price"])

# %% [markdown]
# Average with outliers

# %%
# Data from your message
categories = avg_prices_df['Category']
values = avg_prices_df['Average Price']

# Colors for different categories
colors = ["blue", "orange", "orange", "green", "green", "red", "red"]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors, alpha=0.7, edgecolor="black")

# Apply logarithmic scale to fix visualization issues
plt.yscale("log")

# Label each bar with its value
for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, value, f'{value:,}', 
            ha='center', va='bottom', fontsize=10)

# Formatting
plt.xlabel("Plate Category")
plt.ylabel("Average Price (Log Scale)")
plt.title("Average Price for Each Plate Number Category (Log Scale)")
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Without outliers

# %%
# Calculate the Z-scores for the 'price' column
z_scores = (df['price'] - df['price'].mean()) / df['price'].std()

# Filter out rows where the Z-score is greater than 3 or less than -3
df_no_outliers = df[abs(z_scores) <= 3]

# %%
avg_prices_df
# Out:
#                    Category  Average Price
# 0                 One Digit         723176
# 1         Two Digits (Same)          36671
# 2    Two Digits (Different)     1392785861
# 3       Three Digits (Same)      600493830
# 4  Three Digits (Different)          15277
# 5        Four Digits (Same)          38931
# 6   Four Digits (Different)           9495

# %% [markdown]
# ----

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
# 1   ر ه م   Z H R        ر        ه        م        R        H        Z
# 2   ر ه م   Z H R        ر        ه        م        R        H        Z
# 3   ر أ ن   N A R        ر        أ        ن        R        A        N
# 4   ه ر ب   B R H        ه        ر        ب        H        R        B
#
#   plate_no  price class
# 0     9777   6500   NaN
# 1     9888   6500   NaN
# 2     9666   6500   NaN
# 3        3  35000   NaN
# 4       22  50000   NaN

# %%
df[df['plate_no'] == '1234']
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 702    ر ن أ   A N R        ر        ن        أ        R        N        A
# 931    ر ع ع   E E R        ر        ع        ع        R        E        E
# 2913   س ق ب   B G S        س        ق        ب        S        G        B
# 3428   ح ل ك   K L J        ح        ل        ك        J        L        K
#
#      plate_no  price class
# 702      1234  10000   NaN
# 931      1234   4000   NaN
# 2913     1234   1000   NaN
# 3428     1234  20000   NaN

# %% [markdown]
# 1. The Length/Number of Digits in a plate

# %%
df['plate_no_length'] = df['plate_no'].map(lambda x : len(x))

# %%
df.head(10)
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
# 1   ر ه م   Z H R        ر        ه        م        R        H        Z
# 2   ر ه م   Z H R        ر        ه        م        R        H        Z
# 3   ر أ ن   N A R        ر        أ        ن        R        A        N
# 4   ه ر ب   B R H        ه        ر        ب        H        R        B
# 5   ر ه م   Z H R        ر        ه        م        R        H        Z
# 6   أ ر ب   B R A        أ        ر        ب        A        R        B
# 7   ع ر ب   B R E        ع        ر        ب        E        R        B
# 8   ر و ح   J U R        ر        و        ح        R        U        J
# 9   ص ى ن   N V X        ص        ى        ن        X        V        N
#
#   plate_no  price class  plate_no_length
# 0     9777   6500   NaN                4
# 1     9888   6500   NaN                4
# 2     9666   6500   NaN                4
# 3        3  35000   NaN                1
# 4       22  50000   NaN                2
# 5     9966   6500   NaN                4
# 6       75  15500   NaN                2
# 7      167  12000   NaN                3
# 8      775  20000   NaN                3
# 9       11  55000   NaN                2

# %% [markdown]
# 2. similar digits feature

# %%
def is_all_same(plate):
    return len(set(plate)) == 1

# %%
df['similar_digits'] = df['plate_no'].apply(is_all_same)

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits
# 0        9777   6500   NaN                4           False
# 1        9888   6500   NaN                4           False
# 2        9666   6500   NaN                4           False
# 3           3  35000   NaN                1            True
# 4          22  50000   NaN                2            True
# ...       ...    ...   ...              ...             ...
# 3685      203  20000   NaN                3           False
# 3686        2  40000   NaN                1            True
# 3687      505  50000   NaN                3           False
# 3688     3533  15000   NaN                4           False
# 3689        6     50   NaN                1            True
#
# [3690 rows x 13 columns]

# %% [markdown]
# 3. Special date feature

# %%
def is_special_date(plate_no):
    if 1980 <= int(plate_no) <= 2030:
        return True
    else:
        return False

# %%
df[df['plate_no'] == '2030']
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 416    ر ح ل   L J R        ر        ح        ل        R        J        L
# 553    د أ أ   A A D        د        أ        أ        D        A        A
# 642    ر و و   U U R        ر        و        و        R        U        U
# 942    ب ن م   Z N B        ب        ن        م        B        N        Z
# 1482   ر ح ل   L J R        ر        ح        ل        R        J        L
# 1529   أ س س   S S A        أ        س        س        A        S        S
# 1643   ح ر ب   B R J        ح        ر        ب        J        R        B
# 2925   ح ر ق   G R J        ح        ر        ق        J        R        G
# 3098   ب ل ع   E L B        ب        ل        ع        B        L        E
# 3410   د ل س   S L D        د        ل        س        D        L        S
#
#      plate_no   price class  plate_no_length  similar_digits
# 416      2030  350000   NaN                4           False
# 553      2030   20000   NaN                4           False
# 642      2030    7500   NaN                4           False
# 942      2030    4000   NaN                4           False
# 1482     2030  350000   NaN                4           False
# 1529     2030  300000   NaN                4           False
# 1643     2030  100000   NaN                4           False
# 2925     2030   15000   NaN                4           False
# 3098     2030   15000   NaN                4           False
# 3410     2030   10000   NaN                4           False

# %%
df['sepcial_date'] = df['plate_no'].apply(is_special_date)

# %%
df.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
# 1   ر ه م   Z H R        ر        ه        م        R        H        Z
# 2   ر ه م   Z H R        ر        ه        م        R        H        Z
# 3   ر أ ن   N A R        ر        أ        ن        R        A        N
# 4   ه ر ب   B R H        ه        ر        ب        H        R        B
#
#   plate_no  price class  plate_no_length  similar_digits  sepcial_date
# 0     9777   6500   NaN                4           False         False
# 1     9888   6500   NaN                4           False         False
# 2     9666   6500   NaN                4           False         False
# 3        3  35000   NaN                1            True         False
# 4       22  50000   NaN                2            True         False

# %% [markdown]
# 4. Saudi tribes feature

# %%
saudi_tribes = ['07', '101', '111', '205', '305', '404', '405', '411', '501',
                '502', '504','505', '507', '509', '511', '513', '514', '516', '517',
                '518', '523', '555', '601', '702', '707', '711', '812', '906','909', '911']

# %%
df['saudi_tribes'] = df['plate_no'].isin(saudi_tribes)

# %%
df.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
# 1   ر ه م   Z H R        ر        ه        م        R        H        Z
# 2   ر ه م   Z H R        ر        ه        م        R        H        Z
# 3   ر أ ن   N A R        ر        أ        ن        R        A        N
# 4   ه ر ب   B R H        ه        ر        ب        H        R        B
#
#   plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0     9777   6500   NaN                4           False         False
# 1     9888   6500   NaN                4           False         False
# 2     9666   6500   NaN                4           False         False
# 3        3  35000   NaN                1            True         False
# 4       22  50000   NaN                2            True         False
#
#    saudi_tribes
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
df[df['saudi_tribes'] == True]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 34     س ه و   U H S        س        ه        و        S        H        U
# 51     س ى أ   A V S        س        ى        أ        S        V        A
# 55     ح ك ن   N K J        ح        ك        ن        J        K        N
# 63     ب س م   Z S B        ب        س        م        B        S        Z
# 87     س ه ق   G H S        س        ه        ق        S        H        G
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3602   ص س ر   R S X        ص        س        ر        X        S        R
# 3622   ح ى ل   L V J        ح        ى        ل        J        V        L
# 3652   ع ل و   U L E        ع        ل        و        E        L        U
# 3661   ق ه ق   G H G        ق        ه        ق        G        H        G
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
#
#      plate_no   price class  plate_no_length  similar_digits  sepcial_date  \
# 34        501   22000   NaN                3           False         False
# 51        555   25000   NaN                3            True         False
# 55        111   40000   NaN                3            True         False
# 63        911  100000   NaN                3           False         False
# 87        111   31000   NaN                3            True         False
# ...       ...     ...   ...              ...             ...           ...
# 3602      555   13000   NaN                3            True         False
# 3622      111  100000   NaN                3            True         False
# 3652      404   25000   NaN                3           False         False
# 3661      505       1   NaN                3           False         False
# 3687      505   50000   NaN                3           False         False
#
#       saudi_tribes
# 34            True
# 51            True
# 55            True
# 63            True
# 87            True
# ...            ...
# 3602          True
# 3622          True
# 3652          True
# 3661          True
# 3687          True
#
# [181 rows x 15 columns]

# %% [markdown]
# 5. in detail number of digits

# %%
# Define regex patterns for different plate types
patterns = {
    "One Digit": r"^\d$",
    "Two Digits (Same)": r"^(\d)\1$",
    "Two Digits (Different)": r"^(\d)(?!\1)\d$",
    "Three Digits (Same)": r"^(\d)\1\1$",
    "Three Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)\d$",
    "Four Digits (Same)": r"^(\d)\1\1\1$",
    "Four Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$"
}

# %%
for name, pattern in patterns.items():
    df[name] = df["plate_no"].astype(str).apply(lambda x: bool(re.match(pattern, x)))

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 3           3  35000   NaN                1            True         False
# 4          22  50000   NaN                2            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3685      203  20000   NaN                3           False         False
# 3686        2  40000   NaN                1            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
# 3689        6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3685         False      False              False                   False
# 3686         False       True              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
# 3689         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3685                False                      True               False
# 3686                False                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
# 3689                False                     False               False
#
#       Four Digits (Different)
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 3685                    False
# 3686                    False
# 3687                    False
# 3688                    False
# 3689                    False
#
# [3690 rows x 22 columns]

# %% [markdown]
# 6. Emergency numbers

# %%
saudi_emergency_numbers = ["999", "997", "998", "993", "911", "996", "994", "933", "937", "930", "989", "991"]

# %%
df['emergency_no'] = df['plate_no'].isin(saudi_emergency_numbers)

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 3           3  35000   NaN                1            True         False
# 4          22  50000   NaN                2            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3685      203  20000   NaN                3           False         False
# 3686        2  40000   NaN                1            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
# 3689        6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3685         False      False              False                   False
# 3686         False       True              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
# 3689         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3685                False                      True               False
# 3686                False                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
# 3689                False                     False               False
#
#       Four Digits (Different)  emergency_no
# 0                       False         False
# 1                       False         False
# 2                       False         False
# 3                       False         False
# 4                       False         False
# ...                       ...           ...
# 3685                    False         False
# 3686                    False         False
# 3687                    False         False
# 3688                    False         False
# 3689                    False         False
#
# [3690 rows x 23 columns]

# %% [markdown]
# 7. in-order consecutive numbers

# %%
def in_order(number):
    pattern =  r"^(\d)(?=\1|[2-9])$"
    if isinstance(number, str) and number.isdigit():
        return all(int(number[i]) + 1 == int(number[i + 1]) for i in range(len(number) - 1))
    return False

# %%
df['in_order'] = df['plate_no'].apply(in_order)

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 3           3  35000   NaN                1            True         False
# 4          22  50000   NaN                2            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3685      203  20000   NaN                3           False         False
# 3686        2  40000   NaN                1            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
# 3689        6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3685         False      False              False                   False
# 3686         False       True              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
# 3689         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3685                False                      True               False
# 3686                False                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
# 3689                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order
# 0                       False         False     False
# 1                       False         False     False
# 2                       False         False     False
# 3                       False         False      True
# 4                       False         False     False
# ...                       ...           ...       ...
# 3685                    False         False     False
# 3686                    False         False      True
# 3687                    False         False     False
# 3688                    False         False     False
# 3689                    False         False      True
#
# [3690 rows x 24 columns]

# %% [markdown]
# 8. reversed order consecutive numbers

# %%
def is_reversed_order(number):
    if isinstance(number, str) and number.isdigit():
        return all(int(number[i]) - 1 == int(number[i + 1]) for i in range(len(number) - 1))
    return False

# %%
df['reversed_order'] = df['plate_no'].apply(is_reversed_order)

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 3           3  35000   NaN                1            True         False
# 4          22  50000   NaN                2            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3685      203  20000   NaN                3           False         False
# 3686        2  40000   NaN                1            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
# 3689        6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3685         False      False              False                   False
# 3686         False       True              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
# 3689         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3685                False                      True               False
# 3686                False                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
# 3689                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order
# 0                       False         False     False           False
# 1                       False         False     False           False
# 2                       False         False     False           False
# 3                       False         False      True            True
# 4                       False         False     False           False
# ...                       ...           ...       ...             ...
# 3685                    False         False     False           False
# 3686                    False         False      True            True
# 3687                    False         False     False           False
# 3688                    False         False     False           False
# 3689                    False         False      True            True
#
# [3690 rows x 25 columns]

# %% [markdown]
# 9. place of similarity

# %% [markdown]
# 9.1 Same two middle digits in four-digit plate number

# %%
def has_repeating_middle(row):
    pattern = r"^\d(\d)\1\d$"
    return bool(re.match(pattern, row))

# %%
df['same_middles_no'] = df['plate_no'].apply(has_repeating_middle)

# %%
df[df['same_middles_no'] == True]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 12     ر أ س   S A R        ر        أ        س        R        A        S
# 14     ح ط أ   A T J        ح        ط        أ        J        T        A
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3629   أ م ح   J Z A        أ        م        ح        A        Z        J
# 3650   أ ح ص   X J A        أ        ح        ص        A        J        X
# 3653   أ ك ح   J K A        أ        ك        ح        A        K        J
# 3655   ح ل م   Z L J        ح        ل        م        J        L        Z
# 3683   ب أ م   Z A B        ب        أ        م        B        A        Z
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 12       1991  11000   NaN                4           False          True
# 14       7770   6000   NaN                4           False         False
# ...       ...    ...   ...              ...             ...           ...
# 3629     5552  10000   NaN                4           False         False
# 3650     9009      1   NaN                4           False         False
# 3653     7000  10000   NaN                4           False         False
# 3655     8444  10000   NaN                4           False         False
# 3683     8333  10000   NaN                4           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 12           False      False              False                   False
# 14           False      False              False                   False
# ...            ...        ...                ...                     ...
# 3629         False      False              False                   False
# 3650         False      False              False                   False
# 3653         False      False              False                   False
# 3655         False      False              False                   False
# 3683         False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 12                  False                     False               False
# 14                  False                     False               False
# ...                   ...                       ...                 ...
# 3629                False                     False               False
# 3650                False                     False               False
# 3653                False                     False               False
# 3655                False                     False               False
# 3683                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                       False         False     False           False
# 1                       False         False     False           False
# 2                       False         False     False           False
# 12                      False         False     False           False
# 14                      False         False     False           False
# ...                       ...           ...       ...             ...
# 3629                    False         False     False           False
# 3650                    False         False     False           False
# 3653                    False         False     False           False
# 3655                    False         False     False           False
# 3683                    False         False     False           False
#
#       same_middles_no
# 0                True
# 1                True
# 2                True
# 12               True
# 14               True
# ...               ...
# 3629             True
# 3650             True
# 3653             True
# 3655             True
# 3683             True
#
# [450 rows x 26 columns]

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 3           3  35000   NaN                1            True         False
# 4          22  50000   NaN                2            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3685      203  20000   NaN                3           False         False
# 3686        2  40000   NaN                1            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
# 3689        6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3685         False      False              False                   False
# 3686         False       True              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
# 3689         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3685                False                      True               False
# 3686                False                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
# 3689                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                       False         False     False           False
# 1                       False         False     False           False
# 2                       False         False     False           False
# 3                       False         False      True            True
# 4                       False         False     False           False
# ...                       ...           ...       ...             ...
# 3685                    False         False     False           False
# 3686                    False         False      True            True
# 3687                    False         False     False           False
# 3688                    False         False     False           False
# 3689                    False         False      True            True
#
#       same_middles_no
# 0                True
# 1                True
# 2                True
# 3               False
# 4               False
# ...               ...
# 3685            False
# 3686            False
# 3687            False
# 3688            False
# 3689            False
#
# [3690 rows x 26 columns]

# %% [markdown]
# 9.2 plaindormic plate numbers

# %%
# plaindromic is a word that is read the same from left to right or right to left 
def has_palindromic_pattern(plate_no):
    pattern = r"^(\d)(\d)?\2?\1$"  
    return bool(re.match(pattern, plate_no))

# %%
pd.set_option('display.max_columns', None)

# %%
df['plaindromic_no'] = df['plate_no'].apply(has_palindromic_pattern)

# %%
df[df['plaindromic_no'] == True]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# 9      ص ى ن   N V X        ص        ى        ن        X        V        N
# 12     ر أ س   S A R        ر        أ        س        R        A        S
# 15     د ص ط   T X D        د        ص        ط        D        X        T
# 24     ط ك ل   L K T        ط        ك        ل        T        K        L
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3661   ق ه ق   G H G        ق        ه        ق        G        H        G
# 3663   م ك ل   L K Z        م        ك        ل        Z        K        L
# 3667   ه ه س   S H H        ه        ه        س        H        H        S
# 3684   ر ص د   D X R        ر        ص        د        R        X        D
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 4          22  50000   NaN                2            True         False
# 9          11  55000   NaN                2            True         False
# 12       1991  11000   NaN                4           False          True
# 15         77  16000   NaN                2            True         False
# 24        444  20500   NaN                3            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3661      505      1   NaN                3           False         False
# 3663       33      1   NaN                2            True         False
# 3667       22  50000   NaN                2            True         False
# 3684      777  30000   NaN                3            True         False
# 3687      505  50000   NaN                3           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 4            False      False               True                   False
# 9            False      False               True                   False
# 12           False      False              False                   False
# 15           False      False               True                   False
# 24           False      False              False                   False
# ...            ...        ...                ...                     ...
# 3661          True      False              False                   False
# 3663         False      False               True                   False
# 3667         False      False               True                   False
# 3684         False      False              False                   False
# 3687          True      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 4                   False                     False               False
# 9                   False                     False               False
# 12                  False                     False               False
# 15                  False                     False               False
# 24                   True                     False               False
# ...                   ...                       ...                 ...
# 3661                False                     False               False
# 3663                False                     False               False
# 3667                False                     False               False
# 3684                 True                     False               False
# 3687                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 4                       False         False     False           False
# 9                       False         False     False           False
# 12                      False         False     False           False
# 15                      False         False     False           False
# 24                      False         False     False           False
# ...                       ...           ...       ...             ...
# 3661                    False         False     False           False
# 3663                    False         False     False           False
# 3667                    False         False     False           False
# 3684                    False         False     False           False
# 3687                    False         False     False           False
#
#       same_middles_no  plaindromic_no
# 4               False            True
# 9               False            True
# 12               True            True
# 15              False            True
# 24              False            True
# ...               ...             ...
# 3661            False            True
# 3663            False            True
# 3667            False            True
# 3684            False            True
# 3687            False            True
#
# [792 rows x 27 columns]

# %% [markdown]
# 9.3 the same first and last digits

# %%
def has_matching_first_last(plate_no):
    pattern = r"^(\d)(\d{0,2})\1$"
    return bool(re.match(pattern, plate_no))

# %%
df['same_first_last_no'] = df['plate_no'].apply(has_matching_first_last)

# %%
df[df['same_first_last_no'] == True]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# 9      ص ى ن   N V X        ص        ى        ن        X        V        N
# 12     ر أ س   S A R        ر        أ        س        R        A        S
# 15     د ص ط   T X D        د        ص        ط        D        X        T
# 17     ر م ه   H Z R        ر        م        ه        R        Z        H
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3663   م ك ل   L K Z        م        ك        ل        Z        K        L
# 3667   ه ه س   S H H        ه        ه        س        H        H        S
# 3684   ر ص د   D X R        ر        ص        د        R        X        D
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 4          22  50000   NaN                2            True         False
# 9          11  55000   NaN                2            True         False
# 12       1991  11000   NaN                4           False          True
# 15         77  16000   NaN                2            True         False
# 17       4464   5000   NaN                4           False         False
# ...       ...    ...   ...              ...             ...           ...
# 3663       33      1   NaN                2            True         False
# 3667       22  50000   NaN                2            True         False
# 3684      777  30000   NaN                3            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 4            False      False               True                   False
# 9            False      False               True                   False
# 12           False      False              False                   False
# 15           False      False               True                   False
# 17           False      False              False                   False
# ...            ...        ...                ...                     ...
# 3663         False      False               True                   False
# 3667         False      False               True                   False
# 3684         False      False              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 4                   False                     False               False
# 9                   False                     False               False
# 12                  False                     False               False
# 15                  False                     False               False
# 17                  False                     False               False
# ...                   ...                       ...                 ...
# 3663                False                     False               False
# 3667                False                     False               False
# 3684                 True                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 4                       False         False     False           False
# 9                       False         False     False           False
# 12                      False         False     False           False
# 15                      False         False     False           False
# 17                      False         False     False           False
# ...                       ...           ...       ...             ...
# 3663                    False         False     False           False
# 3667                    False         False     False           False
# 3684                    False         False     False           False
# 3687                    False         False     False           False
# 3688                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no
# 4               False            True                True
# 9               False            True                True
# 12               True            True                True
# 15              False            True                True
# 17              False           False                True
# ...               ...             ...                 ...
# 3663            False            True                True
# 3667            False            True                True
# 3684            False            True                True
# 3687            False            True                True
# 3688            False           False                True
#
# [892 rows x 28 columns]

# %% [markdown]
# 9.4 repeating sides (two lefts or two rights)

# %%
def has_repeating_sides(plate_no):
    pattern = r"^(\d)\1\d?$|^(\d)\1\d\d$|^\d?(\d)\3$|^\d\d(\d)\4$"
    return bool(re.match(pattern, plate_no))

# %%
df['same_two_sides'] = df['plate_no'].apply(has_repeating_sides)

# %%
df[df['same_two_sides'] == True]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# 5      ر ه م   Z H R        ر        ه        م        R        H        Z
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3681   د ك ك   K K D        د        ك        ك        D        K        K
# 3682   ب ن ك   K N B        ب        ن        ك        B        N        K
# 3683   ب أ م   Z A B        ب        أ        م        B        A        Z
# 3684   ر ص د   D X R        ر        ص        د        R        X        D
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 4          22  50000   NaN                2            True         False
# 5        9966   6500   NaN                4           False         False
# ...       ...    ...   ...              ...             ...           ...
# 3681     6688  10000   NaN                4           False         False
# 3682     6055   5000   NaN                4           False         False
# 3683     8333  10000   NaN                4           False         False
# 3684      777  30000   NaN                3            True         False
# 3688     3533  15000   NaN                4           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 4            False      False               True                   False
# 5            False      False              False                   False
# ...            ...        ...                ...                     ...
# 3681         False      False              False                   False
# 3682         False      False              False                   False
# 3683         False      False              False                   False
# 3684         False      False              False                   False
# 3688         False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 4                   False                     False               False
# 5                   False                     False               False
# ...                   ...                       ...                 ...
# 3681                False                     False               False
# 3682                False                     False               False
# 3683                False                     False               False
# 3684                 True                     False               False
# 3688                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                       False         False     False           False
# 1                       False         False     False           False
# 2                       False         False     False           False
# 4                       False         False     False           False
# 5                       False         False     False           False
# ...                       ...           ...       ...             ...
# 3681                    False         False     False           False
# 3682                    False         False     False           False
# 3683                    False         False     False           False
# 3684                    False         False     False           False
# 3688                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides
# 0                True           False               False            True
# 1                True           False               False            True
# 2                True           False               False            True
# 4               False            True                True            True
# 5               False           False               False            True
# ...               ...             ...                 ...             ...
# 3681            False           False               False            True
# 3682            False           False               False            True
# 3683             True           False               False            True
# 3684            False            True                True            True
# 3688            False           False                True            True
#
# [1186 rows x 29 columns]

# %%
df[df['plate_no'] == '0']
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 473    أ أ أ   A A A        أ        أ        أ        A        A        A
# 631    س ح ر   R J S        س        ح        ر        S        J        R
# 1801   س م ح   J Z S        س        م        ح        S        Z        J
# 2177   ب ر ق   G R B        ب        ر        ق        B        R        G
# 2229   ب ط أ   A T B        ب        ط        أ        B        T        A
# 2488       س       S        س      NaN      NaN        S      NaN      NaN
# 2489       س       S        س      NaN      NaN        S      NaN      NaN
# 2774   س و أ   A U S        س        و        أ        S        U        A
# 3343   ع ن د   D N E        ع        ن        د        E        N        D
#
#      plate_no      price class  plate_no_length  similar_digits  sepcial_date  \
# 473         0    2000000   NaN                1            True         False
# 631         0     400000   NaN                1            True         False
# 1801        0        500   NaN                1            True         False
# 2177        0      10000   NaN                1            True         False
# 2229        0       1000   NaN                1            True         False
# 2488        0  205000000   NaN                1            True         False
# 2489        0    2500000   NaN                1            True         False
# 2774        0          1   NaN                1            True         False
# 3343        0       8000   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 473          False       True              False                   False
# 631          False       True              False                   False
# 1801         False       True              False                   False
# 2177         False       True              False                   False
# 2229         False       True              False                   False
# 2488         False       True              False                   False
# 2489         False       True              False                   False
# 2774         False       True              False                   False
# 3343         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 473                 False                     False               False
# 631                 False                     False               False
# 1801                False                     False               False
# 2177                False                     False               False
# 2229                False                     False               False
# 2488                False                     False               False
# 2489                False                     False               False
# 2774                False                     False               False
# 3343                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 473                     False         False      True            True
# 631                     False         False      True            True
# 1801                    False         False      True            True
# 2177                    False         False      True            True
# 2229                    False         False      True            True
# 2488                    False         False      True            True
# 2489                    False         False      True            True
# 2774                    False         False      True            True
# 3343                    False         False      True            True
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides
# 473             False           False               False           False
# 631             False           False               False           False
# 1801            False           False               False           False
# 2177            False           False               False           False
# 2229            False           False               False           False
# 2488            False           False               False           False
# 2489            False           False               False           False
# 2774            False           False               False           False
# 3343            False           False               False           False

# %% [markdown]
# 10. One-digit

# %% [markdown]
# Checking the count of one-digit df

# %%
df[df['One Digit']].shape
# Out:
# (372, 29)

# %% [markdown]
# 10.1 zero

# %%
bool(re.match(patterns['One Digit'],'0') and '0'=='0')
# Out:
# True

# %%
df['one_digit_zero'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '0'))

# %% [markdown]
# 10.2 one

# %%
df['one_digit_one'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '1'))

# %% [markdown]
# 10.3 two

# %%
df['one_digit_two'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '2'))

# %% [markdown]
# 10.4 three

# %%
df['one_digit_three'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '3'))

# %% [markdown]
# 10.5 four

# %%
df['one_digit_four'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '4'))

# %% [markdown]
# 10.6 five

# %%
df['one_digit_five'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '5'))

# %% [markdown]
# 10.7 six

# %%
df['one_digit_six'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '6'))

# %% [markdown]
# 10.8 seven

# %%
df['one_digit_seven'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '7'))

# %% [markdown]
# 10.9 eight

# %%
df['one_digit_eight'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '8'))

# %% [markdown]
# 10.10 nine

# %%
df['one_digit_nine'] = df['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '9'))

# %%
df[df['plate_no'] == '911']
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 63     ب س م   Z S B        ب        س        م        B        S        Z
# 143    ق ل أ   A L G        ق        ل        أ        G        L        A
# 353    ح و أ   A U J        ح        و        أ        J        U        A
# 475    ح ق ك   K G J        ح        ق        ك        J        G        K
# 798    ي ق ح   J G V        ي        ق        ح        V        G        J
# 901    ي ق ح   V G J        ي        ق        ح        J        G        V
# 1614   ل ط ى   V T L        ل        ط        ى        L        T        V
# 1653   م س م   Z S Z        م        س        م        Z        S        Z
# 2013   أ ر ب   B R A        أ        ر        ب        A        R        B
# 2081   ب أ ع   E A B        ب        أ        ع        B        A        E
# 2094   ك و ل   L U K        ك        و        ل        K        U        L
#
#      plate_no   price class  plate_no_length  similar_digits  sepcial_date  \
# 63        911  100000   NaN                3           False         False
# 143       911   25000   NaN                3           False         False
# 353       911   60000   NaN                3           False         False
# 475       911   45000   NaN                3           False         False
# 798       911   20000   NaN                3           False         False
# 901       911   17500   NaN                3           False         False
# 1614      911   25000   NaN                3           False         False
# 1653      911   30000   NaN                3           False         False
# 2013      911    5000   NaN                3           False         False
# 2081      911       1   NaN                3           False         False
# 2094      911      38   NaN                3           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 63            True      False              False                   False
# 143           True      False              False                   False
# 353           True      False              False                   False
# 475           True      False              False                   False
# 798           True      False              False                   False
# 901           True      False              False                   False
# 1614          True      False              False                   False
# 1653          True      False              False                   False
# 2013          True      False              False                   False
# 2081          True      False              False                   False
# 2094          True      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 63                  False                     False               False
# 143                 False                     False               False
# 353                 False                     False               False
# 475                 False                     False               False
# 798                 False                     False               False
# 901                 False                     False               False
# 1614                False                     False               False
# 1653                False                     False               False
# 2013                False                     False               False
# 2081                False                     False               False
# 2094                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 63                      False          True     False           False
# 143                     False          True     False           False
# 353                     False          True     False           False
# 475                     False          True     False           False
# 798                     False          True     False           False
# 901                     False          True     False           False
# 1614                    False          True     False           False
# 1653                    False          True     False           False
# 2013                    False          True     False           False
# 2081                    False          True     False           False
# 2094                    False          True     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 63              False           False               False            True
# 143             False           False               False            True
# 353             False           False               False            True
# 475             False           False               False            True
# 798             False           False               False            True
# 901             False           False               False            True
# 1614            False           False               False            True
# 1653            False           False               False            True
# 2013            False           False               False            True
# 2081            False           False               False            True
# 2094            False           False               False            True
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 63             False          False          False            False
# 143            False          False          False            False
# 353            False          False          False            False
# 475            False          False          False            False
# 798            False          False          False            False
# 901            False          False          False            False
# 1614           False          False          False            False
# 1653           False          False          False            False
# 2013           False          False          False            False
# 2081           False          False          False            False
# 2094           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 63             False           False          False            False
# 143            False           False          False            False
# 353            False           False          False            False
# 475            False           False          False            False
# 798            False           False          False            False
# 901            False           False          False            False
# 1614           False           False          False            False
# 1653           False           False          False            False
# 2013           False           False          False            False
# 2081           False           False          False            False
# 2094           False           False          False            False
#
#       one_digit_eight  one_digit_nine
# 63              False           False
# 143             False           False
# 353             False           False
# 475             False           False
# 798             False           False
# 901             False           False
# 1614            False           False
# 1653            False           False
# 2013            False           False
# 2081            False           False
# 2094            False           False

# %%
df.shape
# Out:
# (3690, 39)

# %%
df[df['one_digit_nine'] == True]
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 56     ص ل م   Z L X        ص        ل        م        X        L        Z
# 117    ح ك ك   K K J        ح        ك        ك        J        K        K
# 151    ه ب ط   T B H        ه        ب        ط        H        B        T
# 156    س م ى   V Z S        س        م        ى        S        Z        V
# 175    و س أ   A S U        و        س        أ        U        S        A
# 626    ن م س   S Z N        ن        م        س        N        Z        S
# 628    ص ل م   Z L X        ص        ل        م        X        L        Z
# 691    ص ق ن   N G X        ص        ق        ن        X        G        N
# 692    ص ع د   D E X        ص        ع        د        X        E        D
# 1042   ن د أ   A D N        ن        د        أ        N        D        A
# 1140   ن و ح   J U N        ن        و        ح        N        U        J
# 1142   ن و ح   J U N        ن        و        ح        N        U        J
# 1147   ح ب ك   K B J        ح        ب        ك        J        B        K
# 1148   ن ح و   U J N        ن        ح        و        N        J        U
# 1151   ن د أ   A D N        ن        د        أ        N        D        A
# 1168   ه ك ر   R K H        ه        ك        ر        H        K        R
# 1230   ك ه س   S H K        ك        ه        س        K        H        S
# 1359   س ك ر   R K S        س        ك        ر        S        K        R
# 1393   ك ر ر   R R K        ك        ر        ر        K        R        R
# 1407   ى ح ع   E J V        ى        ح        ع        V        J        E
# 1433   ه ن م   Z N H        ه        ن        م        H        N        Z
# 1451   ص ل ك   K L X        ص        ل        ك        X        L        K
# 1468   و أ ه   H A U        و        أ        ه        U        A        H
# 1916   ب ه د   D H B        ب        ه        د        B        H        D
# 1992   ن د أ   A D N        ن        د        أ        N        D        A
# 2185   ن و ح   J U N        ن        و        ح        N        U        J
# 2225   أ ه ى   V H A        أ        ه        ى        A        H        V
# 2804   و ب و   U B U        و        ب        و        U        B        U
# 2806   د س س   S S D        د        س        س        D        S        S
# 3008   ح ق ل   L G J        ح        ق        ل        J        G        L
# 3078   ع ب أ   A B E        ع        ب        أ        E        B        A
# 3176   ط ى س   S V T        ط        ى        س        T        V        S
# 3288   ر ك أ   A K R        ر        ك        أ        R        K        A
#
#      plate_no    price class  plate_no_length  similar_digits  sepcial_date  \
# 56          9    69000   NaN                1            True         False
# 117         9    32000   NaN                1            True         False
# 151         9    85000   NaN                1            True         False
# 156         9   250000   NaN                1            True         False
# 175         9    75000   NaN                1            True         False
# 626         9   135000   NaN                1            True         False
# 628         9    73000   NaN                1            True         False
# 691         9    64000   NaN                1            True         False
# 692         9   115000   NaN                1            True         False
# 1042        9   140000   NaN                1            True         False
# 1140        9    20008   NaN                1            True         False
# 1142        9    20000   NaN                1            True         False
# 1147        9    20000   NaN                1            True         False
# 1148        9    20000   NaN                1            True         False
# 1151        9    20000   NaN                1            True         False
# 1168        9    25000   NaN                1            True         False
# 1230        9    70000   NaN                1            True         False
# 1359        9  1000000   NaN                1            True         False
# 1393        9   150000   NaN                1            True         False
# 1407        9    88000   NaN                1            True         False
# 1433        9   155000   NaN                1            True         False
# 1451        9    25000   NaN                1            True         False
# 1468        9   120000   NaN                1            True         False
# 1916        9   100000   NaN                1            True         False
# 1992        9    20000   NaN                1            True         False
# 2185        9    20000   NaN                1            True         False
# 2225        9   100000   NaN                1            True         False
# 2804        9   200000   NaN                1            True         False
# 2806        9    28000   NaN                1            True         False
# 3008        9    75000   NaN                1            True         False
# 3078        9    65000   NaN                1            True         False
# 3176        9        5   NaN                1            True         False
# 3288        9       45   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 56           False       True              False                   False
# 117          False       True              False                   False
# 151          False       True              False                   False
# 156          False       True              False                   False
# 175          False       True              False                   False
# 626          False       True              False                   False
# 628          False       True              False                   False
# 691          False       True              False                   False
# 692          False       True              False                   False
# 1042         False       True              False                   False
# 1140         False       True              False                   False
# 1142         False       True              False                   False
# 1147         False       True              False                   False
# 1148         False       True              False                   False
# 1151         False       True              False                   False
# 1168         False       True              False                   False
# 1230         False       True              False                   False
# 1359         False       True              False                   False
# 1393         False       True              False                   False
# 1407         False       True              False                   False
# 1433         False       True              False                   False
# 1451         False       True              False                   False
# 1468         False       True              False                   False
# 1916         False       True              False                   False
# 1992         False       True              False                   False
# 2185         False       True              False                   False
# 2225         False       True              False                   False
# 2804         False       True              False                   False
# 2806         False       True              False                   False
# 3008         False       True              False                   False
# 3078         False       True              False                   False
# 3176         False       True              False                   False
# 3288         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 56                  False                     False               False
# 117                 False                     False               False
# 151                 False                     False               False
# 156                 False                     False               False
# 175                 False                     False               False
# 626                 False                     False               False
# 628                 False                     False               False
# 691                 False                     False               False
# 692                 False                     False               False
# 1042                False                     False               False
# 1140                False                     False               False
# 1142                False                     False               False
# 1147                False                     False               False
# 1148                False                     False               False
# 1151                False                     False               False
# 1168                False                     False               False
# 1230                False                     False               False
# 1359                False                     False               False
# 1393                False                     False               False
# 1407                False                     False               False
# 1433                False                     False               False
# 1451                False                     False               False
# 1468                False                     False               False
# 1916                False                     False               False
# 1992                False                     False               False
# 2185                False                     False               False
# 2225                False                     False               False
# 2804                False                     False               False
# 2806                False                     False               False
# 3008                False                     False               False
# 3078                False                     False               False
# 3176                False                     False               False
# 3288                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 56                      False         False      True            True
# 117                     False         False      True            True
# 151                     False         False      True            True
# 156                     False         False      True            True
# 175                     False         False      True            True
# 626                     False         False      True            True
# 628                     False         False      True            True
# 691                     False         False      True            True
# 692                     False         False      True            True
# 1042                    False         False      True            True
# 1140                    False         False      True            True
# 1142                    False         False      True            True
# 1147                    False         False      True            True
# 1148                    False         False      True            True
# 1151                    False         False      True            True
# 1168                    False         False      True            True
# 1230                    False         False      True            True
# 1359                    False         False      True            True
# 1393                    False         False      True            True
# 1407                    False         False      True            True
# 1433                    False         False      True            True
# 1451                    False         False      True            True
# 1468                    False         False      True            True
# 1916                    False         False      True            True
# 1992                    False         False      True            True
# 2185                    False         False      True            True
# 2225                    False         False      True            True
# 2804                    False         False      True            True
# 2806                    False         False      True            True
# 3008                    False         False      True            True
# 3078                    False         False      True            True
# 3176                    False         False      True            True
# 3288                    False         False      True            True
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 56              False           False               False           False
# 117             False           False               False           False
# 151             False           False               False           False
# 156             False           False               False           False
# 175             False           False               False           False
# 626             False           False               False           False
# 628             False           False               False           False
# 691             False           False               False           False
# 692             False           False               False           False
# 1042            False           False               False           False
# 1140            False           False               False           False
# 1142            False           False               False           False
# 1147            False           False               False           False
# 1148            False           False               False           False
# 1151            False           False               False           False
# 1168            False           False               False           False
# 1230            False           False               False           False
# 1359            False           False               False           False
# 1393            False           False               False           False
# 1407            False           False               False           False
# 1433            False           False               False           False
# 1451            False           False               False           False
# 1468            False           False               False           False
# 1916            False           False               False           False
# 1992            False           False               False           False
# 2185            False           False               False           False
# 2225            False           False               False           False
# 2804            False           False               False           False
# 2806            False           False               False           False
# 3008            False           False               False           False
# 3078            False           False               False           False
# 3176            False           False               False           False
# 3288            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 56             False          False          False            False
# 117            False          False          False            False
# 151            False          False          False            False
# 156            False          False          False            False
# 175            False          False          False            False
# 626            False          False          False            False
# 628            False          False          False            False
# 691            False          False          False            False
# 692            False          False          False            False
# 1042           False          False          False            False
# 1140           False          False          False            False
# 1142           False          False          False            False
# 1147           False          False          False            False
# 1148           False          False          False            False
# 1151           False          False          False            False
# 1168           False          False          False            False
# 1230           False          False          False            False
# 1359           False          False          False            False
# 1393           False          False          False            False
# 1407           False          False          False            False
# 1433           False          False          False            False
# 1451           False          False          False            False
# 1468           False          False          False            False
# 1916           False          False          False            False
# 1992           False          False          False            False
# 2185           False          False          False            False
# 2225           False          False          False            False
# 2804           False          False          False            False
# 2806           False          False          False            False
# 3008           False          False          False            False
# 3078           False          False          False            False
# 3176           False          False          False            False
# 3288           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 56             False           False          False            False
# 117            False           False          False            False
# 151            False           False          False            False
# 156            False           False          False            False
# 175            False           False          False            False
# 626            False           False          False            False
# 628            False           False          False            False
# 691            False           False          False            False
# 692            False           False          False            False
# 1042           False           False          False            False
# 1140           False           False          False            False
# 1142           False           False          False            False
# 1147           False           False          False            False
# 1148           False           False          False            False
# 1151           False           False          False            False
# 1168           False           False          False            False
# 1230           False           False          False            False
# 1359           False           False          False            False
# 1393           False           False          False            False
# 1407           False           False          False            False
# 1433           False           False          False            False
# 1451           False           False          False            False
# 1468           False           False          False            False
# 1916           False           False          False            False
# 1992           False           False          False            False
# 2185           False           False          False            False
# 2225           False           False          False            False
# 2804           False           False          False            False
# 2806           False           False          False            False
# 3008           False           False          False            False
# 3078           False           False          False            False
# 3176           False           False          False            False
# 3288           False           False          False            False
#
#       one_digit_eight  one_digit_nine
# 56              False            True
# 117             False            True
# 151             False            True
# 156             False            True
# 175             False            True
# 626             False            True
# 628             False            True
# 691             False            True
# 692             False            True
# 1042            False            True
# 1140            False            True
# 1142            False            True
# 1147            False            True
# 1148            False            True
# 1151            False            True
# 1168            False            True
# 1230            False            True
# 1359            False            True
# 1393            False            True
# 1407            False            True
# 1433            False            True
# 1451            False            True
# 1468            False            True
# 1916            False            True
# 1992            False            True
# 2185            False            True
# 2225            False            True
# 2804            False            True
# 2806            False            True
# 3008            False            True
# 3078            False            True
# 3176            False            True
# 3288            False            True

# %%
df.sort_values(by='price', ascending=False).head(20)
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 2746   ه ك ن   N K H        ه        ك        ن        H        K        N
# 2552   د ح ط   T J D        د        ح        ط        D        J        T
# 2541   د ح ط   T J D        د        ح        ط        D        J        T
# 2542   د ح ط   T J D        د        ح        ط        D        J        T
# 2717   ب و ب   B U B        ب        و        ب        B        U        B
# 2510   د ح ط   T J D        د        ح        ط        D        J        T
# 2488       س       S        س      NaN      NaN        S      NaN      NaN
# 1550   ب ب ى   V B B        ب        ب        ى        B        B        V
# 516    ى ق ح   J G V        ى        ق        ح        V        G        J
# 2256   ن ل س   S L N        ن        ل        س        N        L        S
# 711    ق ح ط   T J G        ق        ح        ط        G        J        T
# 1172   ل ح ن   N J L        ل        ح        ن        L        J        N
# 536    ب و ق   G U B        ب        و        ق        B        U        G
# 385    س ن ر   R N S        س        ن        ر        S        N        R
# 2489       س       S        س      NaN      NaN        S      NaN      NaN
# 473    أ أ أ   A A A        أ        أ        أ        A        A        A
# 1402   م ك ه   H K Z        م        ك        ه        Z        K        H
# 3383   ه ب أ   A B H        ه        ب        أ        H        B        A
# 2160   د م د   D Z D        د        م        د        D        Z        D
# 3677   أ ن ق   G N A        أ        ن        ق        A        N        G
#
#      plate_no         price class  plate_no_length  similar_digits  \
# 2746       80  999999999999   NaN                2           False
# 2552      999  108446043404   NaN                3            True
# 2541      999    7643844543   NaN                3            True
# 2542      999    2484543484   NaN                3            True
# 2717      707     552318009   NaN                3           False
# 2510      999     310443054   NaN                3            True
# 2488        0     205000000   NaN                1            True
# 1550        1       7000000   NaN                1            True
# 516       979       5250000   NaN                3           False
# 2256      555       5000000   NaN                3            True
# 711       505       5000000   NaN                3           False
# 1172        7       4700000   NaN                1            True
# 536      7373       4000000   NaN                4           False
# 385         1       2500000   NaN                1            True
# 2489        0       2500000   NaN                1            True
# 473         0       2000000   NaN                1            True
# 1402       10       1100000   NaN                2           False
# 3383        1       1100000   NaN                1            True
# 2160     8888       1010101   NaN                4            True
# 3677        3       1000000   NaN                1            True
#
#       sepcial_date  saudi_tribes  One Digit  Two Digits (Same)  \
# 2746         False         False      False              False
# 2552         False         False      False              False
# 2541         False         False      False              False
# 2542         False         False      False              False
# 2717         False          True      False              False
# 2510         False         False      False              False
# 2488         False         False       True              False
# 1550         False         False       True              False
# 516          False         False      False              False
# 2256         False          True      False              False
# 711          False          True      False              False
# 1172         False         False       True              False
# 536          False         False      False              False
# 385          False         False       True              False
# 2489         False         False       True              False
# 473          False         False       True              False
# 1402         False         False      False              False
# 3383         False         False       True              False
# 2160         False         False      False              False
# 3677         False         False       True              False
#
#       Two Digits (Different)  Three Digits (Same)  Three Digits (Different)  \
# 2746                    True                False                     False
# 2552                   False                 True                     False
# 2541                   False                 True                     False
# 2542                   False                 True                     False
# 2717                   False                False                     False
# 2510                   False                 True                     False
# 2488                   False                False                     False
# 1550                   False                False                     False
# 516                    False                False                     False
# 2256                   False                 True                     False
# 711                    False                False                     False
# 1172                   False                False                     False
# 536                    False                False                     False
# 385                    False                False                     False
# 2489                   False                False                     False
# 473                    False                False                     False
# 1402                    True                False                     False
# 3383                   False                False                     False
# 2160                   False                False                     False
# 3677                   False                False                     False
#
#       Four Digits (Same)  Four Digits (Different)  emergency_no  in_order  \
# 2746               False                    False         False     False
# 2552               False                    False          True     False
# 2541               False                    False          True     False
# 2542               False                    False          True     False
# 2717               False                    False         False     False
# 2510               False                    False          True     False
# 2488               False                    False         False      True
# 1550               False                    False         False      True
# 516                False                    False         False     False
# 2256               False                    False         False     False
# 711                False                    False         False     False
# 1172               False                    False         False      True
# 536                False                    False         False     False
# 385                False                    False         False      True
# 2489               False                    False         False      True
# 473                False                    False         False      True
# 1402               False                    False         False     False
# 3383               False                    False         False      True
# 2160                True                    False         False     False
# 3677               False                    False         False      True
#
#       reversed_order  same_middles_no  plaindromic_no  same_first_last_no  \
# 2746           False            False           False               False
# 2552           False            False            True                True
# 2541           False            False            True                True
# 2542           False            False            True                True
# 2717           False            False            True                True
# 2510           False            False            True                True
# 2488            True            False           False               False
# 1550            True            False           False               False
# 516            False            False            True                True
# 2256           False            False            True                True
# 711            False            False            True                True
# 1172            True            False           False               False
# 536            False            False           False               False
# 385             True            False           False               False
# 2489            True            False           False               False
# 473             True            False           False               False
# 1402            True            False           False               False
# 3383            True            False           False               False
# 2160           False             True            True                True
# 3677            True            False           False               False
#
#       same_two_sides  one_digit_zero  one_digit_one  one_digit_two  \
# 2746           False           False          False          False
# 2552            True           False          False          False
# 2541            True           False          False          False
# 2542            True           False          False          False
# 2717           False           False          False          False
# 2510            True           False          False          False
# 2488           False            True          False          False
# 1550           False           False           True          False
# 516            False           False          False          False
# 2256            True           False          False          False
# 711            False           False          False          False
# 1172           False           False          False          False
# 536            False           False          False          False
# 385            False           False           True          False
# 2489           False            True          False          False
# 473            False            True          False          False
# 1402           False           False          False          False
# 3383           False           False           True          False
# 2160            True           False          False          False
# 3677           False           False          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 2746            False           False           False          False
# 2552            False           False           False          False
# 2541            False           False           False          False
# 2542            False           False           False          False
# 2717            False           False           False          False
# 2510            False           False           False          False
# 2488            False           False           False          False
# 1550            False           False           False          False
# 516             False           False           False          False
# 2256            False           False           False          False
# 711             False           False           False          False
# 1172            False           False           False          False
# 536             False           False           False          False
# 385             False           False           False          False
# 2489            False           False           False          False
# 473             False           False           False          False
# 1402            False           False           False          False
# 3383            False           False           False          False
# 2160            False           False           False          False
# 3677             True           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine
# 2746            False            False           False
# 2552            False            False           False
# 2541            False            False           False
# 2542            False            False           False
# 2717            False            False           False
# 2510            False            False           False
# 2488            False            False           False
# 1550            False            False           False
# 516             False            False           False
# 2256            False            False           False
# 711             False            False           False
# 1172             True            False           False
# 536             False            False           False
# 385             False            False           False
# 2489            False            False           False
# 473             False            False           False
# 1402            False            False           False
# 3383            False            False           False
# 2160            False            False           False
# 3677            False            False           False

# %%
df
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0      ر ه م   Z H R        ر        ه        م        R        H        Z
# 1      ر ه م   Z H R        ر        ه        م        R        H        Z
# 2      ر ه م   Z H R        ر        ه        م        R        H        Z
# 3      ر أ ن   N A R        ر        أ        ن        R        A        N
# 4      ه ر ب   B R H        ه        ر        ب        H        R        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3685   ه م ن   N Z H        ه        م        ن        H        Z        N
# 3686   د ص ع   E X D        د        ص        ع        D        X        E
# 3687   ب ى ى   V V B        ب        ى        ى        B        V        V
# 3688   ر ع ب   B E R        ر        ع        ب        R        E        B
# 3689   ق و ص   X U G        ق        و        ص        G        U        X
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0        9777   6500   NaN                4           False         False
# 1        9888   6500   NaN                4           False         False
# 2        9666   6500   NaN                4           False         False
# 3           3  35000   NaN                1            True         False
# 4          22  50000   NaN                2            True         False
# ...       ...    ...   ...              ...             ...           ...
# 3685      203  20000   NaN                3           False         False
# 3686        2  40000   NaN                1            True         False
# 3687      505  50000   NaN                3           False         False
# 3688     3533  15000   NaN                4           False         False
# 3689        6     50   NaN                1            True         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0            False      False              False                   False
# 1            False      False              False                   False
# 2            False      False              False                   False
# 3            False       True              False                   False
# 4            False      False               True                   False
# ...            ...        ...                ...                     ...
# 3685         False      False              False                   False
# 3686         False       True              False                   False
# 3687          True      False              False                   False
# 3688         False      False              False                   False
# 3689         False       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3685                False                      True               False
# 3686                False                     False               False
# 3687                False                     False               False
# 3688                False                     False               False
# 3689                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                       False         False     False           False
# 1                       False         False     False           False
# 2                       False         False     False           False
# 3                       False         False      True            True
# 4                       False         False     False           False
# ...                       ...           ...       ...             ...
# 3685                    False         False     False           False
# 3686                    False         False      True            True
# 3687                    False         False     False           False
# 3688                    False         False     False           False
# 3689                    False         False      True            True
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 0                True           False               False            True
# 1                True           False               False            True
# 2                True           False               False            True
# 3               False           False               False           False
# 4               False            True                True            True
# ...               ...             ...                 ...             ...
# 3685            False           False               False           False
# 3686            False           False               False           False
# 3687            False            True                True           False
# 3688            False           False                True            True
# 3689            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 0              False          False          False            False
# 1              False          False          False            False
# 2              False          False          False            False
# 3              False          False          False             True
# 4              False          False          False            False
# ...              ...            ...            ...              ...
# 3685           False          False          False            False
# 3686           False          False           True            False
# 3687           False          False          False            False
# 3688           False          False          False            False
# 3689           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 0              False           False          False            False
# 1              False           False          False            False
# 2              False           False          False            False
# 3              False           False          False            False
# 4              False           False          False            False
# ...              ...             ...            ...              ...
# 3685           False           False          False            False
# 3686           False           False          False            False
# 3687           False           False          False            False
# 3688           False           False          False            False
# 3689           False           False           True            False
#
#       one_digit_eight  one_digit_nine
# 0               False           False
# 1               False           False
# 2               False           False
# 3               False           False
# 4               False           False
# ...               ...             ...
# 3685            False           False
# 3686            False           False
# 3687            False           False
# 3688            False           False
# 3689            False           False
#
# [3690 rows x 39 columns]

# %%
df.shape
# Out:
# (3690, 39)

# %% [markdown]
# # characters Features eng

# %% [markdown]
# #### Case 1: Triple Letters
# _______

# %%
# -- Case 1 Triple Letter in both Arabic and English ( أ أ أ ) , ( A A A )
def has_triple_letters(text):
    return bool(re.search(r'(\S)\s*\1\s*\1', text))

# -- Apply on all select columns 'char_ar'
df['is_triple_letters'] = (df['char_ar'].apply(has_triple_letters)) & (df['char_en'].apply(has_triple_letters))

# -- Show the result
# -- Filter to check the result 
three_L = df[(df['is_triple_letters'])]
three_L
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 25     ك ك ك   K K K        ك        ك        ك        K        K        K
# 62     ب ب ب   B B B        ب        ب        ب        B        B        B
# 66     ح ح ح   J J J        ح        ح        ح        J        J        J
# 67     ر ر ر   R R R        ر        ر        ر        R        R        R
# 68     ب ب ب   B B B        ب        ب        ب        B        B        B
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 2782   ب ب ب   B B B        ب        ب        ب        B        B        B
# 2821   س س س   S S S        س        س        س        S        S        S
# 3089   ر ر ر   R R R        ر        ر        ر        R        R        R
# 3426   ح ح ح   J J J        ح        ح        ح        J        J        J
# 3566   م م م   Z Z Z        م        م        م        Z        Z        Z
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 25        789  25000   NaN                3           False         False
# 62       1606   9000   NaN                4           False         False
# 66       2244  35000   NaN                4           False         False
# 67        455  50000   NaN                3           False         False
# 68       2230  15000   NaN                4           False         False
# ...       ...    ...   ...              ...             ...           ...
# 2782     3522  40000   NaN                4           False         False
# 2821      470  20000   NaN                3           False         False
# 3089      375   4000   NaN                3           False         False
# 3426      410  15000   NaN                3           False         False
# 3566      784  35000   NaN                3           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 25           False      False              False                   False
# 62           False      False              False                   False
# 66           False      False              False                   False
# 67           False      False              False                   False
# 68           False      False              False                   False
# ...            ...        ...                ...                     ...
# 2782         False      False              False                   False
# 2821         False      False              False                   False
# 3089         False      False              False                   False
# 3426         False      False              False                   False
# 3566         False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 25                  False                      True               False
# 62                  False                     False               False
# 66                  False                     False               False
# 67                  False                     False               False
# 68                  False                     False               False
# ...                   ...                       ...                 ...
# 2782                False                     False               False
# 2821                False                      True               False
# 3089                False                      True               False
# 3426                False                      True               False
# 3566                False                      True               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 25                      False         False      True           False
# 62                      False         False     False           False
# 66                      False         False     False           False
# 67                      False         False     False           False
# 68                      False         False     False           False
# ...                       ...           ...       ...             ...
# 2782                    False         False     False           False
# 2821                    False         False     False           False
# 3089                    False         False     False           False
# 3426                    False         False     False           False
# 3566                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 25              False           False               False           False
# 62              False           False               False           False
# 66              False           False               False            True
# 67              False           False               False            True
# 68              False           False               False           False
# ...               ...             ...                 ...             ...
# 2782            False           False               False            True
# 2821            False           False               False           False
# 3089            False           False               False           False
# 3426            False           False               False           False
# 3566            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 25             False          False          False            False
# 62             False          False          False            False
# 66             False          False          False            False
# 67             False          False          False            False
# 68             False          False          False            False
# ...              ...            ...            ...              ...
# 2782           False          False          False            False
# 2821           False          False          False            False
# 3089           False          False          False            False
# 3426           False          False          False            False
# 3566           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 25             False           False          False            False
# 62             False           False          False            False
# 66             False           False          False            False
# 67             False           False          False            False
# 68             False           False          False            False
# ...              ...             ...            ...              ...
# 2782           False           False          False            False
# 2821           False           False          False            False
# 3089           False           False          False            False
# 3426           False           False          False            False
# 3566           False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters
# 25              False           False               True
# 62              False           False               True
# 66              False           False               True
# 67              False           False               True
# 68              False           False               True
# ...               ...             ...                ...
# 2782            False           False               True
# 2821            False           False               True
# 3089            False           False               True
# 3426            False           False               True
# 3566            False           False               True
#
# [102 rows x 40 columns]

# %% [markdown]
# #### Case 2: One Letter

# %%
# -- Case 2 One Letter in both Arabic and English ( أ ) , ( A )
def has_one_letter(text):
    return bool(len(text) == 1)

# -- Apply on all select columns 'char_ar'
df['is_one_letters'] = (df['char_ar'].apply(has_one_letter)) & (df['char_en'].apply(has_one_letter))


# -- Show the result
# -- Filter to check the result 
one_L = df[(df['is_one_letters'])]
one_L
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 2080       ص       X        ص      NaN      NaN        X      NaN      NaN
# 2488       س       S        س      NaN      NaN        S      NaN      NaN
# 2489       س       S        س      NaN      NaN        S      NaN      NaN
# 2615       ق       G        ق      NaN      NaN        G      NaN      NaN
# 3045       أ       A        أ      NaN      NaN        A      NaN      NaN
#
#      plate_no      price class  plate_no_length  similar_digits  sepcial_date  \
# 2080        8      90000   NaN                1            True         False
# 2488        0  205000000   NaN                1            True         False
# 2489        0    2500000   NaN                1            True         False
# 2615        1     100000   NaN                1            True         False
# 3045      519      25000   NaN                3           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 2080         False       True              False                   False
# 2488         False       True              False                   False
# 2489         False       True              False                   False
# 2615         False       True              False                   False
# 3045         False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 2080                False                     False               False
# 2488                False                     False               False
# 2489                False                     False               False
# 2615                False                     False               False
# 3045                False                      True               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 2080                    False         False      True            True
# 2488                    False         False      True            True
# 2489                    False         False      True            True
# 2615                    False         False      True            True
# 3045                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 2080            False           False               False           False
# 2488            False           False               False           False
# 2489            False           False               False           False
# 2615            False           False               False           False
# 3045            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 2080           False          False          False            False
# 2488            True          False          False            False
# 2489            True          False          False            False
# 2615           False           True          False            False
# 3045           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 2080           False           False          False            False
# 2488           False           False          False            False
# 2489           False           False          False            False
# 2615           False           False          False            False
# 3045           False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters
# 2080             True           False              False            True
# 2488            False           False              False            True
# 2489            False           False              False            True
# 2615            False           False              False            True
# 3045            False           False              False            True

# %% [markdown]
# #### Case 3: First Letter == Third Letter

# %%
# -- Case 3: First Letter and Third Letter is the same

def has_match_letters(text):
    clean_text = text.replace(' ', '')

    if len(clean_text) < 3:
        return False 
    
    # -- return true if ( N A N ) and excluded Case one ( A A A) 
    return bool(clean_text[0] == clean_text[2] and clean_text[1] != clean_text[2]) 

# -- Apply on all select columns 'char_ar'
df['First_Third_Match'] = (df['char_ar'].apply(has_match_letters)) & (df['char_en'].apply(has_match_letters))

# -- Show the result
# -- Filter to check the result 
one_third = df[(df['First_Third_Match'])]
one_third
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 16     د ه د   D H D        د        ه        د        D        H        D
# 21     م ه م   Z H Z        م        ه        م        Z        H        Z
# 28     د ط د   D T D        د        ط        د        D        T        D
# 38     ن و ن   N U N        ن        و        ن        N        U        N
# 49     ر ق ر   R G R        ر        ق        ر        R        G        R
# ...      ...     ...      ...      ...      ...      ...      ...      ...
# 3549   ل ر ل   L R L        ل        ر        ل        L        R        L
# 3560   ه ح ه   H J H        ه        ح        ه        H        J        H
# 3588   م ط م   Z T Z        م        ط        م        Z        T        Z
# 3642   م ن م   Z N Z        م        ن        م        Z        N        Z
# 3661   ق ه ق   G H G        ق        ه        ق        G        H        G
#
#      plate_no   price class  plate_no_length  similar_digits  sepcial_date  \
# 16       7779    5000   NaN                4           False         False
# 21        966  100000   NaN                3           False         False
# 28          2  115000   NaN                1            True         False
# 38        775   25000   NaN                3           False         False
# 49         12   22000   NaN                2           False         False
# ...       ...     ...   ...              ...             ...           ...
# 3549       56   15000   NaN                2           False         False
# 3560       22   32000   NaN                2            True         False
# 3588      558    7000   NaN                3           False         False
# 3642      904       1   NaN                3           False         False
# 3661      505       1   NaN                3           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 16           False      False              False                   False
# 21           False      False              False                   False
# 28           False       True              False                   False
# 38           False      False              False                   False
# 49           False      False              False                    True
# ...            ...        ...                ...                     ...
# 3549         False      False              False                    True
# 3560         False      False               True                   False
# 3588         False      False              False                   False
# 3642         False      False              False                   False
# 3661          True      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 16                  False                     False               False
# 21                  False                     False               False
# 28                  False                     False               False
# 38                  False                     False               False
# 49                  False                     False               False
# ...                   ...                       ...                 ...
# 3549                False                     False               False
# 3560                False                     False               False
# 3588                False                     False               False
# 3642                False                      True               False
# 3661                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 16                      False         False     False           False
# 21                      False         False     False           False
# 28                      False         False      True            True
# 38                      False         False     False           False
# 49                      False         False      True           False
# ...                       ...           ...       ...             ...
# 3549                    False         False      True           False
# 3560                    False         False     False           False
# 3588                    False         False     False           False
# 3642                    False         False     False           False
# 3661                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 16               True           False               False           False
# 21              False           False               False            True
# 28              False           False               False           False
# 38              False           False               False            True
# 49              False           False               False           False
# ...               ...             ...                 ...             ...
# 3549            False           False               False           False
# 3560            False            True                True            True
# 3588            False           False               False            True
# 3642            False           False               False           False
# 3661            False            True                True           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 16             False          False          False            False
# 21             False          False          False            False
# 28             False          False           True            False
# 38             False          False          False            False
# 49             False          False          False            False
# ...              ...            ...            ...              ...
# 3549           False          False          False            False
# 3560           False          False          False            False
# 3588           False          False          False            False
# 3642           False          False          False            False
# 3661           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 16             False           False          False            False
# 21             False           False          False            False
# 28             False           False          False            False
# 38             False           False          False            False
# 49             False           False          False            False
# ...              ...             ...            ...              ...
# 3549           False           False          False            False
# 3560           False           False          False            False
# 3588           False           False          False            False
# 3642           False           False          False            False
# 3661           False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 16              False           False              False           False
# 21              False           False              False           False
# 28              False           False              False           False
# 38              False           False              False           False
# 49              False           False              False           False
# ...               ...             ...                ...             ...
# 3549            False           False              False           False
# 3560            False           False              False           False
# 3588            False           False              False           False
# 3642            False           False              False           False
# 3661            False           False              False           False
#
#       First_Third_Match
# 16                 True
# 21                 True
# 28                 True
# 38                 True
# 49                 True
# ...                 ...
# 3549               True
# 3560               True
# 3588               True
# 3642               True
# 3661               True
#
# [210 rows x 42 columns]

# %% [markdown]
# #### Case 4: Only "Two" char matching

# %%
# -- Case 4: Only Two char and the same ( N N ) ( ن ن )

def has_two_chars(text):
    clean_text = text.replace(' ', '')
    return len(clean_text) == 2

df['has_two_chars'] = df['char_ar'].apply(has_two_chars)
# -- Apply to 'char_ar'
oneNice = df[df['char_ar'].apply(has_two_chars)]
oneNice
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 1898     ق ر     R G        ق        ر      NaN        G        R      NaN
# 2267     أ م     Z A        أ        م      NaN        A        Z      NaN
# 2281     ب د     D B        ب        د      NaN        B        D      NaN
# 2316     ح أ     A J        ح        أ      NaN        J        A      NaN
# 3319     ى م     Z V        ى        م      NaN        V        Z      NaN
# 3325     ن ص     X N        ن        ص      NaN        N        X      NaN
# 3567     ى م     Z V        ى        م      NaN        V        Z      NaN
# 3635     د ن     N D        د        ن      NaN        D        N      NaN
#
#      plate_no   price class  plate_no_length  similar_digits  sepcial_date  \
# 1898      503  100000   NaN                3           False         False
# 2267       68    5000   NaN                2           False         False
# 2281       25    7500   NaN                2           False         False
# 2316     5436    6000   NaN                4           False         False
# 3319       50   45000   NaN                2           False         False
# 3325      668    8000   NaN                3           False         False
# 3567       50     110   NaN                2           False         False
# 3635       15   13000   NaN                2           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 1898         False      False              False                   False
# 2267         False      False              False                    True
# 2281         False      False              False                    True
# 2316         False      False              False                   False
# 3319         False      False              False                    True
# 3325         False      False              False                   False
# 3567         False      False              False                    True
# 3635         False      False              False                    True
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 1898                False                      True               False
# 2267                False                     False               False
# 2281                False                     False               False
# 2316                False                     False               False
# 3319                False                     False               False
# 3325                False                     False               False
# 3567                False                     False               False
# 3635                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 1898                    False         False     False           False
# 2267                    False         False     False           False
# 2281                    False         False     False           False
# 2316                     True         False     False           False
# 3319                    False         False     False           False
# 3325                    False         False     False           False
# 3567                    False         False     False           False
# 3635                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 1898            False           False               False           False
# 2267            False           False               False           False
# 2281            False           False               False           False
# 2316            False           False               False           False
# 3319            False           False               False           False
# 3325            False           False               False            True
# 3567            False           False               False           False
# 3635            False           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 1898           False          False          False            False
# 2267           False          False          False            False
# 2281           False          False          False            False
# 2316           False          False          False            False
# 3319           False          False          False            False
# 3325           False          False          False            False
# 3567           False          False          False            False
# 3635           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 1898           False           False          False            False
# 2267           False           False          False            False
# 2281           False           False          False            False
# 2316           False           False          False            False
# 3319           False           False          False            False
# 3325           False           False          False            False
# 3567           False           False          False            False
# 3635           False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 1898            False           False              False           False
# 2267            False           False              False           False
# 2281            False           False              False           False
# 2316            False           False              False           False
# 3319            False           False              False           False
# 3325            False           False              False           False
# 3567            False           False              False           False
# 3635            False           False              False           False
#
#       First_Third_Match  has_two_chars
# 1898              False           True
# 2267              False           True
# 2281              False           True
# 2316              False           True
# 3319              False           True
# 3325              False           True
# 3567              False           True
# 3635              False           True

# %% [markdown]
# #### Case 5: Consecutive Characters

# %% [markdown]
# #### Case 6: Tribe Characters

# %%
# -- Case 6: Tribe Characters (ح ر ب)

# Arabic Letters That DO NOT Appear on Saudi df
# The following letters are not used in Saudi vehicle df
# ❌ ث - ج - ذ - ز - ش - ض - ظ - غ - ف - ت - ي - خ

# Arabic Letters That ARE Used on Saudi Plates:
# ✅ أ - ب - ح - د - ر - س - ص - ط - ع - ق - ك - ل - م - ن - و - ى - هـ

tribes = ['ق ح ط', 'ح ر ب', 'د س ر', 'م ط ر', 'س ب ع', 'د ح ه', 'ى ا م']


def contains_tribe(text):
    return any(tribe in text for tribe in tribes)

# -- Apply the function to the 'char_ar' column
df['Contains_Tribe'] = df['char_ar'].apply(contains_tribe)

# -- Show the result
# -- Filter to check the result 
Contains_Tribe = df[(df['Contains_Tribe'])]

# %% [markdown]
# #### Case 7: English  Words

# %%
# -- Case 7: English Characters (K S A)

# English Letters That DO NOT Appear on Saudi Plates:
# The following letters are not used in Saudi vehicle plates:
# ❌ C - F - I - M - O - P - Q - W - Y

# English Letters That ARE Used on Saudi Plates:
# ✅  B - U - N - V - Z - H - R - G - L - J - K - A - D - E - T - X - S

# List of 2-letter words
two_letter_words = [
    "K A",  # Common prefix in Arabic names (e.g., "Khalid")
    "S A",  # Short for Saudi Arabia
    "L A",  # Means "no" in Arabic
    "H A",  # Expression of joy or laughter
    "R A",  # Short for "Riyadh" or a common sound in Arabic
    "J A",  # Short for "Jeddah" or a common sound in Arabic
    "B A",  # Common prefix in Arabic names (e.g., "Basel")
    "X A",  # Unique and modern, often used in license plates for style
]

# List of 3-letter words with meanings
three_letter_words = [
    "K S A",  # Abbreviation for Saudi Arabia, highly popular
    "D A D",  # Common English word, also meaningful in Arabic
    "L A H",  # Means "no" in Arabic, widely recognized
    "J A D",  # Means "new" in Arabic
    "B A D",  # Means "after" in Arabic
    "G A S",  # Common English word, also recognized in Arabic
    "R E D",  # Common English word, also recognized in Arabic
    "J E T",  # Common English word, also recognized in Arabic
    "T A G",  # Common English word
    "H U G",  # Common English word
    "L A X",  # Means "relaxed" in English
    "L E X"   # Short for "lexicon" or a name
]

all_words = two_letter_words + three_letter_words

def contains_special_words(text):
    return text in all_words

# -- Apply the function to the 'char_ar' column
df['contains_special_words'] = df['char_en'].apply(contains_special_words)

# -- Show the result
# -- Filter to check the result 
contains_special_words = df[(df['contains_special_words'])]

# %% [markdown]
# #### Case 8: Car Names or Editions

# %%
# -- Case 7: English Characters Cars Names (L X)
# List of car names or editions with meanings
car_names = [
    "L X",   # Lexus LX series (e.g., LX 570) - Luxury SUV
    "G X",   # Lexus GX series (e.g., GX 460) - Luxury SUV
    "R X",   # Lexus RX series (e.g., RX 350) - Luxury crossover
    "L S",   # Lexus LS series (e.g., LS 500) - Flagship luxury sedan
    "L C",   # Lexus LC series (e.g., LC 500) - Luxury coupe
    "E S",   # Lexus ES series (e.g., ES 350) - Executive sedan
    "G S",   # Lexus GS series (e.g., GS 350) - Luxury sports sedan
    "R C",   # Lexus RC series (e.g., RC 350) - Luxury coupe
    "U X",   # Lexus UX series (e.g., UX 200) - Compact luxury crossover
    "N X",   # Lexus NX series (e.g., NX 300) - Compact luxury SUV
    "G T",   # Grand Touring trim (e.g., Porsche 911 GT3, BMW M8 GT)
    "G L",   # Mercedes-Benz GL series (e.g., GL 450) - Luxury SUV
    "G L E",  # Mercedes-Benz GLE series (e.g., GLE 450) - Luxury SUV
    "G L S",  # Mercedes-Benz GLS series (e.g., GLS 580) - Flagship luxury SUV
    "S",    # Mercedes-Benz S-Class (e.g., S 500) - Flagship luxury sedan
    "C",    # Mercedes-Benz C-Class (e.g., C 300) - Executive sedan
    "E",    # Mercedes-Benz E-Class (e.g., E 350) - Executive sedan
    "G",    # Mercedes-Benz G-Class (e.g., G 550) - Luxury off-road SUV
    "A M G",  # Mercedes-AMG performance models (e.g., C 63 AMG)
    "X",    # BMW X series (e.g., X5, X7) - Luxury SUVs
    "M",    # BMW M series (e.g., M5, M8) - High-performance models
    "Q",    # Audi Q series (e.g., Q7, Q8) - Luxury SUVs
    "A",    # Audi A series (e.g., A8, A6) - Luxury sedans
    "R S",   # Audi RS series (e.g., RS 7) - High-performance models
    "S",    # Audi S series (e.g., S5) - Sporty performance models
    "R",    # Porsche 911 Carrera R - High-performance sports car
    "C",    # Porsche Cayenne (e.g., Cayenne Turbo) - Luxury SUV
    "P",    # Porsche Panamera (e.g., Panamera Turbo) - Luxury sedan
    "T",    # Tesla Model T (e.g., Tesla Model S Plaid) - High-performance EV
    "S",    # Tesla Model S (e.g., Model S Plaid) - Luxury electric sedan
    "X",    # Tesla Model X (e.g., Model X Plaid) - Luxury electric SUV
    "Y",    # Tesla Model Y (e.g., Model Y Performance) - Compact electric SUV
    "J",    # Jaguar F-Type (e.g., F-Type R) - Luxury sports car
    "F",    # Ferrari (e.g., Ferrari 488 GTB) - High-performance sports car
    "L",    # Lamborghini (e.g., Lamborghini Urus) - Luxury SUV
    "B",    # Bentley (e.g., Bentayga) - Luxury SUV
    "R",    # Rolls-Royce (e.g., Rolls-Royce Cullinan) - Ultra-luxury SUV
    "W",    # Range Rover (e.g., Range Rover Vogue) - Luxury SUV
    "V",    # Volvo XC90 (e.g., XC90 Excellence) - Luxury SUV
]


def contains_special_cars(text):
    return text in car_names

# -- Apply the function to the 'char_ar' column
df['contains_special_cars'] = df['char_en'].apply(contains_special_cars)

# -- Show the result
# -- Filter to check the result 
contains_special_cars = df[(df['contains_special_cars'])]

# %%
df['thousands_plate_no'] = df['plate_no'].map(lambda x : bool(re.match(r'^\d000$', x)))

# %%
df['similar_three_in_four'] = df['plate_no'].map(lambda x : bool(re.match(r"(\d(\d)\2{2}|\2{2}\d)", x)))

# %%
words_freq = pd.read_csv('data/words_frequency.csv')

# %%
words_freq
# Out:
#        في  first_name_rank
# 0      من       100.000000
# 1     على        99.956859
# 2       و        99.913719
# 3      لأ        99.870578
# 4      عن        99.827437
# ...   ...              ...
# 2313  أكى         0.215703
# 2314  ىوو         0.172563
# 2315  موه         0.129422
# 2316  صرن         0.086281
# 2317  ومه         0.043141
#
# [2318 rows x 2 columns]

# %%
words_freq.drop('Unnamed: 0',axis=1,inplace=True)

# %%
words_freq['first_name_rank'] = words_freq['first_name_rank'].apply(lambda x : x /100)

# %%
words_freq.columns = ["word", "word_freq_score"]

df['combined_word'] = df['char1_ar'] + df['char2_ar'] + df['char3_ar']
# Map frequency scores to the combined words
df['word_freq_score'] = df['combined_word'].map(dict(zip(words_freq['word'], words_freq['word_freq_score']))).fillna(0)
df.sort_values(by='word_freq_score',ascending=False).head(150).tail(30)
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 2527   س ع د   D E S        س        ع        د        S        E        D
# 1312   س ع د   D E S        س        ع        د        S        E        D
# 2629   س ع د   D E S        س        ع        د        S        E        D
# 878    س ع د   S E D        س        ع        د        D        E        S
# 255    س ع د   D E S        س        ع        د        S        E        D
# 924    س ع د   D E S        س        ع        د        S        E        D
# 2969   س ع د   D E S        س        ع        د        S        E        D
# 2632   س ع د   D E S        س        ع        د        S        E        D
# 1806   س ع د   D E S        س        ع        د        S        E        D
# 1324   س ع د   D E S        س        ع        د        S        E        D
# 1036   س ع د   D E S        س        ع        د        S        E        D
# 3274   س ع د   D E S        س        ع        د        S        E        D
# 2454   س ع د   D E S        س        ع        د        S        E        D
# 98     س ع د   D E S        س        ع        د        S        E        D
# 3326   س ع د   D E S        س        ع        د        S        E        D
# 1950   س ع د   D E S        س        ع        د        S        E        D
# 1568   س ع د   D E S        س        ع        د        S        E        D
# 3260   س ع د   D E S        س        ع        د        S        E        D
# 2297   س ع د   D E S        س        ع        د        S        E        D
# 3244   س ع د   D E S        س        ع        د        S        E        D
# 72     س ع د   D E S        س        ع        د        S        E        D
# 2012   س ع د   D E S        س        ع        د        S        E        D
# 1948   س ع د   D E S        س        ع        د        S        E        D
# 958    أ ح ب   B J A        أ        ح        ب        A        J        B
# 1558   أ ح ب   B J A        أ        ح        ب        A        J        B
# 871    أ ح ب   A J B        أ        ح        ب        B        J        A
# 3235   أ ح ب   B J A        أ        ح        ب        A        J        B
# 1066   أ ح ب   B J A        أ        ح        ب        A        J        B
# 2326   أ ح ب   B J A        أ        ح        ب        A        J        B
# 814    أ ح ب   B J A        أ        ح        ب        A        J        B
#
#      plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 2527      784   6700   NaN                3           False         False
# 1312     2522  20000   NaN                4           False         False
# 2629     5057  20000   NaN                4           False         False
# 878      8177   6500   NaN                4           False         False
# 255      2045   6000   NaN                4           False         False
# 924      5011   8500   NaN                4           False         False
# 2969      481  25000   NaN                3           False         False
# 2632      606  12500   NaN                3           False         False
# 1806     3294   5000   NaN                4           False         False
# 1324     3883  25000   NaN                4           False         False
# 1036     3393  17000   NaN                4           False         False
# 3274     6024   5000   NaN                4           False         False
# 2454     1895   4500   NaN                4           False         False
# 98       9309   6500   NaN                4           False         False
# 3326     6549  12000   NaN                4           False         False
# 1950     9999  12000   NaN                4            True         False
# 1568      500   7000   NaN                3           False         False
# 3260     8243   8000   NaN                4           False         False
# 2297     5939   3500   NaN                4           False         False
# 3244     7800      1   NaN                4           False         False
# 72       9710   4000   NaN                4           False         False
# 2012        2  85000   NaN                1            True         False
# 1948     5655  10000   NaN                4           False         False
# 958      1225   5200   NaN                4           False         False
# 1558       39  50000   NaN                2           False         False
# 871       343  15000   NaN                3           False         False
# 3235      197  10000   NaN                3           False         False
# 1066      640  14500   NaN                3           False         False
# 2326      542   8500   NaN                3           False         False
# 814      1225   4900   NaN                4           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 2527         False      False              False                   False
# 1312         False      False              False                   False
# 2629         False      False              False                   False
# 878          False      False              False                   False
# 255          False      False              False                   False
# 924          False      False              False                   False
# 2969         False      False              False                   False
# 2632         False      False              False                   False
# 1806         False      False              False                   False
# 1324         False      False              False                   False
# 1036         False      False              False                   False
# 3274         False      False              False                   False
# 2454         False      False              False                   False
# 98           False      False              False                   False
# 3326         False      False              False                   False
# 1950         False      False              False                   False
# 1568         False      False              False                   False
# 3260         False      False              False                   False
# 2297         False      False              False                   False
# 3244         False      False              False                   False
# 72           False      False              False                   False
# 2012         False       True              False                   False
# 1948         False      False              False                   False
# 958          False      False              False                   False
# 1558         False      False              False                    True
# 871          False      False              False                   False
# 3235         False      False              False                   False
# 1066         False      False              False                   False
# 2326         False      False              False                   False
# 814          False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 2527                False                      True               False
# 1312                False                     False               False
# 2629                False                     False               False
# 878                 False                     False               False
# 255                 False                     False               False
# 924                 False                     False               False
# 2969                False                      True               False
# 2632                False                     False               False
# 1806                False                     False               False
# 1324                False                     False               False
# 1036                False                     False               False
# 3274                False                     False               False
# 2454                False                     False               False
# 98                  False                     False               False
# 3326                False                     False               False
# 1950                False                     False                True
# 1568                False                     False               False
# 3260                False                     False               False
# 2297                False                     False               False
# 3244                False                     False               False
# 72                  False                     False               False
# 2012                False                     False               False
# 1948                False                     False               False
# 958                 False                     False               False
# 1558                False                     False               False
# 871                 False                     False               False
# 3235                False                      True               False
# 1066                False                      True               False
# 2326                False                      True               False
# 814                 False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 2527                    False         False     False           False
# 1312                    False         False     False           False
# 2629                    False         False     False           False
# 878                     False         False     False           False
# 255                      True         False     False           False
# 924                     False         False     False           False
# 2969                    False         False     False           False
# 2632                    False         False     False           False
# 1806                     True         False     False           False
# 1324                    False         False     False           False
# 1036                    False         False     False           False
# 3274                     True         False     False           False
# 2454                     True         False     False           False
# 98                      False         False     False           False
# 3326                     True         False     False           False
# 1950                    False         False     False           False
# 1568                    False         False     False           False
# 3260                     True         False     False           False
# 2297                    False         False     False           False
# 3244                    False         False     False           False
# 72                       True         False     False           False
# 2012                    False         False      True            True
# 1948                    False         False     False           False
# 958                     False         False     False           False
# 1558                    False         False     False           False
# 871                     False         False     False           False
# 3235                    False         False     False           False
# 1066                    False         False     False           False
# 2326                    False         False     False           False
# 814                     False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 2527            False           False               False           False
# 1312            False           False                True            True
# 2629            False           False               False           False
# 878             False           False               False            True
# 255             False           False               False           False
# 924             False           False               False            True
# 2969            False           False               False           False
# 2632            False            True                True           False
# 1806            False           False               False           False
# 1324             True            True                True           False
# 1036            False           False                True           False
# 3274            False           False               False           False
# 2454            False           False               False           False
# 98              False           False                True           False
# 3326            False           False               False           False
# 1950             True            True                True            True
# 1568            False           False               False            True
# 3260            False           False               False           False
# 2297            False           False               False           False
# 3244            False           False               False            True
# 72              False           False               False           False
# 2012            False           False               False           False
# 1948            False           False                True            True
# 958              True           False               False           False
# 1558            False           False               False           False
# 871             False            True                True           False
# 3235            False           False               False           False
# 1066            False           False               False           False
# 2326            False           False               False           False
# 814              True           False               False           False
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 2527           False          False          False            False
# 1312           False          False          False            False
# 2629           False          False          False            False
# 878            False          False          False            False
# 255            False          False          False            False
# 924            False          False          False            False
# 2969           False          False          False            False
# 2632           False          False          False            False
# 1806           False          False          False            False
# 1324           False          False          False            False
# 1036           False          False          False            False
# 3274           False          False          False            False
# 2454           False          False          False            False
# 98             False          False          False            False
# 3326           False          False          False            False
# 1950           False          False          False            False
# 1568           False          False          False            False
# 3260           False          False          False            False
# 2297           False          False          False            False
# 3244           False          False          False            False
# 72             False          False          False            False
# 2012           False          False           True            False
# 1948           False          False          False            False
# 958            False          False          False            False
# 1558           False          False          False            False
# 871            False          False          False            False
# 3235           False          False          False            False
# 1066           False          False          False            False
# 2326           False          False          False            False
# 814            False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 2527           False           False          False            False
# 1312           False           False          False            False
# 2629           False           False          False            False
# 878            False           False          False            False
# 255            False           False          False            False
# 924            False           False          False            False
# 2969           False           False          False            False
# 2632           False           False          False            False
# 1806           False           False          False            False
# 1324           False           False          False            False
# 1036           False           False          False            False
# 3274           False           False          False            False
# 2454           False           False          False            False
# 98             False           False          False            False
# 3326           False           False          False            False
# 1950           False           False          False            False
# 1568           False           False          False            False
# 3260           False           False          False            False
# 2297           False           False          False            False
# 3244           False           False          False            False
# 72             False           False          False            False
# 2012           False           False          False            False
# 1948           False           False          False            False
# 958            False           False          False            False
# 1558           False           False          False            False
# 871            False           False          False            False
# 3235           False           False          False            False
# 1066           False           False          False            False
# 2326           False           False          False            False
# 814            False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 2527            False           False              False           False
# 1312            False           False              False           False
# 2629            False           False              False           False
# 878             False           False              False           False
# 255             False           False              False           False
# 924             False           False              False           False
# 2969            False           False              False           False
# 2632            False           False              False           False
# 1806            False           False              False           False
# 1324            False           False              False           False
# 1036            False           False              False           False
# 3274            False           False              False           False
# 2454            False           False              False           False
# 98              False           False              False           False
# 3326            False           False              False           False
# 1950            False           False              False           False
# 1568            False           False              False           False
# 3260            False           False              False           False
# 2297            False           False              False           False
# 3244            False           False              False           False
# 72              False           False              False           False
# 2012            False           False              False           False
# 1948            False           False              False           False
# 958             False           False              False           False
# 1558            False           False              False           False
# 871             False           False              False           False
# 3235            False           False              False           False
# 1066            False           False              False           False
# 2326            False           False              False           False
# 814             False           False              False           False
#
#       First_Third_Match  has_two_chars  Contains_Tribe  \
# 2527              False          False           False
# 1312              False          False           False
# 2629              False          False           False
# 878               False          False           False
# 255               False          False           False
# 924               False          False           False
# 2969              False          False           False
# 2632              False          False           False
# 1806              False          False           False
# 1324              False          False           False
# 1036              False          False           False
# 3274              False          False           False
# 2454              False          False           False
# 98                False          False           False
# 3326              False          False           False
# 1950              False          False           False
# 1568              False          False           False
# 3260              False          False           False
# 2297              False          False           False
# 3244              False          False           False
# 72                False          False           False
# 2012              False          False           False
# 1948              False          False           False
# 958               False          False           False
# 1558              False          False           False
# 871               False          False           False
# 3235              False          False           False
# 1066              False          False           False
# 2326              False          False           False
# 814               False          False           False
#
#       contains_special_words  contains_special_cars  thousands_plate_no  \
# 2527                   False                  False               False
# 1312                   False                  False               False
# 2629                   False                  False               False
# 878                    False                  False               False
# 255                    False                  False               False
# 924                    False                  False               False
# 2969                   False                  False               False
# 2632                   False                  False               False
# 1806                   False                  False               False
# 1324                   False                  False               False
# 1036                   False                  False               False
# 3274                   False                  False               False
# 2454                   False                  False               False
# 98                     False                  False               False
# 3326                   False                  False               False
# 1950                   False                  False               False
# 1568                   False                  False               False
# 3260                   False                  False               False
# 2297                   False                  False               False
# 3244                   False                  False               False
# 72                     False                  False               False
# 2012                   False                  False               False
# 1948                   False                  False               False
# 958                    False                  False               False
# 1558                   False                  False               False
# 871                    False                  False               False
# 3235                   False                  False               False
# 1066                   False                  False               False
# 2326                   False                  False               False
# 814                    False                  False               False
#
#       similar_three_in_four combined_word  word_freq_score
# 2527                  False           سعد         0.935720
# 1312                  False           سعد         0.935720
# 2629                  False           سعد         0.935720
# 878                   False           سعد         0.935720
# 255                   False           سعد         0.935720
# 924                   False           سعد         0.935720
# 2969                  False           سعد         0.935720
# 2632                  False           سعد         0.935720
# 1806                  False           سعد         0.935720
# 1324                  False           سعد         0.935720
# 1036                  False           سعد         0.935720
# 3274                  False           سعد         0.935720
# 2454                  False           سعد         0.935720
# 98                    False           سعد         0.935720
# 3326                  False           سعد         0.935720
# 1950                   True           سعد         0.935720
# 1568                  False           سعد         0.935720
# 3260                  False           سعد         0.935720
# 2297                  False           سعد         0.935720
# 3244                  False           سعد         0.935720
# 72                    False           سعد         0.935720
# 2012                  False           سعد         0.935720
# 1948                  False           سعد         0.935720
# 958                   False           أحب         0.935289
# 1558                  False           أحب         0.935289
# 871                   False           أحب         0.935289
# 3235                  False           أحب         0.935289
# 1066                  False           أحب         0.935289
# 2326                  False           أحب         0.935289
# 814                   False           أحب         0.935289

# %%
first_rank = pd.read_csv('data/first_name_rank.csv')

# %%
first_rank.head()
# Out:
#    Unnamed: 0 first_name  first_name_rank
# 0          52        أبو       100.000000
# 1        1770        على        99.925595
# 2        1661        عبد        99.851190
# 3         670        حسن        99.776786
# 4         146         أم        99.702381

# %%
first_rank['first_name_rank'] = first_rank['first_name_rank'].apply(lambda x : x / 100)

# %%
df['first_name_rank'] = df['char1_ar'] + df['char2_ar'] + df['char3_ar']
df['first_name_rank'] = df['first_name_rank'].map(dict(zip(first_rank['first_name'], first_rank['first_name_rank']))).fillna(0)

# %%
df.sort_values(by='first_name_rank',ascending=False).head(50).tail(50)
# Out:
#      char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 1465   أ ب و   U B A        أ        ب        و        A        B        U
# 3322   ع ل ى   V L E        ع        ل        ى        E        L        V
# 1577   ع ل ى   V L E        ع        ل        ى        E        L        V
# 3447   ع ل ى   V L E        ع        ل        ى        E        L        V
# 3444   ع ل ى   V L E        ع        ل        ى        E        L        V
# 3443   ع ل ى   V L E        ع        ل        ى        E        L        V
# 2618   ح س ن   N S J        ح        س        ن        J        S        N
# 3197   ح س ن   N S J        ح        س        ن        J        S        N
# 1400   ح س ن   N S J        ح        س        ن        J        S        N
# 138    ح س ن   N S J        ح        س        ن        J        S        N
# 1980   ح س ن   N S J        ح        س        ن        J        S        N
# 397    ح س ن   N S J        ح        س        ن        J        S        N
# 2602   ح س ن   N S J        ح        س        ن        J        S        N
# 314    ع م ر   R Z E        ع        م        ر        E        Z        R
# 1080   ع م ر   R Z E        ع        م        ر        E        Z        R
# 3281   ع م ر   R Z E        ع        م        ر        E        Z        R
# 1132   ع م ر   R Z E        ع        م        ر        E        Z        R
# 1666   ع م ر   R Z E        ع        م        ر        E        Z        R
# 2454   س ع د   D E S        س        ع        د        S        E        D
# 3326   س ع د   D E S        س        ع        د        S        E        D
# 3274   س ع د   D E S        س        ع        د        S        E        D
# 878    س ع د   S E D        س        ع        د        D        E        S
# 72     س ع د   D E S        س        ع        د        S        E        D
# 924    س ع د   D E S        س        ع        د        S        E        D
# 98     س ع د   D E S        س        ع        د        S        E        D
# 2012   س ع د   D E S        س        ع        د        S        E        D
# 1948   س ع د   D E S        س        ع        د        S        E        D
# 1950   س ع د   D E S        س        ع        د        S        E        D
# 1806   س ع د   D E S        س        ع        د        S        E        D
# 2297   س ع د   D E S        س        ع        د        S        E        D
# 1568   س ع د   D E S        س        ع        د        S        E        D
# 1036   س ع د   D E S        س        ع        د        S        E        D
# 3260   س ع د   D E S        س        ع        د        S        E        D
# 1324   س ع د   D E S        س        ع        د        S        E        D
# 1312   س ع د   D E S        س        ع        د        S        E        D
# 2969   س ع د   D E S        س        ع        د        S        E        D
# 255    س ع د   D E S        س        ع        د        S        E        D
# 2629   س ع د   D E S        س        ع        د        S        E        D
# 2632   س ع د   D E S        س        ع        د        S        E        D
# 2527   س ع د   D E S        س        ع        د        S        E        D
# 3244   س ع د   D E S        س        ع        د        S        E        D
# 766    ب د ر   R D B        ب        د        ر        B        D        R
# 298    ب د ر   R D B        ب        د        ر        B        D        R
# 2159   ب د ر   R D B        ب        د        ر        B        D        R
# 11     ب د ر   R D B        ب        د        ر        B        D        R
# 20     ب د ر   R D B        ب        د        ر        B        D        R
# 548    ب د ر   R D B        ب        د        ر        B        D        R
# 2018   ب د ر   R D B        ب        د        ر        B        D        R
# 2366   ب د ر   R D B        ب        د        ر        B        D        R
# 1633   ب د ر   R D B        ب        د        ر        B        D        R
#
#      plate_no   price class  plate_no_length  similar_digits  sepcial_date  \
# 1465        5  200000   NaN                1            True         False
# 3322      400   10000   NaN                3           False         False
# 1577      385   16200   NaN                3           False         False
# 3447      400   10000   NaN                3           False         False
# 3444      400   10000   NaN                3           False         False
# 3443      400   10000   NaN                3           False         False
# 2618     7845    5000   NaN                4           False         False
# 3197     4490    7500   NaN                4           False         False
# 1400     4762   45000   NaN                4           False         False
# 138      6611   20000   NaN                4           False         False
# 1980      659      12   NaN                3           False         False
# 397      1151   15000   NaN                4           False         False
# 2602      960   11000   NaN                3           False         False
# 314       775   49000   NaN                3           False         False
# 1080      505   12300   NaN                3           False         False
# 3281      789   45000   NaN                3           False         False
# 1132       91   13000   NaN                2           False         False
# 1666      789   35000   NaN                3           False         False
# 2454     1895    4500   NaN                4           False         False
# 3326     6549   12000   NaN                4           False         False
# 3274     6024    5000   NaN                4           False         False
# 878      8177    6500   NaN                4           False         False
# 72       9710    4000   NaN                4           False         False
# 924      5011    8500   NaN                4           False         False
# 98       9309    6500   NaN                4           False         False
# 2012        2   85000   NaN                1            True         False
# 1948     5655   10000   NaN                4           False         False
# 1950     9999   12000   NaN                4            True         False
# 1806     3294    5000   NaN                4           False         False
# 2297     5939    3500   NaN                4           False         False
# 1568      500    7000   NaN                3           False         False
# 1036     3393   17000   NaN                4           False         False
# 3260     8243    8000   NaN                4           False         False
# 1324     3883   25000   NaN                4           False         False
# 1312     2522   20000   NaN                4           False         False
# 2969      481   25000   NaN                3           False         False
# 255      2045    6000   NaN                4           False         False
# 2629     5057   20000   NaN                4           False         False
# 2632      606   12500   NaN                3           False         False
# 2527      784    6700   NaN                3           False         False
# 3244     7800       1   NaN                4           False         False
# 766      5355   13000   NaN                4           False         False
# 298      2050   50000   NaN                4           False         False
# 2159     8979   20000   NaN                4           False         False
# 11        277   45000   NaN                3           False         False
# 20       6379    5500   NaN                4           False         False
# 548       979  100000   NaN                3           False         False
# 2018     4795   19000   NaN                4           False         False
# 2366     3116   10000   NaN                4           False         False
# 1633      228   40000   NaN                3           False         False
#
#       saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 1465         False       True              False                   False
# 3322         False      False              False                   False
# 1577         False      False              False                   False
# 3447         False      False              False                   False
# 3444         False      False              False                   False
# 3443         False      False              False                   False
# 2618         False      False              False                   False
# 3197         False      False              False                   False
# 1400         False      False              False                   False
# 138          False      False              False                   False
# 1980         False      False              False                   False
# 397          False      False              False                   False
# 2602         False      False              False                   False
# 314          False      False              False                   False
# 1080          True      False              False                   False
# 3281         False      False              False                   False
# 1132         False      False              False                    True
# 1666         False      False              False                   False
# 2454         False      False              False                   False
# 3326         False      False              False                   False
# 3274         False      False              False                   False
# 878          False      False              False                   False
# 72           False      False              False                   False
# 924          False      False              False                   False
# 98           False      False              False                   False
# 2012         False       True              False                   False
# 1948         False      False              False                   False
# 1950         False      False              False                   False
# 1806         False      False              False                   False
# 2297         False      False              False                   False
# 1568         False      False              False                   False
# 1036         False      False              False                   False
# 3260         False      False              False                   False
# 1324         False      False              False                   False
# 1312         False      False              False                   False
# 2969         False      False              False                   False
# 255          False      False              False                   False
# 2629         False      False              False                   False
# 2632         False      False              False                   False
# 2527         False      False              False                   False
# 3244         False      False              False                   False
# 766          False      False              False                   False
# 298          False      False              False                   False
# 2159         False      False              False                   False
# 11           False      False              False                   False
# 20           False      False              False                   False
# 548          False      False              False                   False
# 2018         False      False              False                   False
# 2366         False      False              False                   False
# 1633         False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 1465                False                     False               False
# 3322                False                     False               False
# 1577                False                      True               False
# 3447                False                     False               False
# 3444                False                     False               False
# 3443                False                     False               False
# 2618                False                     False               False
# 3197                False                     False               False
# 1400                False                     False               False
# 138                 False                     False               False
# 1980                False                      True               False
# 397                 False                     False               False
# 2602                False                      True               False
# 314                 False                     False               False
# 1080                False                     False               False
# 3281                False                      True               False
# 1132                False                     False               False
# 1666                False                      True               False
# 2454                False                     False               False
# 3326                False                     False               False
# 3274                False                     False               False
# 878                 False                     False               False
# 72                  False                     False               False
# 924                 False                     False               False
# 98                  False                     False               False
# 2012                False                     False               False
# 1948                False                     False               False
# 1950                False                     False                True
# 1806                False                     False               False
# 2297                False                     False               False
# 1568                False                     False               False
# 1036                False                     False               False
# 3260                False                     False               False
# 1324                False                     False               False
# 1312                False                     False               False
# 2969                False                      True               False
# 255                 False                     False               False
# 2629                False                     False               False
# 2632                False                     False               False
# 2527                False                      True               False
# 3244                False                     False               False
# 766                 False                     False               False
# 298                 False                     False               False
# 2159                False                     False               False
# 11                  False                     False               False
# 20                  False                     False               False
# 548                 False                     False               False
# 2018                False                     False               False
# 2366                False                     False               False
# 1633                False                     False               False
#
#       Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 1465                    False         False      True            True
# 3322                    False         False     False           False
# 1577                    False         False     False           False
# 3447                    False         False     False           False
# 3444                    False         False     False           False
# 3443                    False         False     False           False
# 2618                     True         False     False           False
# 3197                    False         False     False           False
# 1400                     True         False     False           False
# 138                     False         False     False           False
# 1980                    False         False     False           False
# 397                     False         False     False           False
# 2602                    False         False     False           False
# 314                     False         False     False           False
# 1080                    False         False     False           False
# 3281                    False         False      True           False
# 1132                    False         False     False           False
# 1666                    False         False      True           False
# 2454                     True         False     False           False
# 3326                     True         False     False           False
# 3274                     True         False     False           False
# 878                     False         False     False           False
# 72                       True         False     False           False
# 924                     False         False     False           False
# 98                      False         False     False           False
# 2012                    False         False      True            True
# 1948                    False         False     False           False
# 1950                    False         False     False           False
# 1806                     True         False     False           False
# 2297                    False         False     False           False
# 1568                    False         False     False           False
# 1036                    False         False     False           False
# 3260                     True         False     False           False
# 1324                    False         False     False           False
# 1312                    False         False     False           False
# 2969                    False         False     False           False
# 255                      True         False     False           False
# 2629                    False         False     False           False
# 2632                    False         False     False           False
# 2527                    False         False     False           False
# 3244                    False         False     False           False
# 766                     False         False     False           False
# 298                     False         False     False           False
# 2159                    False         False     False           False
# 11                      False         False     False           False
# 20                       True         False     False           False
# 548                     False         False     False           False
# 2018                     True         False     False           False
# 2366                    False         False     False           False
# 1633                    False         False     False           False
#
#       same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 1465            False           False               False           False
# 3322            False           False               False            True
# 1577            False           False               False           False
# 3447            False           False               False            True
# 3444            False           False               False            True
# 3443            False           False               False            True
# 2618            False           False               False           False
# 3197            False           False               False           False
# 1400            False           False               False           False
# 138             False           False               False            True
# 1980            False           False               False           False
# 397             False           False                True           False
# 2602            False           False               False           False
# 314             False           False               False            True
# 1080            False            True                True           False
# 3281            False           False               False           False
# 1132            False           False               False           False
# 1666            False           False               False           False
# 2454            False           False               False           False
# 3326            False           False               False           False
# 3274            False           False               False           False
# 878             False           False               False            True
# 72              False           False               False           False
# 924             False           False               False            True
# 98              False           False                True           False
# 2012            False           False               False           False
# 1948            False           False                True            True
# 1950             True            True                True            True
# 1806            False           False               False           False
# 2297            False           False               False           False
# 1568            False           False               False            True
# 1036            False           False                True           False
# 3260            False           False               False           False
# 1324             True            True                True           False
# 1312            False           False                True            True
# 2969            False           False               False           False
# 255             False           False               False           False
# 2629            False           False               False           False
# 2632            False            True                True           False
# 2527            False           False               False           False
# 3244            False           False               False            True
# 766             False           False                True            True
# 298             False           False               False           False
# 2159            False           False               False           False
# 11              False           False               False            True
# 20              False           False               False           False
# 548             False            True                True           False
# 2018            False           False               False           False
# 2366             True           False               False           False
# 1633            False           False               False            True
#
#       one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 1465           False          False          False            False
# 3322           False          False          False            False
# 1577           False          False          False            False
# 3447           False          False          False            False
# 3444           False          False          False            False
# 3443           False          False          False            False
# 2618           False          False          False            False
# 3197           False          False          False            False
# 1400           False          False          False            False
# 138            False          False          False            False
# 1980           False          False          False            False
# 397            False          False          False            False
# 2602           False          False          False            False
# 314            False          False          False            False
# 1080           False          False          False            False
# 3281           False          False          False            False
# 1132           False          False          False            False
# 1666           False          False          False            False
# 2454           False          False          False            False
# 3326           False          False          False            False
# 3274           False          False          False            False
# 878            False          False          False            False
# 72             False          False          False            False
# 924            False          False          False            False
# 98             False          False          False            False
# 2012           False          False           True            False
# 1948           False          False          False            False
# 1950           False          False          False            False
# 1806           False          False          False            False
# 2297           False          False          False            False
# 1568           False          False          False            False
# 1036           False          False          False            False
# 3260           False          False          False            False
# 1324           False          False          False            False
# 1312           False          False          False            False
# 2969           False          False          False            False
# 255            False          False          False            False
# 2629           False          False          False            False
# 2632           False          False          False            False
# 2527           False          False          False            False
# 3244           False          False          False            False
# 766            False          False          False            False
# 298            False          False          False            False
# 2159           False          False          False            False
# 11             False          False          False            False
# 20             False          False          False            False
# 548            False          False          False            False
# 2018           False          False          False            False
# 2366           False          False          False            False
# 1633           False          False          False            False
#
#       one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 1465           False            True          False            False
# 3322           False           False          False            False
# 1577           False           False          False            False
# 3447           False           False          False            False
# 3444           False           False          False            False
# 3443           False           False          False            False
# 2618           False           False          False            False
# 3197           False           False          False            False
# 1400           False           False          False            False
# 138            False           False          False            False
# 1980           False           False          False            False
# 397            False           False          False            False
# 2602           False           False          False            False
# 314            False           False          False            False
# 1080           False           False          False            False
# 3281           False           False          False            False
# 1132           False           False          False            False
# 1666           False           False          False            False
# 2454           False           False          False            False
# 3326           False           False          False            False
# 3274           False           False          False            False
# 878            False           False          False            False
# 72             False           False          False            False
# 924            False           False          False            False
# 98             False           False          False            False
# 2012           False           False          False            False
# 1948           False           False          False            False
# 1950           False           False          False            False
# 1806           False           False          False            False
# 2297           False           False          False            False
# 1568           False           False          False            False
# 1036           False           False          False            False
# 3260           False           False          False            False
# 1324           False           False          False            False
# 1312           False           False          False            False
# 2969           False           False          False            False
# 255            False           False          False            False
# 2629           False           False          False            False
# 2632           False           False          False            False
# 2527           False           False          False            False
# 3244           False           False          False            False
# 766            False           False          False            False
# 298            False           False          False            False
# 2159           False           False          False            False
# 11             False           False          False            False
# 20             False           False          False            False
# 548            False           False          False            False
# 2018           False           False          False            False
# 2366           False           False          False            False
# 1633           False           False          False            False
#
#       one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 1465            False           False              False           False
# 3322            False           False              False           False
# 1577            False           False              False           False
# 3447            False           False              False           False
# 3444            False           False              False           False
# 3443            False           False              False           False
# 2618            False           False              False           False
# 3197            False           False              False           False
# 1400            False           False              False           False
# 138             False           False              False           False
# 1980            False           False              False           False
# 397             False           False              False           False
# 2602            False           False              False           False
# 314             False           False              False           False
# 1080            False           False              False           False
# 3281            False           False              False           False
# 1132            False           False              False           False
# 1666            False           False              False           False
# 2454            False           False              False           False
# 3326            False           False              False           False
# 3274            False           False              False           False
# 878             False           False              False           False
# 72              False           False              False           False
# 924             False           False              False           False
# 98              False           False              False           False
# 2012            False           False              False           False
# 1948            False           False              False           False
# 1950            False           False              False           False
# 1806            False           False              False           False
# 2297            False           False              False           False
# 1568            False           False              False           False
# 1036            False           False              False           False
# 3260            False           False              False           False
# 1324            False           False              False           False
# 1312            False           False              False           False
# 2969            False           False              False           False
# 255             False           False              False           False
# 2629            False           False              False           False
# 2632            False           False              False           False
# 2527            False           False              False           False
# 3244            False           False              False           False
# 766             False           False              False           False
# 298             False           False              False           False
# 2159            False           False              False           False
# 11              False           False              False           False
# 20              False           False              False           False
# 548             False           False              False           False
# 2018            False           False              False           False
# 2366            False           False              False           False
# 1633            False           False              False           False
#
#       First_Third_Match  has_two_chars  Contains_Tribe  \
# 1465              False          False           False
# 3322              False          False           False
# 1577              False          False           False
# 3447              False          False           False
# 3444              False          False           False
# 3443              False          False           False
# 2618              False          False           False
# 3197              False          False           False
# 1400              False          False           False
# 138               False          False           False
# 1980              False          False           False
# 397               False          False           False
# 2602              False          False           False
# 314               False          False           False
# 1080              False          False           False
# 3281              False          False           False
# 1132              False          False           False
# 1666              False          False           False
# 2454              False          False           False
# 3326              False          False           False
# 3274              False          False           False
# 878               False          False           False
# 72                False          False           False
# 924               False          False           False
# 98                False          False           False
# 2012              False          False           False
# 1948              False          False           False
# 1950              False          False           False
# 1806              False          False           False
# 2297              False          False           False
# 1568              False          False           False
# 1036              False          False           False
# 3260              False          False           False
# 1324              False          False           False
# 1312              False          False           False
# 2969              False          False           False
# 255               False          False           False
# 2629              False          False           False
# 2632              False          False           False
# 2527              False          False           False
# 3244              False          False           False
# 766               False          False           False
# 298               False          False           False
# 2159              False          False           False
# 11                False          False           False
# 20                False          False           False
# 548               False          False           False
# 2018              False          False           False
# 2366              False          False           False
# 1633              False          False           False
#
#       contains_special_words  contains_special_cars  thousands_plate_no  \
# 1465                   False                  False               False
# 3322                   False                  False               False
# 1577                   False                  False               False
# 3447                   False                  False               False
# 3444                   False                  False               False
# 3443                   False                  False               False
# 2618                   False                  False               False
# 3197                   False                  False               False
# 1400                   False                  False               False
# 138                    False                  False               False
# 1980                   False                  False               False
# 397                    False                  False               False
# 2602                   False                  False               False
# 314                    False                  False               False
# 1080                   False                  False               False
# 3281                   False                  False               False
# 1132                   False                  False               False
# 1666                   False                  False               False
# 2454                   False                  False               False
# 3326                   False                  False               False
# 3274                   False                  False               False
# 878                    False                  False               False
# 72                     False                  False               False
# 924                    False                  False               False
# 98                     False                  False               False
# 2012                   False                  False               False
# 1948                   False                  False               False
# 1950                   False                  False               False
# 1806                   False                  False               False
# 2297                   False                  False               False
# 1568                   False                  False               False
# 1036                   False                  False               False
# 3260                   False                  False               False
# 1324                   False                  False               False
# 1312                   False                  False               False
# 2969                   False                  False               False
# 255                    False                  False               False
# 2629                   False                  False               False
# 2632                   False                  False               False
# 2527                   False                  False               False
# 3244                   False                  False               False
# 766                    False                  False               False
# 298                    False                  False               False
# 2159                   False                  False               False
# 11                     False                  False               False
# 20                     False                  False               False
# 548                    False                  False               False
# 2018                   False                  False               False
# 2366                   False                  False               False
# 1633                   False                  False               False
#
#       similar_three_in_four combined_word  word_freq_score  first_name_rank
# 1465                  False           أبو         0.966350         1.000000
# 3322                  False           على         0.999569         0.999256
# 1577                  False           على         0.999569         0.999256
# 3447                  False           على         0.999569         0.999256
# 3444                  False           على         0.999569         0.999256
# 3443                  False           على         0.999569         0.999256
# 2618                  False           حسن         0.956859         0.997768
# 3197                  False           حسن         0.956859         0.997768
# 1400                  False           حسن         0.956859         0.997768
# 138                   False           حسن         0.956859         0.997768
# 1980                  False           حسن         0.956859         0.997768
# 397                   False           حسن         0.956859         0.997768
# 2602                  False           حسن         0.956859         0.997768
# 314                   False           عمر         0.961605         0.996280
# 1080                  False           عمر         0.961605         0.996280
# 3281                  False           عمر         0.961605         0.996280
# 1132                  False           عمر         0.961605         0.996280
# 1666                  False           عمر         0.961605         0.996280
# 2454                  False           سعد         0.935720         0.995536
# 3326                  False           سعد         0.935720         0.995536
# 3274                  False           سعد         0.935720         0.995536
# 878                   False           سعد         0.935720         0.995536
# 72                    False           سعد         0.935720         0.995536
# 924                   False           سعد         0.935720         0.995536
# 98                    False           سعد         0.935720         0.995536
# 2012                  False           سعد         0.935720         0.995536
# 1948                  False           سعد         0.935720         0.995536
# 1950                   True           سعد         0.935720         0.995536
# 1806                  False           سعد         0.935720         0.995536
# 2297                  False           سعد         0.935720         0.995536
# 1568                  False           سعد         0.935720         0.995536
# 1036                  False           سعد         0.935720         0.995536
# 3260                  False           سعد         0.935720         0.995536
# 1324                  False           سعد         0.935720         0.995536
# 1312                  False           سعد         0.935720         0.995536
# 2969                  False           سعد         0.935720         0.995536
# 255                   False           سعد         0.935720         0.995536
# 2629                  False           سعد         0.935720         0.995536
# 2632                  False           سعد         0.935720         0.995536
# 2527                  False           سعد         0.935720         0.995536
# 3244                  False           سعد         0.935720         0.995536
# 766                   False           بدر         0.900777         0.994792
# 298                   False           بدر         0.900777         0.994792
# 2159                  False           بدر         0.900777         0.994792
# 11                    False           بدر         0.900777         0.994792
# 20                    False           بدر         0.900777         0.994792
# 548                   False           بدر         0.900777         0.994792
# 2018                  False           بدر         0.900777         0.994792
# 2366                  False           بدر         0.900777         0.994792
# 1633                  False           بدر         0.900777         0.994792

# %%
df.shape
# Out:
# (3690, 51)

# %%
df.head(1)
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   ر ه م   Z H R        ر        ه        م        R        H        Z
#
#   plate_no  price class  plate_no_length  similar_digits  sepcial_date  \
# 0     9777   6500   NaN                4           False         False
#
#    saudi_tribes  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0         False      False              False                   False
#
#    Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                False                     False               False
#
#    Four Digits (Different)  emergency_no  in_order  reversed_order  \
# 0                    False         False     False           False
#
#    same_middles_no  plaindromic_no  same_first_last_no  same_two_sides  \
# 0             True           False               False            True
#
#    one_digit_zero  one_digit_one  one_digit_two  one_digit_three  \
# 0           False          False          False            False
#
#    one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 0           False           False          False            False
#
#    one_digit_eight  one_digit_nine  is_triple_letters  is_one_letters  \
# 0            False           False              False           False
#
#    First_Third_Match  has_two_chars  Contains_Tribe  contains_special_words  \
# 0              False          False           False                   False
#
#    contains_special_cars  thousands_plate_no  similar_three_in_four  \
# 0                  False               False                   True
#
#   combined_word  word_freq_score  first_name_rank
# 0           رهم         0.087575              0.0

# %%
df.to_csv('data/data_with_features.csv',index=False)

# %%
tribes = ['07', '101', '111', '205', '305', '404', '405', '411', '501',
                '502', '504','505', '507', '509', '511', '513', '514', '516', '517',
                '518', '523', '555', '601', '702', '707', '711', '812', '906','909', '911']
tribes_chart = ['ق ح ط', 'ح ر ب', 'د س ر', 'م ط ر', 'س ب ع', 'د ح ه', 'ى ا م']

# Define regex patterns for different plate types
patterns = {
    "One Digit": r"^\d$",
    "Two Digits (Same)": r"^(\d)\1$",
    "Two Digits (Different)": r"^(\d)(?!\1)\d$",
    "Three Digits (Same)": r"^(\d)\1\1$",
    "Three Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)\d$",
    "Four Digits (Same)": r"^(\d)\1\1\1$",
    "Four Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$"
}
# List of 2-letter words
two_letter_words = [
    "K A",  # Common prefix in Arabic names (e.g., "Khalid")
    "S A",  # Short for Saudi Arabia
    "L A",  # Means "no" in Arabic
    "H A",  # Expression of joy or laughter
    "R A",  # Short for "Riyadh" or a common sound in Arabic
    "J A",  # Short for "Jeddah" or a common sound in Arabic
    "B A",  # Common prefix in Arabic names (e.g., "Basel")
    "X A",  # Unique and modern, often used in license plates for style
]

# List of 3-letter words with meanings
three_letter_words = [
    "K S A",  # Abbreviation for Saudi Arabia, highly popular
    "D A D",  # Common English word, also meaningful in Arabic
    "L A H",  # Means "no" in Arabic, widely recognized
    "J A D",  # Means "new" in Arabic
    "B A D",  # Means "after" in Arabic
    "G A S",  # Common English word, also recognized in Arabic
    "R E D",  # Common English word, also recognized in Arabic
    "J E T",  # Common English word, also recognized in Arabic
    "T A G",  # Common English word
    "H U G",  # Common English word
    "L A X",  # Means "relaxed" in English
    "L E X"   # Short for "lexicon" or a name
]

all_words = two_letter_words + three_letter_words
car_names = [
    "L X",   # Lexus LX series (e.g., LX 570) - Luxury SUV
    "G X",   # Lexus GX series (e.g., GX 460) - Luxury SUV
    "R X",   # Lexus RX series (e.g., RX 350) - Luxury crossover
    "L S",   # Lexus LS series (e.g., LS 500) - Flagship luxury sedan
    "L C",   # Lexus LC series (e.g., LC 500) - Luxury coupe
    "E S",   # Lexus ES series (e.g., ES 350) - Executive sedan
    "G S",   # Lexus GS series (e.g., GS 350) - Luxury sports sedan
    "R C",   # Lexus RC series (e.g., RC 350) - Luxury coupe
    "U X",   # Lexus UX series (e.g., UX 200) - Compact luxury crossover
    "N X",   # Lexus NX series (e.g., NX 300) - Compact luxury SUV
    "G T",   # Grand Touring trim (e.g., Porsche 911 GT3, BMW M8 GT)
    "G L",   # Mercedes-Benz GL series (e.g., GL 450) - Luxury SUV
    "G L E",  # Mercedes-Benz GLE series (e.g., GLE 450) - Luxury SUV
    "G L S",  # Mercedes-Benz GLS series (e.g., GLS 580) - Flagship luxury SUV
    "S",    # Mercedes-Benz S-Class (e.g., S 500) - Flagship luxury sedan
    "C",    # Mercedes-Benz C-Class (e.g., C 300) - Executive sedan
    "E",    # Mercedes-Benz E-Class (e.g., E 350) - Executive sedan
    "G",    # Mercedes-Benz G-Class (e.g., G 550) - Luxury off-road SUV
    "A M G",  # Mercedes-AMG performance models (e.g., C 63 AMG)
    "X",    # BMW X series (e.g., X5, X7) - Luxury SUVs
    "M",    # BMW M series (e.g., M5, M8) - High-performance models
    "Q",    # Audi Q series (e.g., Q7, Q8) - Luxury SUVs
    "A",    # Audi A series (e.g., A8, A6) - Luxury sedans
    "R S",   # Audi RS series (e.g., RS 7) - High-performance models
    "S",    # Audi S series (e.g., S5) - Sporty performance models
    "R",    # Porsche 911 Carrera R - High-performance sports car
    "C",    # Porsche Cayenne (e.g., Cayenne Turbo) - Luxury SUV
    "P",    # Porsche Panamera (e.g., Panamera Turbo) - Luxury sedan
    "T",    # Tesla Model T (e.g., Tesla Model S Plaid) - High-performance EV
    "S",    # Tesla Model S (e.g., Model S Plaid) - Luxury electric sedan
    "X",    # Tesla Model X (e.g., Model X Plaid) - Luxury electric SUV
    "Y",    # Tesla Model Y (e.g., Model Y Performance) - Compact electric SUV
    "J",    # Jaguar F-Type (e.g., F-Type R) - Luxury sports car
    "F",    # Ferrari (e.g., Ferrari 488 GTB) - High-performance sports car
    "L",    # Lamborghini (e.g., Lamborghini Urus) - Luxury SUV
    "B",    # Bentley (e.g., Bentayga) - Luxury SUV
    "R",    # Rolls-Royce (e.g., Rolls-Royce Cullinan) - Ultra-luxury SUV
    "W",    # Range Rover (e.g., Range Rover Vogue) - Luxury SUV
    "V",    # Volvo XC90 (e.g., XC90 Excellence) - Luxury SUV
]

saudi_emergency_numbers = ["999", "997", "998", "993", "911", "996", "994", "933", "937", "930", "989", "991"]

def has_match_letters(text):
    clean_text = text.replace(' ', '')

    if len(clean_text) < 3:
        return False 
    
    # -- return true if ( N A N ) and excluded Case one ( A A A) 
    return bool(clean_text[0] == clean_text[2] and clean_text[1] != clean_text[2])

# %%
def get_features(char,plate_no):
    features = {}
    features['plate_no_length'] = len(plate_no)
    features['similar_digits'] = len(set(plate_no)) == 1
    # in detail number of digits

    # Special date feature
    features['sepcial_date'] = True if 1980 <= int(plate_no) <= 2030 else False
    # Saudi tribes feature
    features ['saudi_tribes'] = plate_no in tribes
    # # Define regex patterns for different plate types
    for name, pattern in patterns.items():
        features[name] = bool(re.match(pattern, plate_no))
    # Emergency numbers
    features['emergency_no'] = plate_no in saudi_emergency_numbers
    # 7. in-order consecutive numbers
    pattern =  r"^(\d)(?=\1|[2-9])$"
    if isinstance(plate_no, str) and plate_no.isdigit():
        features['in_order'] =  all(int(plate_no[i]) + 1 == int(plate_no[i + 1]) for i in range(len(plate_no) - 1))
    else:
         features['in_order'] = False
    # 8. reversed order consecutive numbers
    if isinstance(plate_no, str) and plate_no.isdigit():
         features['reversed_order'] =  all(int(plate_no[i]) - 1 == int(plate_no[i + 1]) for i in range(len(plate_no) - 1))
    else:
         features['reversed_order'] = False

    # place of similarity

    #Same two middle digits in four-digit plate number
    pattern = r"^\d(\d)\1\d$"
    features['same_middles_no'] = bool(re.match(pattern, plate_no))
    # # plaindromic is a word that is read the same from left to right or right to left 
    pattern = r"^(\d)(\d)?\2?\1$"  
    features['plaindromic_no'] = bool(re.match(pattern, plate_no))

    # the same first and last 
    pattern = r"^(\d)(\d{0,2})\1$"
    features['same_first_last_no'] = bool(re.match(pattern, plate_no))
    # repeating sides (two lefts or two rights) 3344
    pattern = r"^(\d)\1\d?$|^(\d)\1\d\d$|^\d?(\d)\3$|^\d\d(\d)\4$"
    features['same_two_sides'] = bool(re.match(pattern, plate_no))
    # Checking the count of one-digit df
    features['one_digit_zero'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='0')
    features['one_digit_one'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='1')
    features['one_digit_two'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='2')
    features['one_digit_three'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='3')
    features['one_digit_four'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='4')
    features['one_digit_five'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='5')
    features['one_digit_six'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='6')
    features['one_digit_seven'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='7')
    features['one_digit_eight'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='8')
    features['one_digit_nine'] = bool(re.match(patterns['One Digit'],plate_no) and plate_no=='9')
    

    # // characters Features eng:
    # Triple Letters
    features['is_triple_letters'] = bool(re.search(r'(\S)\s*\1\s*\1', char))
    features['is_one_letters'] = bool(len(char) == 1)
    #  First Letter == Third Letter
    clean_text = plate_no.replace(' ', '')

    features['First_Third_Match'] = has_match_letters(clean_text)
    features['has_two_chars'] =  len(clean_text) == 2
    features['Contains_Tribe'] = any(tribe in char for tribe in tribes)
     # -- Case 7: English Characters (K S A)
    features['contains_special_words'] = char in all_words
    # -- Case 7: English Characters Cars Names (L X)
    features['contains_special_cars'] = char in car_names

    features['thousands_plate_no'] = bool(re.match(r'^\d000$', char))
    features['similar_three_in_four'] = bool(re.match(r"(\d(\d)\2{2}|\2{2}\d)", char))

   



     





    return len(features)

# %%
get_features('أ ب ت','7')
# Out:
# 37
