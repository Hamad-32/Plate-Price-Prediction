# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
plates = pd.read_csv('plates_no_features.csv')

# %%
plates.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1   أ أ أ   A A A        أ        أ        أ        A        A        A
# 2   أ أ أ   A A A        أ        أ        أ        A        A        A
# 3   أ أ أ   A A A        أ        أ        أ        A        A        A
# 4   أ أ أ   A A A        أ        أ        أ        A        A        A
#
#    plate_no    price  ...  one_digit_one  one_digit_two  one_digit_three  \
# 0         0  2000000  ...          False          False            False
# 1      2116     7000  ...          False          False            False
# 2      3309    13000  ...          False          False            False
# 3      5561     9000  ...          False          False            False
# 4      6932     5000  ...          False          False            False
#
#    one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 0           False           False          False            False
# 1           False           False          False            False
# 2           False           False          False            False
# 3           False           False          False            False
# 4           False           False          False            False
#
#    one_digit_eight  one_digit_nine  two_consecutive_same_digits
# 0            False           False                        False
# 1            False           False                        False
# 2            False           False                        False
# 3            False           False                        False
# 4            False           False                        False
#
# [5 rows x 41 columns]

# %%
plates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3041 entries, 0 to 3040
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   char_ar                      3041 non-null   object
#  1   char_en                      3041 non-null   object
#  2   char1_ar                     3041 non-null   object
#  3   char2_ar                     3036 non-null   object
#  4   char3_ar                     3029 non-null   object
#  5   char1_en                     3041 non-null   object
#  6   char2_en                     3036 non-null   object
#  7   char3_en                     3029 non-null   object
#  8   plate_no                     3041 non-null   int64
#  9   price                        3041 non-null   int64
#  10  rank                         3041 non-null   float64
#  11  popularity                   3041 non-null   float64
#  12  plate_no_length              3041 non-null   int64
#  13  similar_digits               3041 non-null   bool
#  14  sepcial_date                 3041 non-null   bool
#  15  saudi_tribes                 3041 non-null   bool
#  16  emergency_no                 3041 non-null   bool
#  17  in_order                     3041 non-null   bool
#  18  reversed_order               3041 non-null   bool
#  19  One Digit                    3041 non-null   bool
#  20  Two Digits (Same)            3041 non-null   bool
#  21  Two Digits (Different)       3041 non-null   bool
#  22  Three Digits (Same)          3041 non-null   bool
#  23  Three Digits (Different)     3041 non-null   bool
#  24  Four Digits (Same)           3041 non-null   bool
#  25  Four Digits (Different)      3041 non-null   bool
#  26  same_middles_no              3041 non-null   bool
#  27  plaindromic_no               3041 non-null   bool
#  28  same_first_last_no           3041 non-null   bool
#  29  same_two_sides               3041 non-null   bool
#  30  one_digit_zero               3041 non-null   bool
#  31  one_digit_one                3041 non-null   bool
#  32  one_digit_two                3041 non-null   bool
#  33  one_digit_three              3041 non-null   bool
#  34  one_digit_four               3041 non-null   bool
#  35  one_digit_five               3041 non-null   bool
#  36  one_digit_six                3041 non-null   bool
#  37  one_digit_seven              3041 non-null   bool
#  38  one_digit_eight              3041 non-null   bool
#  39  one_digit_nine               3041 non-null   bool
#  40  two_consecutive_same_digits  3041 non-null   bool
# dtypes: bool(28), float64(2), int64(3), object(8)
# memory usage: 392.1+ KB

# %%
# plates = plates.drop(columns='Unnamed: 0')

# %%
plates['plate_no'] = plates['plate_no'].astype(str)

# %% [markdown]
# ## EDA to Analyze and Discover Features

# %% [markdown]
# ### Plates with one digit

# %%
# Filter data to include only rows where plate_no is a single digit
one_digit = plates[plates["plate_no"].str.match(r"^\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(one_digit["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Only Single-Digit Plate Numbers)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
plates[plates["plate_no"].str.match(r"^\d$")]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 12        أ ب ق      A B G        أ        ب        ق        A        B
# 35        أ م ل      A Z L        أ        م        ل        A        Z
# 47        أ و س      A U S        أ        و        س        A        U
# 71        ب ح م      B J Z        ب        ح        م        B        J
# ...         ...        ...      ...      ...      ...      ...      ...
# 2930  ق   ح   ك  K   J   G        ق        ح        ك        G        J
# 2963  و   ق   ن  N   G   U        و        ق        ن        U        G
# 3030  ا   ن   ق  G   N   A        ا        ن        ق        A        N
# 3031  ق   ى   ل  L   V   G        ق        ى        ل        G        V
# 3038  د   ص   ع  E   X   D        د        ص        ع        D        X
#
#      char3_en plate_no    price  ...  one_digit_one  one_digit_two  \
# 0           A        0  2000000  ...          False          False
# 12          G        3    70000  ...          False          False
# 35          L        2    85000  ...          False           True
# 47          S        4    34000  ...          False          False
# 71          Z        2    50000  ...          False           True
# ...       ...      ...      ...  ...            ...            ...
# 2930        K        5    55000  ...          False          False
# 2963        N        5    60000  ...          False          False
# 3030        G        3  1000000  ...          False          False
# 3031        L        8    40000  ...          False          False
# 3038        E        2    40000  ...          False           True
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 0               False           False           False          False
# 12               True           False           False          False
# 35              False           False           False          False
# 47              False            True           False          False
# 71              False           False           False          False
# ...               ...             ...             ...            ...
# 2930            False           False            True          False
# 2963            False           False            True          False
# 3030             True           False           False          False
# 3031            False           False           False          False
# 3038            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 0               False            False           False
# 12              False            False           False
# 35              False            False           False
# 47              False            False           False
# 71              False            False           False
# ...               ...              ...             ...
# 2930            False            False           False
# 2963            False            False           False
# 3030            False            False           False
# 3031            False             True           False
# 3038            False            False           False
#
#       two_consecutive_same_digits
# 0                           False
# 12                          False
# 35                          False
# 47                          False
# 71                          False
# ...                           ...
# 2930                        False
# 2963                        False
# 3030                        False
# 3031                        False
# 3038                        False
#
# [320 rows x 41 columns]

# %%
# Checking minimum and maximum price for one-digit plate_no
one_digit['price'].min(), one_digit['price'].max()
# Out:
# (600, 205000000)

# %% [markdown]
# ### Two-digit plates

# %% [markdown]
# Same-two-digit plates

# %%
# Filter data to include only rows where plate_no has two digits
same_two_digits = plates[plates["plate_no"].str.match(r"^(\d)\1$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(same_two_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Same Two Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
plates[plates["plate_no"].str.match(r"^(\d)\1$")]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 15        أ ب ن      A B N        أ        ب        ن        A        B
# 46        أ و د      A U D        أ        و        د        A        U
# 84        ب س س      B S S        ب        س        س        B        S
# 110       ب ل ب      B L B        ب        ل        ب        B        L
# 112       ب ل و      B L U        ب        ل        و        B        L
# ...         ...        ...      ...      ...      ...      ...      ...
# 2926  ب   ع   ك  K   E   B        ب        ع        ك        B        E
# 2934  و   ع   ا  A   E   U        و        ع        ا        U        E
# 2936  ه   ح   ه  H   J   H        ه        ح        ه        H        J
# 2951  ب   س   ط  T   S   B        ب        س        ط        B        S
# 3023  ه   ه   س  S   H   H        ه        ه        س        H        H
#
#      char3_en plate_no   price  ...  one_digit_one  one_digit_two  \
# 15          N       88   30000  ...          False          False
# 46          D       77   60000  ...          False          False
# 84          S       11  250000  ...          False          False
# 110         B       88   37000  ...          False          False
# 112         U       77   60000  ...          False          False
# ...       ...      ...     ...  ...            ...            ...
# 2926        K       55   21000  ...          False          False
# 2934        A       66   29000  ...          False          False
# 2936        H       22   32000  ...          False          False
# 2951        T       99   27000  ...          False          False
# 3023        S       22   50000  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 15              False           False           False          False
# 46              False           False           False          False
# 84              False           False           False          False
# 110             False           False           False          False
# 112             False           False           False          False
# ...               ...             ...             ...            ...
# 2926            False           False           False          False
# 2934            False           False           False          False
# 2936            False           False           False          False
# 2951            False           False           False          False
# 3023            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 15              False            False           False
# 46              False            False           False
# 84              False            False           False
# 110             False            False           False
# 112             False            False           False
# ...               ...              ...             ...
# 2926            False            False           False
# 2934            False            False           False
# 2936            False            False           False
# 2951            False            False           False
# 3023            False            False           False
#
#       two_consecutive_same_digits
# 15                          False
# 46                          False
# 84                          False
# 110                         False
# 112                         False
# ...                           ...
# 2926                        False
# 2934                        False
# 2936                        False
# 2951                        False
# 3023                        False
#
# [177 rows x 41 columns]

# %%
#Checking minimum and maximum price for same-two-digits plates
same_two_digits['price'].min(), same_two_digits['price'].max()
# Out:
# (10000, 400000)

# %% [markdown]
# Different-two-digit plates

# %%
# Filter data to include only rows where plate_no has two different digits
different_two_digits = plates[plates["plate_no"].str.match(r"^(\d)(?!\1)\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(different_two_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Different Two Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
plates[plates["plate_no"].str.match(r"^(\d)(?!\1)\d$")]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 14        أ ب م      A B Z        أ        ب        م        A        B
# 17        أ ر ب      A R B        أ        ر        ب        A        R
# 24        أ ص س      A X S        أ        ص        س        A        X
# 44       أ هـ م      A H Z        أ       هـ        م        A        H
# 57       ب أ هـ      B A H        ب        أ       هـ        B        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3017  د   و   ن  N   U   D        د        و        ن        D        U
# 3018  ل   ب   ن  N   B   L        ل        ب        ن        L        B
# 3019  د   ر   ه  H   R   D        د        ر        ه        D        R
# 3020  س   ق   ط  T   G   S        س        ق        ط        S        G
# 3026  ر   ر   س  S   R   R        ر        ر        س        R        R
#
#      char3_en plate_no  price  ...  one_digit_one  one_digit_two  \
# 14          Z       20  60000  ...          False          False
# 17          B       75  15500  ...          False          False
# 24          S       68  60000  ...          False          False
# 44          Z       97  20000  ...          False          False
# 57          H       14  35000  ...          False          False
# ...       ...      ...    ...  ...            ...            ...
# 3017        N       18  25000  ...          False          False
# 3018        N       56  22000  ...          False          False
# 3019        H       27  25000  ...          False          False
# 3020        T       46  20000  ...          False          False
# 3026        S       49  15000  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 14              False           False           False          False
# 17              False           False           False          False
# 24              False           False           False          False
# 44              False           False           False          False
# 57              False           False           False          False
# ...               ...             ...             ...            ...
# 3017            False           False           False          False
# 3018            False           False           False          False
# 3019            False           False           False          False
# 3020            False           False           False          False
# 3026            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 14              False            False           False
# 17              False            False           False
# 24              False            False           False
# 44              False            False           False
# 57              False            False           False
# ...               ...              ...             ...
# 3017            False            False           False
# 3018            False            False           False
# 3019            False            False           False
# 3020            False            False           False
# 3026            False            False           False
#
#       two_consecutive_same_digits
# 14                          False
# 17                          False
# 24                          False
# 44                          False
# 57                          False
# ...                           ...
# 3017                        False
# 3018                        False
# 3019                        False
# 3020                        False
# 3026                        False
#
# [604 rows x 41 columns]

# %%
# Checking minimum and maximum price for different-two-digit plates
different_two_digits['price'].min(), different_two_digits['price'].max()
# Out:
# (1000, 999999999999)

# %%
different_two_digits[different_two_digits['price'] == 999999999999]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 2283  ه   ك   ن  N   K   H        ه        ك        ن        H        K
#
#      char3_en plate_no         price  ...  one_digit_one  one_digit_two  \
# 2283        N       80  999999999999  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 2283            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 2283            False            False           False
#
#       two_consecutive_same_digits
# 2283                        False
#
# [1 rows x 41 columns]

# %% [markdown]
# ### Three-digit plates

# %% [markdown]
# Same-three-digit plates

# %%
# Filter data to include only rows where plate_no has the same three digits
same_three_digits = plates[plates["plate_no"].str.match(r"^(\d)\1\1$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(same_three_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Same Three Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
plates[plates["plate_no"].str.match(r"^(\d)\1\1$")]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 96        ب ع ق      B E G        ب        ع        ق        B        E
# 103       ب ق و      B G U        ب        ق        و        B        G
# 108       ب ك ل      B K L        ب        ك        ل        B        K
# 113       ب م ط      B Z T        ب        م        ط        B        Z
# 128       ح ب د      J B D        ح        ب        د        J        B
# ...         ...        ...      ...      ...      ...      ...      ...
# 2968  م   ل   ب  B   L   Z        م        ل        ب        Z        L
# 2969  ص   س   ر  R   S   X        ص        س        ر        X        S
# 2988  ا   ر   ك  K   R   A        ا        ر        ك        A        R
# 2989  ح   ى   ل  L   V   J        ح        ى        ل        J        V
# 3036  ر   ص   د  D   X   R        ر        ص        د        R        X
#
#      char3_en plate_no   price  ...  one_digit_one  one_digit_two  \
# 96          G      222   19500  ...          False          False
# 103         U      333   32000  ...          False          False
# 108         L      888   27000  ...          False          False
# 113         T      777   21000  ...          False          False
# 128         D      777   20000  ...          False          False
# ...       ...      ...     ...  ...            ...            ...
# 2968        B      888   30000  ...          False          False
# 2969        R      555   13000  ...          False          False
# 2988        K      777   30000  ...          False          False
# 2989        L      111  100000  ...          False          False
# 3036        D      777   30000  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 96              False           False           False          False
# 103             False           False           False          False
# 108             False           False           False          False
# 113             False           False           False          False
# 128             False           False           False          False
# ...               ...             ...             ...            ...
# 2968            False           False           False          False
# 2969            False           False           False          False
# 2988            False           False           False          False
# 2989            False           False           False          False
# 3036            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 96              False            False           False
# 103             False            False           False
# 108             False            False           False
# 113             False            False           False
# 128             False            False           False
# ...               ...              ...             ...
# 2968            False            False           False
# 2969            False            False           False
# 2988            False            False           False
# 2989            False            False           False
# 3036            False            False           False
#
#       two_consecutive_same_digits
# 96                          False
# 103                         False
# 108                         False
# 113                         False
# 128                         False
# ...                           ...
# 2968                        False
# 2969                        False
# 2988                        False
# 2989                        False
# 3036                        False
#
# [175 rows x 41 columns]

# %%
# Checking minimum and maximum price for same-three-digit plates
same_three_digits['price'].min(), same_three_digits['price'].max()
# Out:
# (1000, 108446043404)

# %% [markdown]
# Different-three-digits plates

# %%
# Filter data to include only rows where plate_no has different three digits
different_three_digits = plates[plates["plate_no"].str.match(r"^(\d)(?!\1)(\d)(?!\1|\2)\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(different_three_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Different Three Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
different_three_digits
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 7         أ أ س      A A S        أ        أ        س        A        A
# 28        أ ع ط      A E T        أ        ع        ط        A        E
# 33       أ ل هـ      A L H        أ        ل       هـ        A        L
# 39        أ م ن      A Z N        أ        م        ن        A        Z
# 42       أ ن هـ      A N H        أ        ن       هـ        A        N
# ...         ...        ...      ...      ...      ...      ...      ...
# 3025  ى   ر   ح  J   R   V        ى        ر        ح        V        R
# 3027  س   ا   ل  L   A   S        س        ا        ل        S        A
# 3028  ر   ر   و  U   R   R        ر        ر        و        R        R
# 3032  ب   ه   ا  A   H   B        ب        ه        ا        B        H
# 3037  ه   م   ن  N   Z   H        ه        م        ن        H        Z
#
#      char3_en plate_no  price  ...  one_digit_one  one_digit_two  \
# 7           S      570  10000  ...          False          False
# 28          T      248   9000  ...          False          False
# 33          H      370   8000  ...          False          False
# 39          N      123  50000  ...          False          False
# 42          H      305  30000  ...          False          False
# ...       ...      ...    ...  ...            ...            ...
# 3025        J      120   5000  ...          False          False
# 3027        L      740   3500  ...          False          False
# 3028        U      174   4000  ...          False          False
# 3032        A      264   7000  ...          False          False
# 3037        N      203  20000  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 7               False           False           False          False
# 28              False           False           False          False
# 33              False           False           False          False
# 39              False           False           False          False
# 42              False           False           False          False
# ...               ...             ...             ...            ...
# 3025            False           False           False          False
# 3027            False           False           False          False
# 3028            False           False           False          False
# 3032            False           False           False          False
# 3037            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 7               False            False           False
# 28              False            False           False
# 33              False            False           False
# 39              False            False           False
# 42              False            False           False
# ...               ...              ...             ...
# 3025            False            False           False
# 3027            False            False           False
# 3028            False            False           False
# 3032            False            False           False
# 3037            False            False           False
#
#       two_consecutive_same_digits
# 7                           False
# 28                          False
# 33                          False
# 39                          False
# 42                          False
# ...                           ...
# 3025                        False
# 3027                        False
# 3028                        False
# 3032                        False
# 3037                        False
#
# [402 rows x 41 columns]

# %%
# Checking minimum and maximum price for different-three-digit plates
different_three_digits['price'].min(), different_three_digits['price'].max()
# Out:
# (700, 1000000)

# %% [markdown]
# ### Four-digit plates

# %% [markdown]
# Same-four-digit plates

# %%
# Filter data to include only rows where plate_no has the same three digits
same_four_digits = plates[plates["plate_no"].str.match(r"^(\d)\1\1\1$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(same_four_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Same Four Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
same_four_digits
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 6         أ أ ح      A A J        أ        أ        ح        A        A
# 27        أ ط ل      A T L        أ        ط        ل        A        T
# 31        أ ل ر      A L R        أ        ل        ر        A        L
# 54        أ ى ط      A V T        أ        ى        ط        A        V
# 94        ب ع ح      B E J        ب        ع        ح        B        E
# ...         ...        ...      ...      ...      ...      ...      ...
# 2725  د   د   ا  A   D   D        د        د        ا        D        D
# 2783  د   ب   ك  K   B   D        د        ب        ك        D        B
# 2802  ا   ن   ع  E   N   A        ا        ن        ع        A        N
# 2830  ر   ح   ر  R   J   R        ر        ح        ر        R        J
# 2873  ا   ا   ع  E   A   A        ا        ا        ع        A        A
#
#      char3_en plate_no  price  ...  one_digit_one  one_digit_two  \
# 6           J     5555  60000  ...          False          False
# 27          L     1111  50000  ...          False          False
# 31          R     2222  25000  ...          False          False
# 54          T     6666  55000  ...          False          False
# 94          J     4444  15000  ...          False          False
# ...       ...      ...    ...  ...            ...            ...
# 2725        A     3333  23000  ...          False          False
# 2783        K     8888  20000  ...          False          False
# 2802        E     9999  21000  ...          False          False
# 2830        R     3333  25000  ...          False          False
# 2873        E     6666  15000  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 6               False           False           False          False
# 27              False           False           False          False
# 31              False           False           False          False
# 54              False           False           False          False
# 94              False           False           False          False
# ...               ...             ...             ...            ...
# 2725            False           False           False          False
# 2783            False           False           False          False
# 2802            False           False           False          False
# 2830            False           False           False          False
# 2873            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 6               False            False           False
# 27              False            False           False
# 31              False            False           False
# 54              False            False           False
# 94              False            False           False
# ...               ...              ...             ...
# 2725            False            False           False
# 2783            False            False           False
# 2802            False            False           False
# 2830            False            False           False
# 2873            False            False           False
#
#       two_consecutive_same_digits
# 6                            True
# 27                           True
# 31                           True
# 54                           True
# 94                           True
# ...                           ...
# 2725                         True
# 2783                         True
# 2802                         True
# 2830                         True
# 2873                         True
#
# [71 rows x 41 columns]

# %%
# Checking minimum and maximum price for same-four-digit plates
same_four_digits['price'].min(), same_four_digits['price'].max()
# Out:
# (8000, 1010101)

# %% [markdown]
# Different-four-digit plate

# %%
# Filter data to include only rows where plate_no has different four digits
different_four_digits = plates[plates["plate_no"].str.match(r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$")]

# Plot histogram of prices
plt.figure(figsize=(8, 5))
plt.hist(different_four_digits["price"], bins=10, color="blue", alpha=0.7, edgecolor="black")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("Histogram of Plate Prices (Different Four Digits)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
different_four_digits
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# 22        أ س د      A S D        أ        س        د        A        S
# 51        أ و ك      A U K        أ        و        ك        A        U
# 65        ب ب ب      B B B        ب        ب        ب        B        B
# 78        ب د ر      B D R        ب        د        ر        B        D
# ...         ...        ...      ...      ...      ...      ...      ...
# 2956  ح   ا   م  Z   A   J        ح        ا        م        J        A
# 2960  ح   م   د  D   Z   J        ح        م        د        J        Z
# 2967  ح   ل   م  Z   L   J        ح        ل        م        J        L
# 2984  ح   ر   ب  B   R   J        ح        ر        ب        J        R
# 3024  ح   ر   ب  B   R   J        ح        ر        ب        J        R
#
#      char3_en plate_no  price  ...  one_digit_one  one_digit_two  \
# 4           A     6932   5000  ...          False          False
# 22          D     9320  34000  ...          False          False
# 51          K     2435   6500  ...          False          False
# 65          B     8649   7000  ...          False          False
# 78          R     6379   5500  ...          False          False
# ...       ...      ...    ...  ...            ...            ...
# 2956        Z     4321   8000  ...          False          False
# 2960        D     9240   3000  ...          False          False
# 2967        Z     6490   5000  ...          False          False
# 2984        B     5360   5000  ...          False          False
# 3024        B     6539  15000  ...          False          False
#
#       one_digit_three  one_digit_four  one_digit_five  one_digit_six  \
# 4               False           False           False          False
# 22              False           False           False          False
# 51              False           False           False          False
# 65              False           False           False          False
# 78              False           False           False          False
# ...               ...             ...             ...            ...
# 2956            False           False           False          False
# 2960            False           False           False          False
# 2967            False           False           False          False
# 2984            False           False           False          False
# 3024            False           False           False          False
#
#       one_digit_seven  one_digit_eight  one_digit_nine  \
# 4               False            False           False
# 22              False            False           False
# 51              False            False           False
# 65              False            False           False
# 78              False            False           False
# ...               ...              ...             ...
# 2956            False            False           False
# 2960            False            False           False
# 2967            False            False           False
# 2984            False            False           False
# 3024            False            False           False
#
#       two_consecutive_same_digits
# 4                           False
# 22                          False
# 51                          False
# 65                          False
# 78                          False
# ...                           ...
# 2956                        False
# 2960                        False
# 2967                        False
# 2984                        False
# 3024                        False
#
# [123 rows x 41 columns]

# %%
# Checking price for different-digit-plates
different_four_digits['price'].min(), different_four_digits['price'].max()
# Out:
# (800, 90000)

# %% [markdown]
# Average / mode price for all the cases

# %%
# Define regex patterns for different plate types
patterns = {
    "One Digit": r"^\d$",
    "Two Digits (Same)": r"^(\d)\1$",
    "Two Digits (Different)": r"^(\d)(?!\1)\d$",
    "Three Digits (Same)": r"^(\d)\1\1$",
    "Three Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)\d$",
    "Four Digits (Same)": r"^(\d)\1\1\1$",
    "Four Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$"
}

avg_prices = {}
for category, pattern in patterns.items():
    filtered_df = plates[plates["plate_no"].str.match(pattern)]
    avg_prices[category] = int(filtered_df["price"].mean() or 0)  # Convert to int, set to 0 if NaN

# Convert dictionary to DataFrame
avg_prices_df = pd.DataFrame(list(avg_prices.items()), columns=["Category", "Average Price"])

# %% [markdown]
# Average with outliers

# %%
# Data from your message
categories = avg_prices_df['Category']
values = avg_prices_df['Average Price']

# Colors for different categories
colors = ["blue", "orange", "orange", "green", "green", "red", "red"]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors, alpha=0.7, edgecolor="black")

# Apply logarithmic scale to fix visualization issues
plt.yscale("log")

# Label each bar with its value
for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, value, f'{value:,}', 
            ha='center', va='bottom', fontsize=10)

# Formatting
plt.xlabel("Plate Category")
plt.ylabel("Average Price (Log Scale)")
plt.title("Average Price for Each Plate Number Category (Log Scale)")
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Without outliers

# %%
# Calculate the Z-scores for the 'price' column
z_scores = (plates['price'] - plates['price'].mean()) / plates['price'].std()

# Filter out rows where the Z-score is greater than 3 or less than -3
plates_no_outliers = plates[abs(z_scores) <= 3]

# %%
# Define regex patterns for different plate types
patterns = {
    "One Digit": r"^\d$",
    "Two Digits (Same)": r"^(\d)\1$",
    "Two Digits (Different)": r"^(\d)(?!\1)\d$",
    "Three Digits (Same)": r"^(\d)\1\1$",
    "Three Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)\d$",
    "Four Digits (Same)": r"^(\d)\1\1\1$",
    "Four Digits (Different)": r"^(\d)(?!\1)(\d)(?!\1|\2)(\d)(?!\1|\2|\3)\d$"
}

avg_prices = {}
for category, pattern in patterns.items():
    filtered_df = plates_no_outliers[plates_no_outliers["plate_no"].str.match(pattern)]
    avg_prices[category] = int(filtered_df["price"].median() or 0)  # Convert to int, set to 0 if NaN

# Convert dictionary to DataFrame
avg_prices_df = pd.DataFrame(list(avg_prices.items()), columns=["Category", "Median Price"])

# %%
avg_prices_df
# Out:
#                    Category  Median Price
# 0                 One Digit         79500
# 1         Two Digits (Same)         29000
# 2    Two Digits (Different)         20000
# 3       Three Digits (Same)         26500
# 4  Three Digits (Different)         10000
# 5        Four Digits (Same)         22000
# 6   Four Digits (Different)          5500

# %%
# Without outliers 
# Data from your message
categories = avg_prices_df['Category']
values = avg_prices_df['Median Price']


# Colors for different categories
colors = ["blue", "orange", "orange", "green", "green", "red", "red"]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=colors, alpha=0.7, edgecolor="black")

# Apply logarithmic scale to fix visualization issues
plt.yscale("log")

# Label each bar with its value
for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width()/2, value, f'{value:,}', 
            ha='center', va='bottom', fontsize=10)

# Formatting
plt.xlabel("Plate Category")
plt.ylabel("Median Price (Log Scale)")
plt.title("Median Price for Each Plate Number Category (Log Scale)")
plt.xticks(rotation=20)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## Feature Engineering

# %%
plates.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1   أ أ أ   A A A        أ        أ        أ        A        A        A
# 2   أ أ أ   A A A        أ        أ        أ        A        A        A
# 3   أ أ أ   A A A        أ        أ        أ        A        A        A
# 4   أ أ أ   A A A        أ        أ        أ        A        A        A
#
#   plate_no    price  ...  one_digit_one  one_digit_two  one_digit_three  \
# 0        0  2000000  ...          False          False            False
# 1     2116     7000  ...          False          False            False
# 2     3309    13000  ...          False          False            False
# 3     5561     9000  ...          False          False            False
# 4     6932     5000  ...          False          False            False
#
#    one_digit_four  one_digit_five  one_digit_six  one_digit_seven  \
# 0           False           False          False            False
# 1           False           False          False            False
# 2           False           False          False            False
# 3           False           False          False            False
# 4           False           False          False            False
#
#    one_digit_eight  one_digit_nine  two_consecutive_same_digits
# 0            False           False                        False
# 1            False           False                        False
# 2            False           False                        False
# 3            False           False                        False
# 4            False           False                        False
#
# [5 rows x 41 columns]

# %%
plates[plates['plate_no'] == '1234']
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 324       ر ن أ      R N A        ر        ن        أ        R        N
# 2408  س   ق   ب  B   G   S        س        ق        ب        S        G
# 2824  ح   ل   ك  K   L   J        ح        ل        ك        J        L
#
#      char3_en plate_no  price  rank  popularity  plate_no_length  \
# 324         A     1234  10000   0.0         0.0                4
# 2408        B     1234   1000   0.0         0.0                4
# 2824        K     1234  20000   0.0         0.0                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 324            False         False         False         False     False
# 2408           False         False         False         False     False
# 2824           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 324            False      False              False                   False
# 2408           False      False              False                   False
# 2824           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 324                 False                     False               False
# 2408                False                     False               False
# 2824                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 324                      True            False           False
# 2408                     True            False           False
# 2824                     True            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 324                False           False           False          False
# 2408               False           False           False          False
# 2824               False           False           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 324           False            False           False           False
# 2408          False            False           False           False
# 2824          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine  \
# 324           False            False            False           False
# 2408          False            False            False           False
# 2824          False            False            False           False
#
#       two_consecutive_same_digits
# 324                         False
# 2408                        False
# 2824                        False

# %%
pd.set_option('display.max_columns', None)
plates[plates['in_order'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 12        أ ب ق      A B G        أ        ب        ق        A        B
# 35        أ م ل      A Z L        أ        م        ل        A        Z
# 39        أ م ن      A Z N        أ        م        ن        A        Z
# 47        أ و س      A U S        أ        و        س        A        U
# ...         ...        ...      ...      ...      ...      ...      ...
# 3003  ر   ر   ك  K   R   R        ر        ر        ك        R        R
# 3018  ل   ب   ن  N   B   L        ل        ب        ن        L        B
# 3030  ا   ن   ق  G   N   A        ا        ن        ق        A        N
# 3031  ق   ى   ل  L   V   G        ق        ى        ل        G        V
# 3038  د   ص   ع  E   X   D        د        ص        ع        D        X
#
#      char3_en plate_no    price    rank  popularity  plate_no_length  \
# 0           A        0  2000000     0.0       0.000                1
# 12          G        3    70000     0.0       0.000                1
# 35          L        2    85000  1117.0       0.149                1
# 39          N      123    50000     0.0       0.000                3
# 47          S        4    34000     0.0       0.049                1
# ...       ...      ...      ...     ...         ...              ...
# 3003        K       12    11000     0.0       0.000                2
# 3018        N       56    22000     0.0       0.000                2
# 3030        G        3  1000000     0.0       0.000                1
# 3031        L        8    40000     0.0       0.000                1
# 3038        E        2    40000     0.0       0.000                1
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 0               True         False         False         False      True
# 12              True         False         False         False      True
# 35              True         False         False         False      True
# 39             False         False         False         False      True
# 47              True         False         False         False      True
# ...              ...           ...           ...           ...       ...
# 3003           False         False         False         False      True
# 3018           False         False         False         False      True
# 3030            True         False         False         False      True
# 3031            True         False         False         False      True
# 3038            True         False         False         False      True
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0               True       True              False                   False
# 12              True       True              False                   False
# 35              True       True              False                   False
# 39             False      False              False                   False
# 47              True       True              False                   False
# ...              ...        ...                ...                     ...
# 3003           False      False              False                    True
# 3018           False      False              False                    True
# 3030            True       True              False                   False
# 3031            True       True              False                   False
# 3038            True       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 12                  False                     False               False
# 35                  False                     False               False
# 39                  False                      True               False
# 47                  False                     False               False
# ...                   ...                       ...                 ...
# 3003                False                     False               False
# 3018                False                     False               False
# 3030                False                     False               False
# 3031                False                     False               False
# 3038                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 0                       False            False           False
# 12                      False            False           False
# 35                      False            False           False
# 39                      False            False           False
# 47                      False            False           False
# ...                       ...              ...             ...
# 3003                    False            False           False
# 3018                    False            False           False
# 3030                    False            False           False
# 3031                    False            False           False
# 3038                    False            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 0                  False           False            True          False
# 12                 False           False           False          False
# 35                 False           False           False          False
# 39                 False           False           False          False
# 47                 False           False           False          False
# ...                  ...             ...             ...            ...
# 3003               False           False           False          False
# 3018               False           False           False          False
# 3030               False           False           False          False
# 3031               False           False           False          False
# 3038               False           False           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 0             False            False           False           False
# 12            False             True           False           False
# 35             True            False           False           False
# 39            False            False           False           False
# 47            False            False            True           False
# ...             ...              ...             ...             ...
# 3003          False            False           False           False
# 3018          False            False           False           False
# 3030          False             True           False           False
# 3031          False            False           False           False
# 3038           True            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine  \
# 0             False            False            False           False
# 12            False            False            False           False
# 35            False            False            False           False
# 39            False            False            False           False
# 47            False            False            False           False
# ...             ...              ...              ...             ...
# 3003          False            False            False           False
# 3018          False            False            False           False
# 3030          False            False            False           False
# 3031          False            False             True           False
# 3038          False            False            False           False
#
#       two_consecutive_same_digits
# 0                           False
# 12                          False
# 35                          False
# 39                          False
# 47                          False
# ...                           ...
# 3003                        False
# 3018                        False
# 3030                        False
# 3031                        False
# 3038                        False
#
# [372 rows x 41 columns]

# %% [markdown]
# 1. The Length/Number of Digits in a plate

# %%
plates['plate_no_length'] = plates['plate_no'].map(lambda x : len(x))

# %%
plates.head(10)
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1   أ أ أ   A A A        أ        أ        أ        A        A        A
# 2   أ أ أ   A A A        أ        أ        أ        A        A        A
# 3   أ أ أ   A A A        أ        أ        أ        A        A        A
# 4   أ أ أ   A A A        أ        أ        أ        A        A        A
# 5   أ أ ب   A A B        أ        أ        ب        A        A        B
# 6   أ أ ح   A A J        أ        أ        ح        A        A        J
# 7   أ أ س   A A S        أ        أ        س        A        A        S
# 8   أ أ ط   A A T        أ        أ        ط        A        A        T
# 9   أ أ ك   A A K        أ        أ        ك        A        A        K
#
#   plate_no    price  rank  popularity  plate_no_length  similar_digits  \
# 0        0  2000000   0.0         0.0                1            True
# 1     2116     7000   0.0         0.0                4           False
# 2     3309    13000   0.0         0.0                4           False
# 3     5561     9000   0.0         0.0                4           False
# 4     6932     5000   0.0         0.0                4           False
# 5      667    16000   0.0         0.0                3           False
# 6     5555    60000   0.0         0.0                4            True
# 7      570    10000   0.0         0.0                3           False
# 8      700     3500   0.0         0.0                3           False
# 9     1009     9000   0.0         0.0                4           False
#
#    sepcial_date  saudi_tribes  emergency_no  in_order  reversed_order
# 0         False         False         False      True            True
# 1         False         False         False     False           False
# 2         False         False         False     False           False
# 3         False         False         False     False           False
# 4         False         False         False     False           False
# 5         False         False         False     False           False
# 6         False         False         False     False           False
# 7         False         False         False     False           False
# 8         False         False         False     False           False
# 9         False         False         False     False           False

# %% [markdown]
# 2. similar digits feature

# %%
def is_all_same(plate):
    return len(set(plate)) == 1

# %%
plates['similar_digits'] = plates['plate_no'].apply(is_all_same)

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3039  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3040  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  rank  popularity  plate_no_length  \
# 0           A        0  2000000   0.0         0.0                1
# 1           A     2116     7000   0.0         0.0                4
# 2           A     3309    13000   0.0         0.0                4
# 3           A     5561     9000   0.0         0.0                4
# 4           A     6932     5000   0.0         0.0                4
# ...       ...      ...      ...   ...         ...              ...
# 3038        D      777    30000   0.0         0.0                3
# 3039        N      203    20000   0.0         0.0                3
# 3040        E        2    40000   0.0         0.0                1
# 3041        V      505    50000   0.0         0.0                3
# 3042        B     3533    15000   0.0         0.0                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 0               True         False         False         False      True
# 1              False         False         False         False     False
# 2              False         False         False         False     False
# 3              False         False         False         False     False
# 4              False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3038            True         False         False         False     False
# 3039           False         False         False         False     False
# 3040            True         False         False         False      True
# 3041           False         False          True         False     False
# 3042           False         False         False         False     False
#
#       reversed_order
# 0               True
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 3038           False
# 3039           False
# 3040            True
# 3041           False
# 3042           False
#
# [3043 rows x 19 columns]

# %% [markdown]
# 3. Special date feature

# %%
def is_special_date(plate_no):
    if 1980 <= int(plate_no) <= 2030:
        return True
    else:
        return False

# %%
plates[plates['plate_no'] == '2030']
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 193       د أ أ      D A A        د        أ        أ        D        A
# 275       ر ح ل      R J L        ر        ح        ل        R        J
# 1201      ر ح ل      R J L        ر        ح        ل        R        J
# 1246      ا س س      A S S        ا        س        س        A        S
# 1359      ح ر ب      J R B        ح        ر        ب        J        R
# 2418  ح   ر   ق  G   R   J        ح        ر        ق        J        R
# 2563  ب   ل   ع  E   L   B        ب        ل        ع        B        L
# 2813  د   ل   س  S   L   D        د        ل        س        D        L
#
#      char3_en plate_no   price  rank  popularity  plate_no_length  \
# 193         A     2030   20000   0.0       0.000                4
# 275         L     2030  350000   0.0       0.081                4
# 1201        L     2030  350000   0.0       0.081                4
# 1246        S     2030  300000   0.0       0.000                4
# 1359        B     2030  100000   0.0       0.000                4
# 2418        G     2030   15000   0.0       0.129                4
# 2563        E     2030   15000   0.0       0.000                4
# 2813        S     2030   10000   0.0       0.000                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 193            False          True         False         False     False
# 275            False          True         False         False     False
# 1201           False          True         False         False     False
# 1246           False          True         False         False     False
# 1359           False          True         False         False     False
# 2418           False          True         False         False     False
# 2563           False          True         False         False     False
# 2813           False          True         False         False     False
#
#       reversed_order
# 193            False
# 275            False
# 1201           False
# 1246           False
# 1359           False
# 2418           False
# 2563           False
# 2813           False

# %%
plates[plates['sepcial_date'] == True]['price'].value_counts()
# Out:
# price
# 10000     8
# 15000     5
# 5000      5
# 8000      4
# 7000      4
# 30000     3
# 6000      2
# 3000      2
# 9000      2
# 25000     2
# 2000      2
# 350000    2
# 20000     2
# 300000    1
# 100000    1
# 11000     1
# 7500      1
# 12000     1
# 5500      1
# 4500      1
# 4000      1
# 50000     1
# Name: count, dtype: int64

# %%
plates['sepcial_date'] = plates['plate_no'].apply(is_special_date)

# %%
plates.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1   أ أ أ   A A A        أ        أ        أ        A        A        A
# 2   أ أ أ   A A A        أ        أ        أ        A        A        A
# 3   أ أ أ   A A A        أ        أ        أ        A        A        A
# 4   أ أ أ   A A A        أ        أ        أ        A        A        A
#
#   plate_no    price  rank  popularity  plate_no_length  similar_digits  \
# 0        0  2000000   0.0         0.0                1            True
# 1     2116     7000   0.0         0.0                4           False
# 2     3309    13000   0.0         0.0                4           False
# 3     5561     9000   0.0         0.0                4           False
# 4     6932     5000   0.0         0.0                4           False
#
#    sepcial_date  saudi_tribes  emergency_no  in_order  reversed_order
# 0         False         False         False      True            True
# 1         False         False         False     False           False
# 2         False         False         False     False           False
# 3         False         False         False     False           False
# 4         False         False         False     False           False

# %% [markdown]
# 4. Saudi tribes feature

# %%
saudi_tribes = ['07', '101', '111', '205', '305', '404', '405', '411', '501',
                '502', '504','505', '507', '509', '511', '513', '514', '516', '517',
                '518', '523', '555', '601', '702', '707', '711', '812', '906','909', '911']

# %%
plates['saudi_tribes'] = plates['plate_no'].isin(saudi_tribes)

# %%
plates.head()
# Out:
#   char_ar char_en char1_ar char2_ar char3_ar char1_en char2_en char3_en  \
# 0   أ أ أ   A A A        أ        أ        أ        A        A        A
# 1   أ أ أ   A A A        أ        أ        أ        A        A        A
# 2   أ أ أ   A A A        أ        أ        أ        A        A        A
# 3   أ أ أ   A A A        أ        أ        أ        A        A        A
# 4   أ أ أ   A A A        أ        أ        أ        A        A        A
#
#   plate_no    price  rank  popularity  plate_no_length  similar_digits  \
# 0        0  2000000   0.0         0.0                1            True
# 1     2116     7000   0.0         0.0                4           False
# 2     3309    13000   0.0         0.0                4           False
# 3     5561     9000   0.0         0.0                4           False
# 4     6932     5000   0.0         0.0                4           False
#
#    sepcial_date  saudi_tribes  emergency_no  in_order  reversed_order
# 0         False         False         False      True            True
# 1         False         False         False     False           False
# 2         False         False         False     False           False
# 3         False         False         False     False           False
# 4         False         False         False     False           False

# %%
plates[plates['saudi_tribes'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 43       أ ن هـ      A N H        أ        ن       هـ        A        N
# 59        ب أ ى      B A V        ب        أ        ى        B        A
# 86        ب س م      B S Z        ب        س        م        B        S
# 168       ح ق ك      J G K        ح        ق        ك        J        G
# 172       ح ك ن      J K N        ح        ك        ن        J        K
# ...         ...        ...      ...      ...      ...      ...      ...
# 2952  س   ى   د  D   V   S        س        ى        د        S        V
# 2971  ص   س   ر  R   S   X        ص        س        ر        X        S
# 2991  ح   ى   ل  L   V   J        ح        ى        ل        J        V
# 3014  ع   ل   و  U   L   E        ع        ل        و        E        L
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
#
#      char3_en plate_no   price     rank  popularity  plate_no_length  \
# 43          H      305   30000      0.0       0.000                3
# 59          V      707   30000      0.0       0.000                3
# 86          Z      911  100000  12584.0       0.057                3
# 168         K      911   45000      0.0       0.000                3
# 172         N      111   40000      0.0       0.000                3
# ...       ...      ...     ...      ...         ...              ...
# 2952        D      205   50000      0.0       0.060                3
# 2971        R      555   13000      0.0       0.000                3
# 2991        L      111  100000      0.0       0.000                3
# 3014        U      404   25000  13174.0       0.222                3
# 3041        V      505   50000      0.0       0.000                3
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 43             False         False          True         False     False
# 59             False         False          True         False     False
# 86             False         False          True          True     False
# 168            False         False          True          True     False
# 172             True         False          True         False     False
# ...              ...           ...           ...           ...       ...
# 2952           False         False          True         False     False
# 2971            True         False          True         False     False
# 2991            True         False          True         False     False
# 3014           False         False          True         False     False
# 3041           False         False          True         False     False
#
#       reversed_order
# 43             False
# 59             False
# 86             False
# 168            False
# 172            False
# ...              ...
# 2952           False
# 2971           False
# 2991           False
# 3014           False
# 3041           False
#
# [155 rows x 19 columns]

# %% [markdown]
# 5. in detail number of digits

# %%
for name, pattern in patterns.items():
    plates[name] = plates["plate_no"].astype(str).apply(lambda x: bool(re.match(pattern, x)))

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3039  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3040  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  ...  emergency_no  in_order  reversed_order  \
# 0           A        0  2000000  ...         False      True            True
# 1           A     2116     7000  ...         False     False           False
# 2           A     3309    13000  ...         False     False           False
# 3           A     5561     9000  ...         False     False           False
# 4           A     6932     5000  ...         False     False           False
# ...       ...      ...      ...  ...           ...       ...             ...
# 3038        D      777    30000  ...         False     False           False
# 3039        N      203    20000  ...         False     False           False
# 3040        E        2    40000  ...         False      True            True
# 3041        V      505    50000  ...         False     False           False
# 3042        B     3533    15000  ...         False     False           False
#
#       One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0          True              False                   False
# 1         False              False                   False
# 2         False              False                   False
# 3         False              False                   False
# 4         False              False                   False
# ...         ...                ...                     ...
# 3038      False              False                   False
# 3039      False              False                   False
# 3040       True              False                   False
# 3041      False              False                   False
# 3042      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3038                 True                     False               False
# 3039                False                      True               False
# 3040                False                     False               False
# 3041                False                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                        True
# ...                       ...
# 3038                    False
# 3039                    False
# 3040                    False
# 3041                    False
# 3042                    False
#
# [3043 rows x 26 columns]

# %% [markdown]
# 6. Emergency numbers

# %%
saudi_emergency_numbers = ["999", "997", "998", "993", "911", "996", "994", "933", "937", "930", "989", "991"]

# %%
plates['emergency_no'] = plates['plate_no'].isin(saudi_emergency_numbers)

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3039  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3040  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  ...  emergency_no  in_order  reversed_order  \
# 0           A        0  2000000  ...         False      True            True
# 1           A     2116     7000  ...         False     False           False
# 2           A     3309    13000  ...         False     False           False
# 3           A     5561     9000  ...         False     False           False
# 4           A     6932     5000  ...         False     False           False
# ...       ...      ...      ...  ...           ...       ...             ...
# 3038        D      777    30000  ...         False     False           False
# 3039        N      203    20000  ...         False     False           False
# 3040        E        2    40000  ...         False      True            True
# 3041        V      505    50000  ...         False     False           False
# 3042        B     3533    15000  ...         False     False           False
#
#       One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0          True              False                   False
# 1         False              False                   False
# 2         False              False                   False
# 3         False              False                   False
# 4         False              False                   False
# ...         ...                ...                     ...
# 3038      False              False                   False
# 3039      False              False                   False
# 3040       True              False                   False
# 3041      False              False                   False
# 3042      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3038                 True                     False               False
# 3039                False                      True               False
# 3040                False                     False               False
# 3041                False                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                        True
# ...                       ...
# 3038                    False
# 3039                    False
# 3040                    False
# 3041                    False
# 3042                    False
#
# [3043 rows x 26 columns]

# %% [markdown]
# 7. in-order consecutive numbers

# %%
def in_order(number):
    pattern =  r"^(\d)(?=\1|[2-9])$"
    if isinstance(number, str) and number.isdigit():
        return all(int(number[i]) + 1 == int(number[i + 1]) for i in range(len(number) - 1))
    return False

# %%
plates['in_order'] = plates['plate_no'].apply(in_order)

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3036  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3037  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3038  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3039  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3040  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  rank  popularity  plate_no_length  \
# 0           A        0  2000000   0.0         0.0                1
# 1           A     2116     7000   0.0         0.0                4
# 2           A     3309    13000   0.0         0.0                4
# 3           A     5561     9000   0.0         0.0                4
# 4           A     6932     5000   0.0         0.0                4
# ...       ...      ...      ...   ...         ...              ...
# 3036        D      777    30000   0.0         0.0                3
# 3037        N      203    20000   0.0         0.0                3
# 3038        E        2    40000   0.0         0.0                1
# 3039        V      505    50000   0.0         0.0                3
# 3040        B     3533    15000   0.0         0.0                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 0               True         False         False         False      True
# 1              False         False         False         False     False
# 2              False         False         False         False     False
# 3              False         False         False         False     False
# 4              False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3036            True         False         False         False     False
# 3037           False         False         False         False     False
# 3038            True         False         False         False      True
# 3039           False         False          True         False     False
# 3040           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0               True       True              False                   False
# 1              False      False              False                   False
# 2              False      False              False                   False
# 3              False      False              False                   False
# 4              False      False              False                   False
# ...              ...        ...                ...                     ...
# 3036           False      False              False                   False
# 3037           False      False              False                   False
# 3038            True       True              False                   False
# 3039           False      False              False                   False
# 3040           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3036                 True                     False               False
# 3037                False                      True               False
# 3038                False                     False               False
# 3039                False                     False               False
# 3040                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 0                       False            False           False
# 1                       False             True           False
# 2                       False            False           False
# 3                       False            False           False
# 4                        True            False           False
# ...                       ...              ...             ...
# 3036                    False            False            True
# 3037                    False            False           False
# 3038                    False            False           False
# 3039                    False            False            True
# 3040                    False            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 0                  False           False            True          False
# 1                  False           False           False          False
# 2                  False           False           False          False
# 3                  False           False           False          False
# 4                  False           False           False          False
# ...                  ...             ...             ...            ...
# 3036                True            True           False          False
# 3037               False           False           False          False
# 3038               False           False           False          False
# 3039                True           False           False          False
# 3040                True            True           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 0             False            False           False           False
# 1             False            False           False           False
# 2             False            False           False           False
# 3             False            False           False           False
# 4             False            False           False           False
# ...             ...              ...             ...             ...
# 3036          False            False           False           False
# 3037          False            False           False           False
# 3038           True            False           False           False
# 3039          False            False           False           False
# 3040          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine  \
# 0             False            False            False           False
# 1             False            False            False           False
# 2             False            False            False           False
# 3             False            False            False           False
# 4             False            False            False           False
# ...             ...              ...              ...             ...
# 3036          False            False            False           False
# 3037          False            False            False           False
# 3038          False            False            False           False
# 3039          False            False            False           False
# 3040          False            False            False           False
#
#       two_consecutive_same_digits
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 3036                        False
# 3037                        False
# 3038                        False
# 3039                        False
# 3040                        False
#
# [3041 rows x 41 columns]

# %% [markdown]
# 8. reversed order consecutive numbers

# %%
def is_reversed_order(number):
    if isinstance(number, str) and number.isdigit():
        return all(int(number[i]) - 1 == int(number[i + 1]) for i in range(len(number) - 1))
    return False

# %%
plates['reversed_order'] = plates['plate_no'].apply(is_reversed_order)

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3039  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3040  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  ...  emergency_no  in_order  reversed_order  \
# 0           A        0  2000000  ...         False      True            True
# 1           A     2116     7000  ...         False     False           False
# 2           A     3309    13000  ...         False     False           False
# 3           A     5561     9000  ...         False     False           False
# 4           A     6932     5000  ...         False     False           False
# ...       ...      ...      ...  ...           ...       ...             ...
# 3038        D      777    30000  ...         False     False           False
# 3039        N      203    20000  ...         False     False           False
# 3040        E        2    40000  ...         False      True            True
# 3041        V      505    50000  ...         False     False           False
# 3042        B     3533    15000  ...         False     False           False
#
#       One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0          True              False                   False
# 1         False              False                   False
# 2         False              False                   False
# 3         False              False                   False
# 4         False              False                   False
# ...         ...                ...                     ...
# 3038      False              False                   False
# 3039      False              False                   False
# 3040       True              False                   False
# 3041      False              False                   False
# 3042      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3038                 True                     False               False
# 3039                False                      True               False
# 3040                False                     False               False
# 3041                False                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                        True
# ...                       ...
# 3038                    False
# 3039                    False
# 3040                    False
# 3041                    False
# 3042                    False
#
# [3043 rows x 26 columns]

# %% [markdown]
# 9. place of similarity

# %% [markdown]
# 9.1 Same two middle digits in four-digit plate number

# %%
def has_repeating_middle(row):
    pattern = r"^\d(\d)\1\d$"
    return bool(re.match(pattern, row))

# %%
plates['same_middles_no'] = plates['plate_no'].apply(has_repeating_middle)

# %%
plates[plates['same_middles_no'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 6         أ أ ح      A A J        أ        أ        ح        A        A
# 9         أ أ ك      A A K        أ        أ        ك        A        A
# 18        أ ر ر      A R R        أ        ر        ر        A        R
# 19        أ ر ص      A R X        أ        ر        ص        A        R
# ...         ...        ...      ...      ...      ...      ...      ...
# 2982  ا   ع   ح  J   E   A        ا        ع        ح        A        E
# 2997  ا   م   ح  J   Z   A        ا        م        ح        A        Z
# 3015  ا   ك   ح  J   K   A        ا        ك        ح        A        K
# 3017  ح   ل   م  Z   L   J        ح        ل        م        J        L
# 3037  ب   ا   م  Z   A   B        ب        ا        م        B        A
#
#      char3_en plate_no  price    rank  popularity  plate_no_length  \
# 1           A     2116   7000     0.0       0.000                4
# 6           J     5555  60000     0.0       0.000                4
# 9           K     1009   9000     0.0       0.000                4
# 18          R     9993   6000     0.0       0.000                4
# 19          X     3003   4000     0.0       0.000                4
# ...       ...      ...    ...     ...         ...              ...
# 2982        J     7227   6000     0.0       0.000                4
# 2997        J     5552  10000     0.0       0.000                4
# 3015        J     7000  10000     0.0       0.000                4
# 3017        Z     8444  10000  1613.0       0.057                4
# 3037        Z     8333  10000     0.0       0.000                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 1              False         False         False         False     False
# 6               True         False         False         False     False
# 9              False         False         False         False     False
# 18             False         False         False         False     False
# 19             False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 2982           False         False         False         False     False
# 2997           False         False         False         False     False
# 3015           False         False         False         False     False
# 3017           False         False         False         False     False
# 3037           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 1              False      False              False                   False
# 6              False      False              False                   False
# 9              False      False              False                   False
# 18             False      False              False                   False
# 19             False      False              False                   False
# ...              ...        ...                ...                     ...
# 2982           False      False              False                   False
# 2997           False      False              False                   False
# 3015           False      False              False                   False
# 3017           False      False              False                   False
# 3037           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 1                   False                     False               False
# 6                   False                     False                True
# 9                   False                     False               False
# 18                  False                     False               False
# 19                  False                     False               False
# ...                   ...                       ...                 ...
# 2982                False                     False               False
# 2997                False                     False               False
# 3015                False                     False               False
# 3017                False                     False               False
# 3037                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 1                       False             True           False
# 6                       False             True            True
# 9                       False             True           False
# 18                      False             True           False
# 19                      False             True            True
# ...                       ...              ...             ...
# 2982                    False             True            True
# 2997                    False             True           False
# 3015                    False             True           False
# 3017                    False             True           False
# 3037                    False             True           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 1                  False           False           False          False
# 6                   True            True           False          False
# 9                  False           False           False          False
# 18                 False           False           False          False
# 19                  True           False           False          False
# ...                  ...             ...             ...            ...
# 2982                True           False           False          False
# 2997               False           False           False          False
# 3015               False            True           False          False
# 3017               False            True           False          False
# 3037               False            True           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 1             False            False           False           False
# 6             False            False           False           False
# 9             False            False           False           False
# 18            False            False           False           False
# 19            False            False           False           False
# ...             ...              ...             ...             ...
# 2982          False            False           False           False
# 2997          False            False           False           False
# 3015          False            False           False           False
# 3017          False            False           False           False
# 3037          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine
# 1             False            False            False           False
# 6             False            False            False           False
# 9             False            False            False           False
# 18            False            False            False           False
# 19            False            False            False           False
# ...             ...              ...              ...             ...
# 2982          False            False            False           False
# 2997          False            False            False           False
# 3015          False            False            False           False
# 3017          False            False            False           False
# 3037          False            False            False           False
#
# [348 rows x 40 columns]

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3039  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3040  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  rank  popularity  plate_no_length  \
# 0           A        0  2000000   0.0         0.0                1
# 1           A     2116     7000   0.0         0.0                4
# 2           A     3309    13000   0.0         0.0                4
# 3           A     5561     9000   0.0         0.0                4
# 4           A     6932     5000   0.0         0.0                4
# ...       ...      ...      ...   ...         ...              ...
# 3038        D      777    30000   0.0         0.0                3
# 3039        N      203    20000   0.0         0.0                3
# 3040        E        2    40000   0.0         0.0                1
# 3041        V      505    50000   0.0         0.0                3
# 3042        B     3533    15000   0.0         0.0                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 0               True         False         False         False      True
# 1              False         False         False         False     False
# 2              False         False         False         False     False
# 3              False         False         False         False     False
# 4              False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3038            True         False         False         False     False
# 3039           False         False         False         False     False
# 3040            True         False         False         False      True
# 3041           False         False          True         False     False
# 3042           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0               True       True              False                   False
# 1              False      False              False                   False
# 2              False      False              False                   False
# 3              False      False              False                   False
# 4              False      False              False                   False
# ...              ...        ...                ...                     ...
# 3038           False      False              False                   False
# 3039           False      False              False                   False
# 3040            True       True              False                   False
# 3041           False      False              False                   False
# 3042           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3038                 True                     False               False
# 3039                False                      True               False
# 3040                False                     False               False
# 3041                False                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)  same_middles_no
# 0                       False            False
# 1                       False             True
# 2                       False            False
# 3                       False            False
# 4                        True            False
# ...                       ...              ...
# 3038                    False            False
# 3039                    False            False
# 3040                    False            False
# 3041                    False            False
# 3042                    False            False
#
# [3043 rows x 27 columns]

# %% [markdown]
# 9.2 plaindormic plate numbers

# %%
# plaindromic is a word that is read the same from left to right or right to left 
def has_palindromic_pattern(plate_no):
    pattern = r"^(\d)(\d)?\2?\1$"  
    return bool(re.match(pattern, plate_no))

# %%
pd.set_option('display.max_columns', None)

# %%
plates['plaindromic_no'] = plates['plate_no'].apply(has_palindromic_pattern)

# %%
plates[plates['plaindromic_no'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 6         أ أ ح      A A J        أ        أ        ح        A        A
# 15        أ ب ن      A B N        أ        ب        ن        A        B
# 19        أ ر ص      A R X        أ        ر        ص        A        R
# 27        أ ص ن      A X N        أ        ص        ن        A        X
# 28        أ ط ل      A T L        أ        ط        ل        A        T
# ...         ...        ...      ...      ...      ...      ...      ...
# 3013  و   و   س  S   U   U        و        و        س        U        U
# 3014  ع   ل   و  U   L   E        ع        ل        و        E        L
# 3025  ه   ه   س  S   H   H        ه        ه        س        H        H
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
#
#      char3_en plate_no  price     rank  popularity  plate_no_length  \
# 6           J     5555  60000      0.0       0.000                4
# 15          N       88  30000   6577.0       0.055                2
# 19          X     3003   4000      0.0       0.000                4
# 27          N     9449   5000      0.0       0.000                4
# 28          L     1111  50000      0.0       0.000                4
# ...       ...      ...    ...      ...         ...              ...
# 3013        S      808  10000      0.0       0.000                3
# 3014        U      404  25000  13174.0       0.222                3
# 3025        S       22  50000      0.0       0.000                2
# 3038        D      777  30000      0.0       0.000                3
# 3041        V      505  50000      0.0       0.000                3
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 6               True         False         False         False     False
# 15              True         False         False         False     False
# 19             False         False         False         False     False
# 27             False         False         False         False     False
# 28              True         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3013           False         False         False         False     False
# 3014           False         False          True         False     False
# 3025            True         False         False         False     False
# 3038            True         False         False         False     False
# 3041           False         False          True         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 6              False      False              False                   False
# 15             False      False               True                   False
# 19             False      False              False                   False
# 27             False      False              False                   False
# 28             False      False              False                   False
# ...              ...        ...                ...                     ...
# 3013           False      False              False                   False
# 3014           False      False              False                   False
# 3025           False      False               True                   False
# 3038           False      False              False                   False
# 3041           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 6                   False                     False                True
# 15                  False                     False               False
# 19                  False                     False               False
# 27                  False                     False               False
# 28                  False                     False                True
# ...                   ...                       ...                 ...
# 3013                False                     False               False
# 3014                False                     False               False
# 3025                False                     False               False
# 3038                 True                     False               False
# 3041                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no
# 6                       False             True            True
# 15                      False            False            True
# 19                      False             True            True
# 27                      False             True            True
# 28                      False             True            True
# ...                       ...              ...             ...
# 3013                    False            False            True
# 3014                    False            False            True
# 3025                    False            False            True
# 3038                    False            False            True
# 3041                    False            False            True
#
# [678 rows x 28 columns]

# %% [markdown]
# 9.3 the same first and last digits

# %%
def has_matching_first_last(plate_no):
    pattern = r"^(\d)(\d{0,2})\1$"
    return bool(re.match(pattern, plate_no))

# %%
plates['same_first_last_no'] = plates['plate_no'].apply(has_matching_first_last)

# %%
plates[plates['same_first_last_no'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 6         أ أ ح      A A J        أ        أ        ح        A        A
# 13        أ ب ل      A B L        أ        ب        ل        A        B
# 15        أ ب ن      A B N        أ        ب        ن        A        B
# 16        أ د ب      A D B        أ        د        ب        A        D
# 19        أ ر ص      A R X        أ        ر        ص        A        R
# ...         ...        ...      ...      ...      ...      ...      ...
# 3014  ع   ل   و  U   L   E        ع        ل        و        E        L
# 3025  ه   ه   س  S   H   H        ه        ه        س        H        H
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no  price     rank  popularity  plate_no_length  \
# 6           J     5555  60000      0.0       0.000                4
# 13          L     8188  25000      0.0       0.000                4
# 15          N       88  30000   6577.0       0.055                2
# 16          B     9099  12000      0.0       0.000                4
# 19          X     3003   4000      0.0       0.000                4
# ...       ...      ...    ...      ...         ...              ...
# 3014        U      404  25000  13174.0       0.222                3
# 3025        S       22  50000      0.0       0.000                2
# 3038        D      777  30000      0.0       0.000                3
# 3041        V      505  50000      0.0       0.000                3
# 3042        B     3533  15000      0.0       0.000                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 6               True         False         False         False     False
# 13             False         False         False         False     False
# 15              True         False         False         False     False
# 16             False         False         False         False     False
# 19             False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3014           False         False          True         False     False
# 3025            True         False         False         False     False
# 3038            True         False         False         False     False
# 3041           False         False          True         False     False
# 3042           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 6              False      False              False                   False
# 13             False      False              False                   False
# 15             False      False               True                   False
# 16             False      False              False                   False
# 19             False      False              False                   False
# ...              ...        ...                ...                     ...
# 3014           False      False              False                   False
# 3025           False      False               True                   False
# 3038           False      False              False                   False
# 3041           False      False              False                   False
# 3042           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 6                   False                     False                True
# 13                  False                     False               False
# 15                  False                     False               False
# 16                  False                     False               False
# 19                  False                     False               False
# ...                   ...                       ...                 ...
# 3014                False                     False               False
# 3025                False                     False               False
# 3038                 True                     False               False
# 3041                False                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 6                       False             True            True
# 13                      False            False           False
# 15                      False            False            True
# 16                      False            False           False
# 19                      False             True            True
# ...                       ...              ...             ...
# 3014                    False            False            True
# 3025                    False            False            True
# 3038                    False            False            True
# 3041                    False            False            True
# 3042                    False            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 6                   True            True           False          False
# 13                  True            True           False          False
# 15                  True            True           False          False
# 16                  True            True           False          False
# 19                  True           False           False          False
# ...                  ...             ...             ...            ...
# 3014                True           False           False          False
# 3025                True            True           False          False
# 3038                True            True           False          False
# 3041                True           False           False          False
# 3042                True            True           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 6             False            False           False           False
# 13            False            False           False           False
# 15            False            False           False           False
# 16            False            False           False           False
# 19            False            False           False           False
# ...             ...              ...             ...             ...
# 3014          False            False           False           False
# 3025          False            False           False           False
# 3038          False            False           False           False
# 3041          False            False           False           False
# 3042          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine
# 6             False            False            False           False
# 13            False            False            False           False
# 15            False            False            False           False
# 16            False            False            False           False
# 19            False            False            False           False
# ...             ...              ...              ...             ...
# 3014          False            False            False           False
# 3025          False            False            False           False
# 3038          False            False            False           False
# 3041          False            False            False           False
# 3042          False            False            False           False
#
# [751 rows x 40 columns]

# %% [markdown]
# 9.4 repeating sides (two lefts or two rights)

# %%
def has_repeating_sides(plate_no):
    pattern = r"^(\d)\1\d?$|^(\d)\1\d\d$|^\d?(\d)\3$|^\d\d(\d)\4$"
    return bool(re.match(pattern, plate_no))

# %%
plates['same_two_sides'] = plates['plate_no'].apply(has_repeating_sides)

# %%
plates[plates['same_two_sides'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 5         أ أ ب      A A B        أ        أ        ب        A        A
# 6         أ أ ح      A A J        أ        أ        ح        A        A
# 8         أ أ ط      A A T        أ        أ        ط        A        A
# 10        أ أ ن      A A N        أ        أ        ن        A        A
# 13        أ ب ل      A B L        أ        ب        ل        A        B
# ...         ...        ...      ...      ...      ...      ...      ...
# 3035  د   ك   ك  K   K   D        د        ك        ك        D        K
# 3036  ب   ن   ك  K   N   B        ب        ن        ك        B        N
# 3037  ب   ا   م  Z   A   B        ب        ا        م        B        A
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no  price  rank  popularity  plate_no_length  \
# 5           B      667  16000   0.0         0.0                3
# 6           J     5555  60000   0.0         0.0                4
# 8           T      700   3500   0.0         0.0                3
# 10          N      300  14000   0.0         0.0                3
# 13          L     8188  25000   0.0         0.0                4
# ...       ...      ...    ...   ...         ...              ...
# 3035        K     6688  10000   0.0         0.0                4
# 3036        K     6055   5000   0.0         0.0                4
# 3037        Z     8333  10000   0.0         0.0                4
# 3038        D      777  30000   0.0         0.0                3
# 3042        B     3533  15000   0.0         0.0                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 5              False         False         False         False     False
# 6               True         False         False         False     False
# 8              False         False         False         False     False
# 10             False         False         False         False     False
# 13             False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3035           False         False         False         False     False
# 3036           False         False         False         False     False
# 3037           False         False         False         False     False
# 3038            True         False         False         False     False
# 3042           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 5              False      False              False                   False
# 6              False      False              False                   False
# 8              False      False              False                   False
# 10             False      False              False                   False
# 13             False      False              False                   False
# ...              ...        ...                ...                     ...
# 3035           False      False              False                   False
# 3036           False      False              False                   False
# 3037           False      False              False                   False
# 3038           False      False              False                   False
# 3042           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 5                   False                     False               False
# 6                   False                     False                True
# 8                   False                     False               False
# 10                  False                     False               False
# 13                  False                     False               False
# ...                   ...                       ...                 ...
# 3035                False                     False               False
# 3036                False                     False               False
# 3037                False                     False               False
# 3038                 True                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 5                       False            False           False
# 6                       False             True            True
# 8                       False            False           False
# 10                      False            False           False
# 13                      False            False           False
# ...                       ...              ...             ...
# 3035                    False            False           False
# 3036                    False            False           False
# 3037                    False             True           False
# 3038                    False            False            True
# 3042                    False            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 5                  False            True           False          False
# 6                   True            True           False          False
# 8                  False            True           False          False
# 10                 False            True           False          False
# 13                  True            True           False          False
# ...                  ...             ...             ...            ...
# 3035               False            True           False          False
# 3036               False            True           False          False
# 3037               False            True           False          False
# 3038                True            True           False          False
# 3042                True            True           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 5             False            False           False           False
# 6             False            False           False           False
# 8             False            False           False           False
# 10            False            False           False           False
# 13            False            False           False           False
# ...             ...              ...             ...             ...
# 3035          False            False           False           False
# 3036          False            False           False           False
# 3037          False            False           False           False
# 3038          False            False           False           False
# 3042          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine
# 5             False            False            False           False
# 6             False            False            False           False
# 8             False            False            False           False
# 10            False            False            False           False
# 13            False            False            False           False
# ...             ...              ...              ...             ...
# 3035          False            False            False           False
# 3036          False            False            False           False
# 3037          False            False            False           False
# 3038          False            False            False           False
# 3042          False            False            False           False
#
# [984 rows x 40 columns]

# %%
plates[plates['plate_no'] == '0']
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 367       س ح ر      S J R        س        ح        ر        S        J
# 1805  ب   ر   ق  G   R   B        ب        ر        ق        B        R
# 1846  ب   ط   ا  A   T   B        ب        ط        ا        B        T
# 2058          س          S        س      NaN      NaN        S      NaN
# 2059          س          S        س      NaN      NaN        S      NaN
# 2761  ع   ن   د  D   N   E        ع        ن        د        E        N
#
#      char3_en plate_no      price    rank  popularity  plate_no_length  \
# 0           A        0    2000000     0.0       0.000                1
# 367         R        0     400000   870.0       0.101                1
# 1805        G        0      10000  4053.0       0.426                1
# 1846        A        0       1000     0.0       0.000                1
# 2058      NaN        0  205000000     0.0       0.000                1
# 2059      NaN        0    2500000     0.0       0.000                1
# 2761        D        0       8000     0.0       0.000                1
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 0               True         False         False         False      True
# 367             True         False         False         False      True
# 1805            True         False         False         False      True
# 1846            True         False         False         False      True
# 2058            True         False         False         False      True
# 2059            True         False         False         False      True
# 2761            True         False         False         False      True
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0               True       True              False                   False
# 367             True       True              False                   False
# 1805            True       True              False                   False
# 1846            True       True              False                   False
# 2058            True       True              False                   False
# 2059            True       True              False                   False
# 2761            True       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 367                 False                     False               False
# 1805                False                     False               False
# 1846                False                     False               False
# 2058                False                     False               False
# 2059                False                     False               False
# 2761                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 0                       False            False           False
# 367                     False            False           False
# 1805                    False            False           False
# 1846                    False            False           False
# 2058                    False            False           False
# 2059                    False            False           False
# 2761                    False            False           False
#
#       same_first_last_no  same_two_sides
# 0                  False           False
# 367                False           False
# 1805               False           False
# 1846               False           False
# 2058               False           False
# 2059               False           False
# 2761               False           False

# %% [markdown]
# 10. One-digit

# %% [markdown]
# Checking the count of one-digit plates

# %%
one_digit.shape
# Out:
# (320, 19)

# %% [markdown]
# 10.1 zero

# %%
bool(re.match(patterns['One Digit'],'0') and '0'=='0')
# Out:
# True

# %%
plates['one_digit_zero'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '0'))

# %% [markdown]
# 10.2 one

# %%
plates['one_digit_one'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '1'))

# %% [markdown]
# 10.3 two

# %%
plates['one_digit_two'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '2'))

# %% [markdown]
# 10.4 three

# %%
plates['one_digit_three'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '3'))

# %% [markdown]
# 10.5 four

# %%
plates['one_digit_four'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '4'))

# %% [markdown]
# 10.6 five

# %%
plates['one_digit_five'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '5'))

# %% [markdown]
# 10.7 six

# %%
plates['one_digit_six'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '6'))

# %% [markdown]
# 10.8 seven

# %%
plates['one_digit_seven'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '7'))

# %% [markdown]
# 10.9 eight

# %%
plates['one_digit_eight'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '8'))

# %% [markdown]
# 10.10 nine

# %%
plates['one_digit_nine'] = plates['plate_no'].map(lambda x : bool(re.match(patterns['One Digit'], x) and x == '9'))

# %%
plates[plates['plate_no'] == '911']
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 86        ب س م      B S Z        ب        س        م        B        S
# 168       ح ق ك      J G K        ح        ق        ك        J        G
# 187       ح و أ      J U A        ح        و        أ        J        U
# 477       ق ل أ      G L A        ق        ل        أ        G        L
# 751       ي ق ح      J G V        ح        ق        ي        J        G
# 1330      ل ط ى      L T V        ل        ط        ى        L        T
# 1368      م س م      Z S Z        م        س        م        Z        S
# 1672  ا   ر   ب  B   R   A        ا        ر        ب        A        R
#
#      char3_en plate_no   price     rank  popularity  plate_no_length  \
# 86          Z      911  100000  12584.0       0.057                3
# 168         K      911   45000      0.0       0.000                3
# 187         A      911   60000      0.0       0.000                3
# 477         A      911   25000      0.0       0.000                3
# 751         V      911   20000      0.0       0.011                3
# 1330        V      911   25000      0.0       0.000                3
# 1368        Z      911   30000      0.0       0.000                3
# 1672        B      911    5000      0.0       0.000                3
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 86             False         False          True          True     False
# 168            False         False          True          True     False
# 187            False         False          True          True     False
# 477            False         False          True          True     False
# 751            False         False          True          True     False
# 1330           False         False          True          True     False
# 1368           False         False          True          True     False
# 1672           False         False          True          True     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 86             False      False              False                   False
# 168            False      False              False                   False
# 187            False      False              False                   False
# 477            False      False              False                   False
# 751            False      False              False                   False
# 1330           False      False              False                   False
# 1368           False      False              False                   False
# 1672           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 86                  False                     False               False
# 168                 False                     False               False
# 187                 False                     False               False
# 477                 False                     False               False
# 751                 False                     False               False
# 1330                False                     False               False
# 1368                False                     False               False
# 1672                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 86                      False            False           False
# 168                     False            False           False
# 187                     False            False           False
# 477                     False            False           False
# 751                     False            False           False
# 1330                    False            False           False
# 1368                    False            False           False
# 1672                    False            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 86                 False            True           False          False
# 168                False            True           False          False
# 187                False            True           False          False
# 477                False            True           False          False
# 751                False            True           False          False
# 1330               False            True           False          False
# 1368               False            True           False          False
# 1672               False            True           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 86            False            False           False           False
# 168           False            False           False           False
# 187           False            False           False           False
# 477           False            False           False           False
# 751           False            False           False           False
# 1330          False            False           False           False
# 1368          False            False           False           False
# 1672          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine
# 86            False            False            False           False
# 168           False            False            False           False
# 187           False            False            False           False
# 477           False            False            False           False
# 751           False            False            False           False
# 1330          False            False            False           False
# 1368          False            False            False           False
# 1672          False            False            False           False

# %%
plates.shape
# Out:
# (3043, 40)

# %%
plates[plates['one_digit_nine'] == True]
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 171       ح ك ك      J K K        ح        ك        ك        J        K
# 385       س م ى      S Z V        س        م        ى        S        Z
# 409       ص ق ن      X G N        ص        ق        ن        X        G
# 412       ص ل م      X L Z        ص        ل        م        X        L
# 591       ن م س      N Z S        ن        م        س        N        Z
# 605      هـ ب ط      H B T       هـ        ب        ط        H        B
# 651       و س أ      U S A        و        س        أ        U        S
# 863       ن و ح      J U N        ن        و        ح        N        U
# 865       ن و ح      J U N        ن        و        ح        N        U
# 870       ح ب ك      K B J        ح        ب        ك        J        B
# 871       ن ح و      U J N        ن        ح        و        N        J
# 874       ن د أ      A D N        ن        د        أ        N        D
# 891      هـ ك ر      R K H       هـ        ك        ر        H        K
# 953       ك ه س      K H S        ك        ه        س        K        H
# 1078      س ك ر      S K R        س        ك        ر        S        K
# 1112      ك ر ر      K R R        ك        ر        ر        K        R
# 1126      ى ح ع      V J E        ى        ح        ع        V        J
# 1152      ه ن م      H N Z        ه        ن        م        H        N
# 1170      ص ل ك      X L K        ص        ل        ك        X        L
# 1187      و ا ه      U A H        و        ا        ه        U        A
# 1592  ب   ه   د  D   H   B        ب        ه        د        B        H
# 1652  ن   د   ا  A   D   N        ن        د        ا        N        D
# 1811  ن   و   ح  J   U   N        ن        و        ح        N        U
# 1843  ا   ه   ى  V   H   A        ا        ه        ى        A        H
# 2331  و   ب   و  U   B   U        و        ب        و        U        B
# 2333  د   س   س  S   S   D        د        س        س        D        S
# 2484  ح   ق   ل  L   G   J        ح        ق        ل        J        G
# 2544  ع   ب   ا  A   B   E        ع        ب        ا        E        B
#
#      char3_en plate_no    price    rank  popularity  plate_no_length  \
# 171         K        9    32000     0.0       0.000                1
# 385         V        9   250000     0.0       0.136                1
# 409         N        9    64000     0.0       0.000                1
# 412         Z        9    69000     0.0       0.000                1
# 591         S        9   135000     0.0       0.104                1
# 605         T        9    85000     0.0       0.000                1
# 651         A        9    75000     0.0       0.000                1
# 863         J        9    20008  3128.0       0.168                1
# 865         J        9    20000  3128.0       0.168                1
# 870         K        9    20000     0.0       0.000                1
# 871         U        9    20000     0.0       0.000                1
# 874         A        9    20000     0.0       0.000                1
# 891         R        9    25000     0.0       0.000                1
# 953         S        9    70000     0.0       0.000                1
# 1078        R        9  1000000     0.0       0.000                1
# 1112        R        9   150000     0.0       0.000                1
# 1126        E        9    88000     0.0       0.000                1
# 1152        Z        9   155000     0.0       0.000                1
# 1170        K        9    25000     0.0       0.000                1
# 1187        H        9   120000     0.0       0.000                1
# 1592        D        9   100000     0.0       0.000                1
# 1652        A        9    20000  5789.0       0.048                1
# 1811        J        9    20000  3128.0       0.168                1
# 1843        V        9   100000     0.0       0.000                1
# 2331        U        9   200000     0.0       0.000                1
# 2333        S        9    28000     0.0       0.000                1
# 2484        L        9    75000     0.0       0.000                1
# 2544        A        9    65000     0.0       0.000                1
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 171             True         False         False         False      True
# 385             True         False         False         False      True
# 409             True         False         False         False      True
# 412             True         False         False         False      True
# 591             True         False         False         False      True
# 605             True         False         False         False      True
# 651             True         False         False         False      True
# 863             True         False         False         False      True
# 865             True         False         False         False      True
# 870             True         False         False         False      True
# 871             True         False         False         False      True
# 874             True         False         False         False      True
# 891             True         False         False         False      True
# 953             True         False         False         False      True
# 1078            True         False         False         False      True
# 1112            True         False         False         False      True
# 1126            True         False         False         False      True
# 1152            True         False         False         False      True
# 1170            True         False         False         False      True
# 1187            True         False         False         False      True
# 1592            True         False         False         False      True
# 1652            True         False         False         False      True
# 1811            True         False         False         False      True
# 1843            True         False         False         False      True
# 2331            True         False         False         False      True
# 2333            True         False         False         False      True
# 2484            True         False         False         False      True
# 2544            True         False         False         False      True
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 171             True       True              False                   False
# 385             True       True              False                   False
# 409             True       True              False                   False
# 412             True       True              False                   False
# 591             True       True              False                   False
# 605             True       True              False                   False
# 651             True       True              False                   False
# 863             True       True              False                   False
# 865             True       True              False                   False
# 870             True       True              False                   False
# 871             True       True              False                   False
# 874             True       True              False                   False
# 891             True       True              False                   False
# 953             True       True              False                   False
# 1078            True       True              False                   False
# 1112            True       True              False                   False
# 1126            True       True              False                   False
# 1152            True       True              False                   False
# 1170            True       True              False                   False
# 1187            True       True              False                   False
# 1592            True       True              False                   False
# 1652            True       True              False                   False
# 1811            True       True              False                   False
# 1843            True       True              False                   False
# 2331            True       True              False                   False
# 2333            True       True              False                   False
# 2484            True       True              False                   False
# 2544            True       True              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 171                 False                     False               False
# 385                 False                     False               False
# 409                 False                     False               False
# 412                 False                     False               False
# 591                 False                     False               False
# 605                 False                     False               False
# 651                 False                     False               False
# 863                 False                     False               False
# 865                 False                     False               False
# 870                 False                     False               False
# 871                 False                     False               False
# 874                 False                     False               False
# 891                 False                     False               False
# 953                 False                     False               False
# 1078                False                     False               False
# 1112                False                     False               False
# 1126                False                     False               False
# 1152                False                     False               False
# 1170                False                     False               False
# 1187                False                     False               False
# 1592                False                     False               False
# 1652                False                     False               False
# 1811                False                     False               False
# 1843                False                     False               False
# 2331                False                     False               False
# 2333                False                     False               False
# 2484                False                     False               False
# 2544                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 171                     False            False           False
# 385                     False            False           False
# 409                     False            False           False
# 412                     False            False           False
# 591                     False            False           False
# 605                     False            False           False
# 651                     False            False           False
# 863                     False            False           False
# 865                     False            False           False
# 870                     False            False           False
# 871                     False            False           False
# 874                     False            False           False
# 891                     False            False           False
# 953                     False            False           False
# 1078                    False            False           False
# 1112                    False            False           False
# 1126                    False            False           False
# 1152                    False            False           False
# 1170                    False            False           False
# 1187                    False            False           False
# 1592                    False            False           False
# 1652                    False            False           False
# 1811                    False            False           False
# 1843                    False            False           False
# 2331                    False            False           False
# 2333                    False            False           False
# 2484                    False            False           False
# 2544                    False            False           False
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 171                False           False           False          False
# 385                False           False           False          False
# 409                False           False           False          False
# 412                False           False           False          False
# 591                False           False           False          False
# 605                False           False           False          False
# 651                False           False           False          False
# 863                False           False           False          False
# 865                False           False           False          False
# 870                False           False           False          False
# 871                False           False           False          False
# 874                False           False           False          False
# 891                False           False           False          False
# 953                False           False           False          False
# 1078               False           False           False          False
# 1112               False           False           False          False
# 1126               False           False           False          False
# 1152               False           False           False          False
# 1170               False           False           False          False
# 1187               False           False           False          False
# 1592               False           False           False          False
# 1652               False           False           False          False
# 1811               False           False           False          False
# 1843               False           False           False          False
# 2331               False           False           False          False
# 2333               False           False           False          False
# 2484               False           False           False          False
# 2544               False           False           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 171           False            False           False           False
# 385           False            False           False           False
# 409           False            False           False           False
# 412           False            False           False           False
# 591           False            False           False           False
# 605           False            False           False           False
# 651           False            False           False           False
# 863           False            False           False           False
# 865           False            False           False           False
# 870           False            False           False           False
# 871           False            False           False           False
# 874           False            False           False           False
# 891           False            False           False           False
# 953           False            False           False           False
# 1078          False            False           False           False
# 1112          False            False           False           False
# 1126          False            False           False           False
# 1152          False            False           False           False
# 1170          False            False           False           False
# 1187          False            False           False           False
# 1592          False            False           False           False
# 1652          False            False           False           False
# 1811          False            False           False           False
# 1843          False            False           False           False
# 2331          False            False           False           False
# 2333          False            False           False           False
# 2484          False            False           False           False
# 2544          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight  one_digit_nine
# 171           False            False            False            True
# 385           False            False            False            True
# 409           False            False            False            True
# 412           False            False            False            True
# 591           False            False            False            True
# 605           False            False            False            True
# 651           False            False            False            True
# 863           False            False            False            True
# 865           False            False            False            True
# 870           False            False            False            True
# 871           False            False            False            True
# 874           False            False            False            True
# 891           False            False            False            True
# 953           False            False            False            True
# 1078          False            False            False            True
# 1112          False            False            False            True
# 1126          False            False            False            True
# 1152          False            False            False            True
# 1170          False            False            False            True
# 1187          False            False            False            True
# 1592          False            False            False            True
# 1652          False            False            False            True
# 1811          False            False            False            True
# 1843          False            False            False            True
# 2331          False            False            False            True
# 2333          False            False            False            True
# 2484          False            False            False            True
# 2544          False            False            False            True

# %%
plates.sort_values(by='price', ascending=False).head(20)
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 2285  ه   ك   ن  N   K   H        ه        ك        ن        H        K
# 2118  د   ح   ط  T   J   D        د        ح        ط        D        J
# 2107  د   ح   ط  T   J   D        د        ح        ط        D        J
# 2108  د   ح   ط  T   J   D        د        ح        ط        D        J
# 2261  ب   و   ب  B   U   B        ب        و        ب        B        U
# 2080  د   ح   ط  T   J   D        د        ح        ط        D        J
# 2058          س          S        س      NaN      NaN        S      NaN
# 1266      ب ب ى      B B V        ب        ب        ى        B        B
# 688       ى ق ح      V G J        ى        ق        ح        V        G
# 1868  ن   ل   س  S   L   N        ن        ل        س        N        L
# 895       ل ح ن      N J L        ل        ح        ن        L        J
# 123       ب و ق      B U G        ب        و        ق        B        U
# 387       س ن ر      S N R        س        ن        ر        S        N
# 2059          س          S        س      NaN      NaN        S      NaN
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1121      م ك ه      Z K H        م        ك        ه        Z        K
# 2789  ه   ب   ا  A   B   H        ه        ب        ا        H        B
# 1789  د   م   د  D   Z   D        د        م        د        D        Z
# 1078      س ك ر      S K R        س        ك        ر        S        K
# 2069  ن   ا   ر  R   A   N        ن        ا        ر        N        A
#
#      char3_en plate_no         price     rank  popularity  plate_no_length  \
# 2285        N       80  999999999999      0.0       0.000                2
# 2118        T      999  108446043404      0.0       0.000                3
# 2107        T      999    7643844543      0.0       0.000                3
# 2108        T      999    2484543484      0.0       0.000                3
# 2261        B      707     552318009  11202.0       0.070                3
# 2080        T      999     310443054      0.0       0.000                3
# 2058      NaN        0     205000000      0.0       0.000                1
# 1266        V        1       7000000      0.0       0.000                1
# 688         J      979       5250000      0.0       0.000                3
# 1868        S      555       5000000      0.0       0.000                3
# 895         N        7       4700000   3326.0       0.059                1
# 123         G     7373       4000000      0.0       0.000                4
# 387         R        1       2500000      0.0       0.000                1
# 2059      NaN        0       2500000      0.0       0.000                1
# 0           A        0       2000000      0.0       0.000                1
# 1121        H       10       1100000   9148.0       0.073                2
# 2789        A        1       1100000      0.0       0.046                1
# 1789        D     8888       1010101      0.0       0.000                4
# 1078        R        9       1000000      0.0       0.000                1
# 2069        R      393       1000000      0.0       0.000                3
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 2285           False         False         False         False     False
# 2118            True         False         False          True     False
# 2107            True         False         False          True     False
# 2108            True         False         False          True     False
# 2261           False         False          True         False     False
# 2080            True         False         False          True     False
# 2058            True         False         False         False      True
# 1266            True         False         False         False      True
# 688            False         False         False         False     False
# 1868            True         False          True         False     False
# 895             True         False         False         False      True
# 123            False         False         False         False     False
# 387             True         False         False         False      True
# 2059            True         False         False         False      True
# 0               True         False         False         False      True
# 1121           False         False         False         False     False
# 2789            True         False         False         False      True
# 1789            True         False         False         False     False
# 1078            True         False         False         False      True
# 2069           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 2285            True      False              False                    True
# 2118           False      False              False                   False
# 2107           False      False              False                   False
# 2108           False      False              False                   False
# 2261           False      False              False                   False
# 2080           False      False              False                   False
# 2058            True       True              False                   False
# 1266            True       True              False                   False
# 688            False      False              False                   False
# 1868           False      False              False                   False
# 895             True       True              False                   False
# 123            False      False              False                   False
# 387             True       True              False                   False
# 2059            True       True              False                   False
# 0               True       True              False                   False
# 1121            True      False              False                    True
# 2789            True       True              False                   False
# 1789           False      False              False                   False
# 1078            True       True              False                   False
# 2069           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 2285                False                     False               False
# 2118                 True                     False               False
# 2107                 True                     False               False
# 2108                 True                     False               False
# 2261                False                     False               False
# 2080                 True                     False               False
# 2058                False                     False               False
# 1266                False                     False               False
# 688                 False                     False               False
# 1868                 True                     False               False
# 895                 False                     False               False
# 123                 False                     False               False
# 387                 False                     False               False
# 2059                False                     False               False
# 0                   False                     False               False
# 1121                False                     False               False
# 2789                False                     False               False
# 1789                False                     False                True
# 1078                False                     False               False
# 2069                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 2285                    False            False           False
# 2118                    False            False            True
# 2107                    False            False            True
# 2108                    False            False            True
# 2261                    False            False            True
# 2080                    False            False            True
# 2058                    False            False           False
# 1266                    False            False           False
# 688                     False            False            True
# 1868                    False            False            True
# 895                     False            False           False
# 123                     False            False           False
# 387                     False            False           False
# 2059                    False            False           False
# 0                       False            False           False
# 1121                    False            False           False
# 2789                    False            False           False
# 1789                    False             True            True
# 1078                    False            False           False
# 2069                    False            False            True
#
#       same_first_last_no  same_two_sides  one_digit_zero  one_digit_one  \
# 2285               False           False           False          False
# 2118                True            True           False          False
# 2107                True            True           False          False
# 2108                True            True           False          False
# 2261                True           False           False          False
# 2080                True            True           False          False
# 2058               False           False            True          False
# 1266               False           False           False           True
# 688                 True           False           False          False
# 1868                True            True           False          False
# 895                False           False           False          False
# 123                False           False           False          False
# 387                False           False           False           True
# 2059               False           False            True          False
# 0                  False           False            True          False
# 1121               False           False           False          False
# 2789               False           False           False           True
# 1789                True            True           False          False
# 1078               False           False           False          False
# 2069                True           False           False          False
#
#       one_digit_two  one_digit_three  one_digit_four  one_digit_five  \
# 2285          False            False           False           False
# 2118          False            False           False           False
# 2107          False            False           False           False
# 2108          False            False           False           False
# 2261          False            False           False           False
# 2080          False            False           False           False
# 2058          False            False           False           False
# 1266          False            False           False           False
# 688           False            False           False           False
# 1868          False            False           False           False
# 895           False            False           False           False
# 123           False            False           False           False
# 387           False            False           False           False
# 2059          False            False           False           False
# 0             False            False           False           False
# 1121          False            False           False           False
# 2789          False            False           False           False
# 1789          False            False           False           False
# 1078          False            False           False           False
# 2069          False            False           False           False
#
#       one_digit_six  one_digit_seven  one_digit_eight
# 2285          False            False            False
# 2118          False            False            False
# 2107          False            False            False
# 2108          False            False            False
# 2261          False            False            False
# 2080          False            False            False
# 2058          False            False            False
# 1266          False            False            False
# 688           False            False            False
# 1868          False            False            False
# 895           False             True            False
# 123           False            False            False
# 387           False            False            False
# 2059          False            False            False
# 0             False            False            False
# 1121          False            False            False
# 2789          False            False            False
# 1789          False            False            False
# 1078          False            False            False
# 2069          False            False            False

# %%
plates
# Out:
#         char_ar    char_en char1_ar char2_ar char3_ar char1_en char2_en  \
# 0         أ أ أ      A A A        أ        أ        أ        A        A
# 1         أ أ أ      A A A        أ        أ        أ        A        A
# 2         أ أ أ      A A A        أ        أ        أ        A        A
# 3         أ أ أ      A A A        أ        أ        أ        A        A
# 4         أ أ أ      A A A        أ        أ        أ        A        A
# ...         ...        ...      ...      ...      ...      ...      ...
# 3038  ر   ص   د  D   X   R        ر        ص        د        R        X
# 3039  ه   م   ن  N   Z   H        ه        م        ن        H        Z
# 3040  د   ص   ع  E   X   D        د        ص        ع        D        X
# 3041  ب   ى   ى  V   V   B        ب        ى        ى        B        V
# 3042  ر   ع   ب  B   E   R        ر        ع        ب        R        E
#
#      char3_en plate_no    price  rank  popularity  plate_no_length  \
# 0           A        0  2000000   0.0         0.0                1
# 1           A     2116     7000   0.0         0.0                4
# 2           A     3309    13000   0.0         0.0                4
# 3           A     5561     9000   0.0         0.0                4
# 4           A     6932     5000   0.0         0.0                4
# ...       ...      ...      ...   ...         ...              ...
# 3038        D      777    30000   0.0         0.0                3
# 3039        N      203    20000   0.0         0.0                3
# 3040        E        2    40000   0.0         0.0                1
# 3041        V      505    50000   0.0         0.0                3
# 3042        B     3533    15000   0.0         0.0                4
#
#       similar_digits  sepcial_date  saudi_tribes  emergency_no  in_order  \
# 0               True         False         False         False      True
# 1              False         False         False         False     False
# 2              False         False         False         False     False
# 3              False         False         False         False     False
# 4              False         False         False         False     False
# ...              ...           ...           ...           ...       ...
# 3038            True         False         False         False     False
# 3039           False         False         False         False     False
# 3040            True         False         False         False      True
# 3041           False         False          True         False     False
# 3042           False         False         False         False     False
#
#       reversed_order  One Digit  Two Digits (Same)  Two Digits (Different)  \
# 0               True       True              False                   False
# 1              False      False              False                   False
# 2              False      False              False                   False
# 3              False      False              False                   False
# 4              False      False              False                   False
# ...              ...        ...                ...                     ...
# 3038           False      False              False                   False
# 3039           False      False              False                   False
# 3040            True       True              False                   False
# 3041           False      False              False                   False
# 3042           False      False              False                   False
#
#       Three Digits (Same)  Three Digits (Different)  Four Digits (Same)  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                   False                     False               False
# 4                   False                     False               False
# ...                   ...                       ...                 ...
# 3038                 True                     False               False
# 3039                False                      True               False
# 3040                False                     False               False
# 3041                False                     False               False
# 3042                False                     False               False
#
#       Four Digits (Different)  same_middles_no  plaindromic_no  \
# 0                       False            False           False
# 1                       False             True           False
# 2                       False            False           False
# 3                       False            False           False
# 4                        True            False           False
# ...                       ...              ...             ...
# 3038                    False            False            True
# 3039                    False            False           False
# 3040                    False            False           False
# 3041                    False            False            True
# 3042                    False            False           False
#
#       same_first_last_no  same_two_sides
# 0                  False           False
# 1                  False           False
# 2                  False           False
# 3                  False           False
# 4                  False           False
# ...                  ...             ...
# 3038                True            True
# 3039               False           False
# 3040               False           False
# 3041                True           False
# 3042                True            True
#
# [3043 rows x 30 columns]

# %%
# dropping illegal compenation 
plates = plates[plates['char_en'] != 'A S S']

# %%
plates.to_csv('plates_no_features.csv', index=False)

# %%
filtering = plates.select_dtypes(include=['number', 'bool'])
corr_matrix = filtering.corr()


plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Heatmap of Feature Correlations")
plt.show()
